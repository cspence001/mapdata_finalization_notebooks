# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# <b>PIPE

# %% [markdown]
# <b>MAIN PIPE file addition

# %%
ppp_pipe = pd.read_csv("../data/ppp_pipe.csv")
ppp_pipe.head()
ppp_pipe.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'LoanNumber', 'SBAOfficeCode',
#        'ProcessingMethod', 'BorrowerName', 'BorrowerAddress', 'BorrowerCity',
#        'BorrowerState', 'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
# ...

# %%
#ppp_pipe['ServicingLenderLocationID'].nunique()#can haave option to display markers for servicing lender, radius by $
#ppp_pipe['TRIIndustrySector'].value_counts() #Alternate display by

# %% [markdown]
# <b>MAIN PIPE column selection

# %%
#keep track of columns removed
dele = ['Unnamed: 0', 'BorrowerAddress', 'BorrowerCity', 'BorrowerZip', 'SBAGuarantyPercentage', 'InitialApprovalAmount', 'RuralUrbanIndicator', 'HubzoneIndicator',  'LMIIndicator', 
 'BusinessAgeDescription', 'ProjectCity','ProjectCountyName', 'ProjectState', 'ProjectZip','Race', 'Ethnicity', 'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState', 'ServicingLenderZip', 
 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'DateApproved_ts', 'ForgivenessDate_ts',
 'HEALTH_CARE_PROCEED','DEBT_INTEREST_PROCEED', 'NA', '4DigitNAICS', 'NAICSCode', 'Industry', 'IndustrySubsector', 'TRIIndustrySector', 'Loan_Range', 'job_Range', 'Gender', 'Veteran']
#Industry and Industry Subsector taken from HASH file (NAICS)
cols =['LoanNumber', 'DateApprovedTS', 'SBAOfficeCode', 'SBAOfficeLabel','ProcessingMethod', 'BorrowerName', 
       'BorrowerState', 'LoanStatusDate', 'LoanStatus', 'Term', 'CurrentApprovalAmount', 'UndisbursedAmount', 
       'FranchiseName','ServicingLenderLocationID', 'ServicingLenderName', 
       'CD', 'JobsReported', 'OriginatingLenderLocationID', 'OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
       'BusinessType', 'BusinessAgeDescription', 'NonProfit', 'ForgivenessAmount', 'ForgivenessDateTS', 'Estimated_LenderPercent', 'Estimated_LenderProfit', 
       'LongName', 'full_add']

ppp_pipe = ppp_pipe[cols]
ppp_pipe.head()
# Out:
#    LoanNumber  DateApprovedTS  SBAOfficeCode                  SBAOfficeLabel  \
# 0  9547507704        20200501            464  SOUTH CAROLINA DISTRICT OFFICE
# 1  9777677704        20200501            464  SOUTH CAROLINA DISTRICT OFFICE
# 2  5791407702        20200501           1013         SEATTLE DISTRICT OFFICE
# 3  6223567700        20200501            920       SANTA ANA DISTRICT OFFICE
# 4  9662437702        20200501            101   MASSACHUSETTS DISTRICT OFFICE
#
#   ProcessingMethod              BorrowerName BorrowerState LoanStatusDate  \
# 0              PPP     SUMTER COATINGS, INC.            SC       12/18/20
# 1              PPP     PLEASANT PLACES, INC.            SC        9/28/21
# 2              PPP   BOYER CHILDREN'S CLINIC            WA        3/17/21
# 3              PPP  KIRTLEY CONSTRUCTION INC            CA       10/16/21
# 4              PPP              AERO BOX LLC            MI        8/17/21
#
# ...

# %% [markdown]
# <b>HASH file addition

# %%
ppp_hash = pd.read_csv("../data/ppp_hashSort.csv") 
cols = ["LoanNumber", "HASHcodePM", "Industry", "IndustrySubsector"]
ppp_hash = ppp_hash[cols]
ppp_hash
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707    IND0SS0LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707    IND0SS0LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701    IND0SS0LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702    IND0SS0LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708    IND0SS0LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
# ...

# %% [markdown]
# <b>GEO, FIPS file addition

# %%
ppp_geo_fips=pd.read_csv("../data/state_data/geo/ppp_geo_fips.csv")
cols= ["LoanNumber", "Lat", "Long", "FIPS_z"]
result = ppp_geo_fips[cols]
result
# Out:
#         LoanNumber        Lat        Long        FIPS_z
# 0       9547507704  33.853682  -80.369867  4.508500e+14
# 1       9777677704  32.942332  -80.066165  4.501900e+14
# 2       5791407702  47.636067 -122.302559  5.303301e+14
# 3       6223567700  34.224719 -117.372550  6.071005e+13
# 4       9662437702  42.521828  -82.913680  2.609926e+14
# ...            ...        ...         ...           ...
# 968552  4395967002  42.850300 -106.304365  5.602500e+14
# 968553  6985647108  41.499071 -109.464675  5.603797e+14
# 968554  7996438405  44.435381 -105.226008  5.600500e+14
# 968555  9054647103  44.797763 -106.954952  5.603300e+14
# 968556  9184687004  43.587714 -110.822222  5.603997e+14
#
# [968557 rows x 4 columns]

# %% [markdown]
# <b>Merged DataFrame

# %%
#merge 
ppp_hash_pipe = ppp_hash.merge(ppp_pipe, on="LoanNumber", how="left")
ppp_hash_pipe
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
# ...

# %%
ppp_hpgf = ppp_hash_pipe.merge(result, on="LoanNumber", how="left")
ppp_hpgf
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
# ...

# %%
pd.set_option('display.max_rows', 40)
print(ppp_hpgf.isnull().sum())
# Out:
# LoanNumber                          0
# HASHcodePM                          0
# Industry                            0
# IndustrySubsector                   0
# DateApprovedTS                      0
# SBAOfficeCode                       0
# SBAOfficeLabel                      0
# ProcessingMethod                    0
# BorrowerName                        4
# BorrowerState                       0
# LoanStatusDate                 281932
# LoanStatus                          0
# Term                                0
# CurrentApprovalAmount               0
# UndisbursedAmount                 219
# FranchiseName                  933151
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# CD                                 46
# JobsReported                        1
# OriginatingLenderLocationID         0
# OriginatingLender                   0
# OriginatingLenderCity               0
# OriginatingLenderState              0
# BusinessType                        0
# ...

# %%
#Lat='None'>NaN 
ppp_hpgf["Lat"].replace(r'None', np.nan, regex=True)
# Out:
# 0          37.94451
# 1         34.521182
# 2         32.942704
# 3         33.797606
# 4         33.658618
#             ...
# 968552    32.912807
# 968553    47.661514
# 968554    27.929674
# 968555    26.334795
# 968556    36.130811
# Name: Lat, Length: 968557, dtype: object

# %%
#pd.set_option('display.max_rows', None)
latlong_ch= ppp_hpgf.loc[ppp_hpgf["Long"].isnull()] #479618 merge from fips / #479586 merge from geo
latlong_ch
# Out:
#         LoanNumber                 HASHcodePM  \
# 884     9053367710  IND00SS00LR1JR3BT01BA1PPP
# 13870   9284477302  IND11SS19LR3JR6BT01BA1PPP
# 14453   8029977308  IND11SS21LR1JR4BT01BA1PPP
# 17735   7239557206  IND11SS33LR1JR3BT01BA1PPP
# 31292   7382587207  IND22SS12LR2JR4BT02BA1PPP
# ...            ...                        ...
# 905701  7766498406  IND81SS11LR1JR3BT01BA1PPS
# 906203  6905957010  IND81SS11LR1JR3BT02BA1PPP
# 915389  9787997710  IND81SS13LR1JR3BT01BA1PPP
# 932107  1519617110  IND81SS29LR1JR4BT03BA1PPP
# 953743  4965218206  IND81SS33LR2JR6BT04BA1PPP
#
#                                              Industry  \
# 884                                     Not Available
# 13870      Agriculture, Forestry, Fishing and Hunting
# 14453      Agriculture, Forestry, Fishing and Hunting
# 17735      Agriculture, Forestry, Fishing and Hunting
# 31292                                       Utilities
# ...                                               ...
# ...

# %%
ppp_hpgf.loc[ppp_hpgf["FIPS_z"].isnull()]
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 178     4377597702  IND00SS00LR1JR2BT01BA1PPP                   Not Available
# 230     1265847805  IND00SS00LR1JR2BT01BA1PPP                   Not Available
# 251     3325407706  IND00SS00LR1JR2BT01BA1PPP                   Not Available
# 884     9053367710  IND00SS00LR1JR3BT01BA1PPP                   Not Available
# 1526    4311597710  IND00SS00LR1JR3BT02BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 963654  4111228303  IND92SS31LR3JR7BT08BA1PPS           Public Administration
# 964803  1167077806  IND99SS00LR1JR3BT01BA1PPP  Nonclassifiable Establishments
# 965413  5561607708  IND99SS00LR1JR3BT02BA2PPP  Nonclassifiable Establishments
# 966377  3426817710  IND99SS00LR1JR4BT03BA1PPP  Nonclassifiable Establishments
# 967794  3848087705  IND99SS00LR2JR4BT02BA1PPP  Nonclassifiable Establishments
#
# ...

# %% [markdown]
# Output for Labeled, Hashed, Geocoded, FIPS file

# %%
ppp_hpgf.to_csv("../data/pipe_hpgf.csv")

# %%
lat_null = ppp_hpgf.loc[ppp_hpgf["Lat"].isnull()] #587569
long_null = ppp_hpgf.loc[ppp_hpgf["Long"].isnull()] #587569
print(lat_null.shape[0])
print(long_null.shape[0])
fips_null = ppp_hpgf.loc[ppp_hpgf["FIPS_z"].isnull()] #628616
print(fips_null.shape[0])
# Out:
# 129
# 130
# 1050

# %% [markdown]
# Parsing by State Output for Labeled, Hashed, Geocoded, FIPS file

# %%
#compute file for each state
ak_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AK", :]
al_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AL", :]
ar_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AR", :]
as_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AS", :] #American Samoa
az_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AZ", :]

ca_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CA", :]
co_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CO", :]
ct_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CT", :]
dc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DC", :] #D.C.
de_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DE", :]

fl_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "FL", :]
ga_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GA", :]
gu_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GU", :] #Guam
hi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "HI", :]
ia_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IA", :]

id_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ID", :]
il_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IL", :]
in_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IN", :]
ks_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KS", :]
ky_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KY", :]
la_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "LA", :]
ma_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MA", :]
md_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MD", :]
me_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ME", :]
mi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MI", :]
mn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MN", :]
mo_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MO", :]
mp_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MP", :] #Saipan Member of Parliament
ms_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MS", :]
mt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MT", :]
nc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NC", :]
nd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ND", :]
ne_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NE", :]
nh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NH", :]
nj_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NJ", :]
nm_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NM", :]
nv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NV", :]
ny_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NY", :]
oh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OH", :]
ok_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OK", :]
or_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OR", :]
pa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PA", :]
pr_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PR", :] #Puerto Rico
ri_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "RI", :]
sc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SC", :]
sd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SD", :]
tn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TN", :]
tx_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TX", :]
ut_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "UT", :]
va_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VA", :]
vi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VI", :] #Virgin Islands
vt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VT", :]
wa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WA", :]
wi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WI", :]
wv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WV", :]
wy_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WY", :]

# %% [markdown]
# FIPS states

# %% [markdown]
# All States

# %%
#PointPair each state file separately in aggregation notebook
ak_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ak.csv") 
al_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_al.csv")
ar_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ar.csv") 
as_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_as.csv")
az_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_az.csv")  
ca_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ca.csv")  
co_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_co.csv") 
ct_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ct.csv")  
dc_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_dc.csv")
de_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_de.csv") 
fl_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_fl.csv") 
ga_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ga.csv") 
gu_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_gu.csv")
hi_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_hi.csv") 
ia_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ia.csv")  
id_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_id.csv")  
il_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_il.csv")  
in_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_in.csv") 
ks_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ks.csv")  
ky_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ky.csv")  
la_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_la.csv")
ma_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ma.csv") 
md_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_md.csv")
me_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_me.csv")  
mi_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_mi.csv") 
mn_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_mn.csv") 
mo_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_mo.csv")  
mp_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_mp.csv") 
ms_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ms.csv")
mt_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_mt.csv")
nc_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_nc.csv") 
nd_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_nd.csv")  
ne_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ne.csv")
nh_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_nh.csv")  
nj_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_nj.csv")
nm_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_nm.csv") 
nv_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_nv.csv")  
ny_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ny.csv")  
oh_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_oh.csv")
ok_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ok.csv") 
or_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_or.csv")  
pa_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_pa.csv")
pr_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_pr.csv")  
ri_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ri.csv") 
sc_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_sc.csv") 
sd_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_sd.csv") 
tn_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_tn.csv")  
tx_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_tx.csv")  
ut_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_ut.csv")  
va_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_va.csv")  
vi_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_vi.csv")  
vt_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_vt.csv")
wa_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_wa.csv")  
wi_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_wi.csv")  
wv_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_wv.csv") 
wy_hpgf.to_csv("../data/state_data/hash_states/21/hpgf_wy.csv")
