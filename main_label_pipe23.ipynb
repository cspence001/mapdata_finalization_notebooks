# %%
import pandas as pd
import numpy as np
from datetime import datetime
from tqdm.notebook import tqdm

# %% [markdown]
# 2023 RAW INPUT

# %%
csv_path = "../data/raw/>150K/public_150k_plus_230630.csv"
ppp_df_23 = pd.read_csv(csv_path)
ppp_df_23.head()

# %%
ppp_df_23.shape[0]
# Out:
# 965552

# %%
ppp_df_23.columns
# Out:
# Index(['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState',
#        'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
#        'DEBT_INTEREST_PROCEED', 'BusinessType', 'OriginatingLenderLocationID',
# ...

# %% [markdown]
# <h4>Null Check

# %% [markdown]
# <b>Null DataFrame

# %%
pd.set_option('display.max_rows', 70)
print(ppp_df_23.isnull().sum())
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        4
# BorrowerAddress                    14
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                  16825
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  46
# FranchiseName                  930147
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# ...

# %%
pd.set_option('display.max_rows', 70)
ppp_df_23.dtypes
# Out:
# LoanNumber                       int64
# DateApproved                    object
# SBAOfficeCode                    int64
# ProcessingMethod                object
# BorrowerName                    object
# BorrowerAddress                 object
# BorrowerCity                    object
# BorrowerState                   object
# BorrowerZip                     object
# LoanStatusDate                  object
# LoanStatus                      object
# Term                             int64
# SBAGuarantyPercentage            int64
# InitialApprovalAmount          float64
# CurrentApprovalAmount          float64
# UndisbursedAmount              float64
# FranchiseName                   object
# ServicingLenderLocationID        int64
# ServicingLenderName             object
# ServicingLenderAddress          object
# ServicingLenderCity             object
# ServicingLenderState            object
# ServicingLenderZip              object
# RuralUrbanIndicator             object
# ...

# %%
pd.reset_option('all', silent=True)

# %% [markdown]
# <b>Null DataFrame

# %%
pd.set_option('display.max_columns', None)
null_columns=ppp_df_23.columns[ppp_df_23.isnull().any()]
df_col_null = ppp_df_23[null_columns]
df_col_null
# Out:
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# 2                                 BOYER CHILDREN'S CLINIC
# 3                                KIRTLEY CONSTRUCTION INC
# 4                                            AERO BOX LLC
# ...                                                   ...
# 965547                           ROY E PAULSON, JR., P.C.
# 965548  SWEETWATER COUNTY CHILD DEVELOPMENTAL CENTER, ...
# 965549                  ELECTRICAL SYSTEMS OF WYOMING INC
# 965550                                     EDEN LIFE CARE
# 965551                      S & S JOHNSON ENTERPRISES INC
#
#                       BorrowerAddress      BorrowerCity BorrowerState  \
# 0               2410 Highway 15 South            Sumter           NaN
# 1                 7684 Southrail Road  North Charleston           NaN
# ...

# %%
pd.reset_option('all', silent=True)

# %% [markdown]
# <b>Null Address Update: Null State

# %%
null_state = ppp_df_23.loc[ppp_df_23["BorrowerState"].isnull()] #verify same mssing addresses in main
null_state
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0   9547507704   05/01/2020            464              PPP
# 1   9777677704   05/01/2020            464              PPP
# 2   5791407702   05/01/2020           1013              PPP
# 3   6223567700   05/01/2020            920              PPP
# 4   9662437702   05/01/2020            101              PPP
# 5   9774337701   05/01/2020            101              PPP
# 6   9794577700   05/01/2020            491              PPP
# 7   9722187702   05/01/2020            101              PPP
# 8   9725917702   05/01/2020            101              PPP
# 9   9666867710   05/01/2020            101              PPP
# 10  9662697710   05/01/2020            101              PPP
# 11  9724667708   05/01/2020            101              PPP
# 12  9672967701   05/01/2020            101              PPP
#
#                                         BorrowerName        BorrowerAddress  \
# ...

# %%
ppp_df_23.loc[ppp_df_23["LoanNumber"] == 9547507704, 'BorrowerState'] = "SC"
ppp_df_23.loc[ppp_df_23["LoanNumber"] == 9777677704, 'BorrowerState'] = "SC"
ppp_df_23.loc[ppp_df_23["LoanNumber"] == 5791407702, 'BorrowerState'] = "WA"
ppp_df_23.loc[ppp_df_23["LoanNumber"] == 6223567700, 'BorrowerState'] = "CA"
ppp_df_23.loc[ppp_df_23["LoanNumber"] == 9794577700, 'BorrowerState'] = "FL"
'''9547507704, 9777677704, 5791407702, 6223567700, 9794577700 replaced'''
# Out:
# '9547507704, 9777677704, 5791407702, 6223567700, 9794577700 replaced'

# %%
null_state_check = ppp_df_23.loc[ppp_df_23["BorrowerState"].isnull()] 
null_state_check
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 4   9662437702   05/01/2020            101              PPP
# 5   9774337701   05/01/2020            101              PPP
# 7   9722187702   05/01/2020            101              PPP
# 8   9725917702   05/01/2020            101              PPP
# 9   9666867710   05/01/2020            101              PPP
# 10  9662697710   05/01/2020            101              PPP
# 11  9724667708   05/01/2020            101              PPP
# 12  9672967701   05/01/2020            101              PPP
#
#                               BorrowerName BorrowerAddress BorrowerCity  \
# 4                             AERO BOX LLC             NaN          NaN
# 5                   HUDSON EXTRUSIONS INC.             NaN          NaN
# 7   MIAMITOWN AUTO PARTS AND RECYCLING INC             NaN          NaN
# 8                           POPPYCOCKS INC             NaN          NaN
# ...

# %% [markdown]
# <b>Null Address Update: Null Borrower Address

# %%
add_null = ppp_df_23.loc[ppp_df_23["BorrowerAddress"].isnull()]
add_null
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 4       9662437702   05/01/2020            101              PPP
# 5       9774337701   05/01/2020            101              PPP
# 7       9722187702   05/01/2020            101              PPP
# 8       9725917702   05/01/2020            101              PPP
# 9       9666867710   05/01/2020            101              PPP
# 10      9662697710   05/01/2020            101              PPP
# 11      9724667708   05/01/2020            101              PPP
# 12      9672967701   05/01/2020            101              PPP
# 157207  2030257707   05/01/2020            912              PPP
# 175156  8181657703   05/01/2020            811              PPP
# 663182  1681327703   05/01/2020            248              PPP
# 789096  9793947702   05/01/2020            464              PPP
# 845402  3192617705   05/01/2020            610              PPP
# 882649  2491137709   05/01/2020            610              PPP
#
# ...

# %%
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==2030257707, 'BorrowerAddress'] ="1105 East Plaza Blvd. Suite A"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==2030257707, 'BorrowerCity'] ="National City"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==8181657703, 'BorrowerAddress'] ="601 Main St"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==1681327703, 'BorrowerAddress'] ="2041 Park St"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==1681327703, 'BorrowerCity'] ="ATLANTIC BEACH"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==9793947702, 'BorrowerAddress'] ="17 Lockwood Drive, Suite 400"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==3192617705, 'BorrowerAddress'] ="2541 SOUTH IH-35 SUITE 200-263"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==3192617705, 'BorrowerCity'] ="Round Rock"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==2491137709, 'BorrowerAddress'] ="261 FLOWER RIDGE DR"
ppp_df_23.loc[ppp_df_23["LoanNumber"] ==2491137709, 'BorrowerCity'] ="FORT WORTH"

# %%
null_add_check = ppp_df_23.loc[ppp_df_23["BorrowerAddress"].isnull()] 
null_add_check
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 4   9662437702   05/01/2020            101              PPP
# 5   9774337701   05/01/2020            101              PPP
# 7   9722187702   05/01/2020            101              PPP
# 8   9725917702   05/01/2020            101              PPP
# 9   9666867710   05/01/2020            101              PPP
# 10  9662697710   05/01/2020            101              PPP
# 11  9724667708   05/01/2020            101              PPP
# 12  9672967701   05/01/2020            101              PPP
#
#                               BorrowerName BorrowerAddress BorrowerCity  \
# 4                             AERO BOX LLC             NaN          NaN
# 5                   HUDSON EXTRUSIONS INC.             NaN          NaN
# 7   MIAMITOWN AUTO PARTS AND RECYCLING INC             NaN          NaN
# 8                           POPPYCOCKS INC             NaN          NaN
# ...

# %% [markdown]
# "Not Available" for missing Address+City+State <br>
# Manually updated in FIPS processing baesd on Borrower Name

# %%
ppp_df_23.loc[ppp_df_23["BorrowerState"].isnull(), 'BorrowerState'] = "Not Available"
ppp_df_23.loc[ppp_df_23["BorrowerAddress"].isnull(), 'BorrowerAddress'] = "Not Available"
ppp_df_23.loc[ppp_df_23["BorrowerCity"].isnull(), 'BorrowerCity'] = "Not Available"

# %% [markdown]
# Combining Columns for New Full Address column

# %%
ppp_df_23['FullAdd'] = ppp_df_23.BorrowerAddress + ", " + ppp_df_23.BorrowerCity + ", " + ppp_df_23.BorrowerState
ppp_df_23['ServicingLenderFullAddress'] = ppp_df_23.ServicingLenderAddress + ", " + ppp_df_23.ServicingLenderCity + ", " + ppp_df_23.ServicingLenderState
ppp_df_23.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC          Not Available     Not Available
#
#    BorrowerState BorrowerZip LoanStatusDate  ...  \
# 0             SC  29150-9662     12/18/2020  ...
# 1             SC  29420-9000     09/28/2021  ...
# ...

# %% [markdown]
# <b>File Write for Updated Address

# %%
ppp_df_23.to_csv("../data/raw/>150K/public_150k_plus_230630_add.csv")

# %% [markdown]
# <h2>II

# %% [markdown]
# <b>File Read of Update RAW

# %%
csv_path_update = "../data/raw/>150K/public_150k_plus_230630_add.csv"
ppp_df_23 = pd.read_csv(csv_path_update, index_col=0)

# %% [markdown]
# Null Updates (cont.)

# %%
ppp_df_23['ForgivenessAmount']=ppp_df_23['ForgivenessAmount'].fillna(0.0)
ppp_df_23['UndisbursedAmount']=ppp_df_23['UndisbursedAmount'].fillna(0.0)
null_UndisbursedAmount = ppp_df_23.loc[ppp_df_23["UndisbursedAmount"].isnull()] 
null_UndisbursedAmount.head()
# Out:
# Empty DataFrame
# Columns: [LoanNumber, DateApproved, SBAOfficeCode, ProcessingMethod, BorrowerName, BorrowerAddress, BorrowerCity, BorrowerState, BorrowerZip, LoanStatusDate, LoanStatus, Term, SBAGuarantyPercentage, InitialApprovalAmount, CurrentApprovalAmount, UndisbursedAmount, FranchiseName, ServicingLenderLocationID, ServicingLenderName, ServicingLenderAddress, ServicingLenderCity, ServicingLenderState, ServicingLenderZip, RuralUrbanIndicator, HubzoneIndicator, LMIIndicator, BusinessAgeDescription, ProjectCity, ProjectCountyName, ProjectState, ProjectZip, CD, JobsReported, NAICSCode, Race, Ethnicity, UTILITIES_PROCEED, PAYROLL_PROCEED, MORTGAGE_INTEREST_PROCEED, RENT_PROCEED, REFINANCE_EIDL_PROCEED, HEALTH_CARE_PROCEED, DEBT_INTEREST_PROCEED, BusinessType, OriginatingLenderLocationID, OriginatingLender, OriginatingLenderCity, OriginatingLenderState, Gender, Veteran, NonProfit, ForgivenessAmount, ForgivenessDate, FullAdd, ServicingLenderFullAddress]
# Index: []
#
# ...

# %% [markdown]
# <h4>Date to Timestamp Conversion<br></h4>
# mm/dd/yyyy > yyyymmdd

# %% [markdown]
# <b>DateApproved

# %%
dates = []
for date in ppp_df_23['DateApproved']:
    dt = pd.to_datetime(date, format='%m/%d/%Y') #year #### format
    dates.append(dt)

ppp_df_23['DateApprovedTS'] = dates
ppp_df_23['DateApprovedTS']= ppp_df_23['DateApprovedTS'].astype(str)
ppp_df_23['DateApprovedTS']= ppp_df_23['DateApprovedTS'].str.replace('-', '', regex=True)
ppp_df_23.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC          Not Available     Not Available
#
#    BorrowerState BorrowerZip LoanStatusDate  ... OriginatingLenderCity  \
# 0             SC  29150-9662     12/18/2020  ...              COLUMBUS
# ...

# %% [markdown]
# <b>ForgivenessDate

# %%
fdates = []
for fdate in ppp_df_23['ForgivenessDate']:
    fdt = pd.to_datetime(fdate, format='%m/%d/%Y') #year #### format
    fdates.append(fdt)

ppp_df_23['ForgivenessDateTS'] = fdates
ppp_df_23['ForgivenessDateTS']= ppp_df_23['ForgivenessDateTS'].astype(str)
ppp_df_23['ForgivenessDateTS']= ppp_df_23['ForgivenessDateTS'].str.replace('-', '', regex=True)
ppp_df_23.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC          Not Available     Not Available
#
#    BorrowerState BorrowerZip LoanStatusDate  ... OriginatingLenderState  \
# 0             SC  29150-9662     12/18/2020  ...                     GA
# ...

# %% [markdown]
# <b>LoanStatusDate

# %%
ldates = []
for ldate in ppp_df_23['LoanStatusDate']:
    ldt = pd.to_datetime(ldate, format='%m/%d/%Y') #year #### format
    ldates.append(ldt)

ppp_df_23['LoanStatusDateTS'] = ldates
ppp_df_23['LoanStatusDateTS']= ppp_df_23['LoanStatusDateTS'].astype(str)
ppp_df_23['LoanStatusDateTS']= ppp_df_23['LoanStatusDateTS'].str.replace('-', '', regex=True)
ppp_df_23.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC          Not Available     Not Available
#
#    BorrowerState BorrowerZip LoanStatusDate  ...      Gender      Veteran  \
# 0             SC  29150-9662     12/18/2020  ...  Unanswered   Unanswered
# ...

# %% [markdown]
# Dropping Original Date Columns

# %%
ppp_df_23 = ppp_df_23.drop(['DateApproved', 'ForgivenessDate','LoanStatusDate'], axis=1)

# %% [markdown]
# NaT > NaN > "Not Available" [LoanStatusDateTS, ForgivenessDateTS]

# %%
ppp_df_23 = ppp_df_23.replace('NaT', np.nan)
ppp_df_23['LoanStatusDateTS']=ppp_df_23['LoanStatusDateTS'].fillna("Not Available")
ppp_df_23['ForgivenessDateTS']=ppp_df_23['ForgivenessDateTS'].fillna("Not Available")

# %% [markdown]
# <b> Update File due to procesing times of datetime columns

# %%
ppp_df_23.to_csv("../data/raw/>150K/public_150k_plus_230630_addts.csv")

# %% [markdown]
# <h2>III

# %% [markdown]
# <b>File Read of Updated RAW + address + ts

# %%
csv_path_update = "../data/raw/>150K/public_150k_plus_230630_addts.csv"
ppp_df_23 = pd.read_csv(csv_path_update, index_col=0)

# %% [markdown]
# <h4>NAICS Integration

# %% [markdown]
# <b>NAICSCode

# %%
naics_ind = pd.read_csv("../data/raw/NAICS/NAICSind.csv") #NAICSCode, Industry
naics_full = pd.read_csv("../data/raw/NAICS/NAICSfull.csv") #NAICSCode, SubIndustry Values

# %%
naics_ind["NA"] = naics_ind["NA"].astype(str)
print(naics_ind.shape[0])
naics_ind.head()
# Out:
# 25
#    NA                                       Industry
# 0  11     Agriculture, Forestry, Fishing and Hunting
# 1  21  Mining, Quarrying, and Oil and Gas Extraction
# 2  22                                      Utilities
# 3  23                                   Construction
# 4  31                                  Manufacturing

# %%
naics_full["NA"] = naics_full["NAICSCode"].astype(str).str[:2]
print(naics_full.shape[0])
naics_full.head()
# Out:
# 1057
#    NAICSCode                           LongName TRIIndustrySector  \
# 0     111110                    Soybean Farming         999 Other
# 1     111120  Oilseed (except Soybean) Farming          999 Other
# 2     111130          Dry Pea and Bean Farming          999 Other
# 3     111140                      Wheat Farming         999 Other
# 4     111150                      Corn Farming          999 Other
#
#                 IndustrySubsector  4DigitNAICS  NA
# 0  1111 Oilseed and Grain Farming         1111  11
# 1  1111 Oilseed and Grain Farming         1111  11
# 2  1111 Oilseed and Grain Farming         1111  11
# 3  1111 Oilseed and Grain Farming         1111  11
# 4  1111 Oilseed and Grain Farming         1111  11

# %% [markdown]
# Merging NAICS Dataframes on NA

# %%
naics_comb = naics_full.merge(naics_ind, on ="NA", how="left")
print(naics_comb.shape[0])
naics_comb.head()
# Out:
# 1057
#    NAICSCode                           LongName TRIIndustrySector  \
# 0     111110                    Soybean Farming         999 Other
# 1     111120  Oilseed (except Soybean) Farming          999 Other
# 2     111130          Dry Pea and Bean Farming          999 Other
# 3     111140                      Wheat Farming         999 Other
# 4     111150                      Corn Farming          999 Other
#
#                 IndustrySubsector  4DigitNAICS  NA  \
# 0  1111 Oilseed and Grain Farming         1111  11
# 1  1111 Oilseed and Grain Farming         1111  11
# 2  1111 Oilseed and Grain Farming         1111  11
# 3  1111 Oilseed and Grain Farming         1111  11
# 4  1111 Oilseed and Grain Farming         1111  11
#
#                                      Industry
# 0  Agriculture, Forestry, Fishing and Hunting
# 1  Agriculture, Forestry, Fishing and Hunting
# 2  Agriculture, Forestry, Fishing and Hunting
# 3  Agriculture, Forestry, Fishing and Hunting
# ...

# %% [markdown]
# Parsing for Necessary Columns

# %%
cols = ["NAICSCode","Industry","IndustrySubsector","LongName"]
naics_final = naics_comb[cols]
print(naics_final.shape[0])
naics_final.head()
# Out:
# 1057
#    NAICSCode                                    Industry  \
# 0     111110  Agriculture, Forestry, Fishing and Hunting
# 1     111120  Agriculture, Forestry, Fishing and Hunting
# 2     111130  Agriculture, Forestry, Fishing and Hunting
# 3     111140  Agriculture, Forestry, Fishing and Hunting
# 4     111150  Agriculture, Forestry, Fishing and Hunting
#
#                 IndustrySubsector                           LongName
# 0  1111 Oilseed and Grain Farming                    Soybean Farming
# 1  1111 Oilseed and Grain Farming  Oilseed (except Soybean) Farming
# 2  1111 Oilseed and Grain Farming          Dry Pea and Bean Farming
# 3  1111 Oilseed and Grain Farming                      Wheat Farming
# 4  1111 Oilseed and Grain Farming                      Corn Farming

# %% [markdown]
# NAICS Null Check, Dtypes

# %%
print(naics_final.isnull().sum())
# Out:
# NAICSCode            0
# Industry             0
# IndustrySubsector    0
# LongName             0
# dtype: int64

# %%
naics_final.dtypes
# Out:
# NAICSCode             int64
# Industry             object
# IndustrySubsector    object
# LongName             object
# dtype: object

# %% [markdown]
# Convert NAICSCode column from float match NAICS Int64

# %%
ppp_df_23["NAICSCode"] = ppp_df_23["NAICSCode"].fillna(0) # 6628
ppp_df_23["NAICSCode"] = ppp_df_23["NAICSCode"].astype("Int64")
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  OriginatingLenderState      Gender      Veteran  \
# ...

# %% [markdown]
# Merge NAICS to Main

# %%
ppp_df_23_merge = ppp_df_23.merge(naics_final, on="NAICSCode", how="left")
ppp_df_23_merge.head() #6632
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  NonProfit  ForgivenessAmount  \
# ...

# %% [markdown]
# Review Nulls on Merge

# %%
ppp_df_23_merge.loc[ppp_df_23_merge["Industry"].isnull()] #12162
# Out:
#         LoanNumber  SBAOfficeCode ProcessingMethod  \
# 2       5791407702           1013              PPP
# 36      4820397010           1084              PPP
# 260     6287537004           1084              PPP
# 305     1892977209           1084              PPP
# 429     5784067001           1084              PPP
# ...            ...            ...              ...
# 964869  4935817005            897              PPP
# 964906  3960157702            897              PPP
# 964978  7342767709            897              PPP
# 965262  3885147709            897              PPP
# 965480  5145237302            897              PPP
#
#                                              BorrowerName  \
# 2                                 BOYER CHILDREN'S CLINIC
# 36                                         COLVILLE, INC.
# 260     SEWARD ASSOCIATION FOR THE ADVANCEMENT OF MARI...
# 305                                   DENALI VISIONS 3000
# ...

# %% [markdown]
# <b>NAICS Formatting

# %%
ppp_df_23 = ppp_df_23_merge

# %%
ppp_df_23.loc[ppp_df_23["NAICSCode"] == 999990, 'Industry'] = 'Nonclassifiable Establishments'
ppp_df_23.loc[ppp_df_23["NAICSCode"] == 999990, 'IndustrySubsector'] = 'Nonclassifiable Establishments'
ppp_df_23.loc[ppp_df_23["NAICSCode"] == 999990, 'LongName'] = 'Nonclassifiable Establishments'

# %%
ppp_df_23.loc[ppp_df_23["NAICSCode"] == 999990].head()
# Out:
#       LoanNumber  SBAOfficeCode ProcessingMethod  \
# 1503  1126217303           1084              PPP
# 2001  5414867008           1084              PPP
# 2218  4678427701           1084              PPP
# 3526  7212977105            459              PPP
# 4702  5062267000            459              PPP
#
#                          BorrowerName         BorrowerAddress BorrowerCity  \
# 1503              NYSTUENS FOLLY, LLC          1811 Abbott Rd    ANCHORAGE
# 2001                    ALASKA SB LLC        317 W 104th Ave.    ANCHORAGE
# 2218                 HALCYON DAYS LLC      41630 GLADYS COURT        HOMER
# 3526  NEAL TECHNICAL INNOVATIONS, LLC  9101 Milton Jones Road       DAPHNE
# 4702                    PAY SUITE LLC       611 Walnut Street      GADSDEN
#
#      BorrowerState BorrowerZip    LoanStatus  Term  ...  NonProfit  \
# 1503            AK       99507  Paid in Full    24  ...        NaN
# 2001            AK  99515-2611  Paid in Full    24  ...        NaN
# ...

# %%
ppp_df_23_merge.loc[ppp_df_23_merge["Industry"].isnull()]
# Out:
#         LoanNumber  SBAOfficeCode ProcessingMethod  \
# 2       5791407702           1013              PPP
# 36      4820397010           1084              PPP
# 260     6287537004           1084              PPP
# 305     1892977209           1084              PPP
# 429     5784067001           1084              PPP
# ...            ...            ...              ...
# 962807  6656547003            390              PPP
# 962820  1885427101            390              PPP
# 963043  9665527700            390              PPP
# 964906  3960157702            897              PPP
# 965262  3885147709            897              PPP
#
#                                              BorrowerName  \
# 2                                 BOYER CHILDREN'S CLINIC
# 36                                         COLVILLE, INC.
# 260     SEWARD ASSOCIATION FOR THE ADVANCEMENT OF MARI...
# 305                                   DENALI VISIONS 3000
# ...

# %%
ppp_df_23["Industry"] = ppp_df_23["Industry"].fillna("Not Available")
ppp_df_23["IndustrySubsector"] = ppp_df_23["IndustrySubsector"].fillna("Not Available")
ppp_df_23["LongName"] = ppp_df_23["LongName"].fillna("Not Available")
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  NonProfit  ForgivenessAmount  \
# ...

# %% [markdown]
# Null Check, Not Available after NAICS Null Formatting

# %%
print(ppp_df_23[ppp_df_23["Industry"] == 'Not Available'].shape[0])#12162 - 4078
print(ppp_df_23[ppp_df_23["Industry"] == 'Nonclassifiable Establishments'].shape[0])
# Out:
# 8084
# 4078

# %% [markdown]
# <h4>SBA District Office Labeling

# %%
sba_xslx = pd.read_excel("../data/raw/SBA/SBAOfficeCodeLabels.xlsx", dtype=str, index_col=None)
sba_xslx.to_csv('../data/raw/SBA/SBAOfficeCodeLabels.csv', encoding='utf-8', index=False)
sba_df = pd.read_csv("../data/raw/SBA/SBAOfficeCodeLabels.csv")
sba_df.index = sba_df.index.astype('int64')
sba_df
# Out:
#     SBAOfficeCode                    SBAOfficeLabel
# 0             100         BOSTON REGIONAL OFFICE
# 1             101  MASSACHUSETTS DISTRICT OFFICE
# 2             130      SPRINGFIELD BRANCH OFFICE
# 3             150        VERMONT DISTRICT OFFICE
# 4             156    CONNECTICUT DISTRICT OFFICE
# ..            ...                               ...
# 89           1013        SEATTLE DISTRICT OFFICE
# 90           1084         ALASKA DISTRICT OFFICE
# 91           1086       PORTLAND DISTRICT OFFICE
# 92           1087          BOISE DISTRICT OFFICE
# 93           1094          SPOKANE BRANCH OFFICE
#
# [94 rows x 2 columns]

# %%
ppp_df_23= ppp_df_23.merge(sba_df, on="SBAOfficeCode", how="left")
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  ForgivenessAmount  \
# 0  Paid in Full    24  ...          773553.37
# ...

# %% [markdown]
# SBA District Office Labeling: Verification

# %%
ppp_df_23.loc[ppp_df_23["SBAOfficeLabel"].isnull()]
# Out:
# Empty DataFrame
# ...

# %%
print(ppp_df_23['SBAOfficeLabel'].nunique())
print(ppp_df_23['SBAOfficeCode'].nunique())
# Out:
# 74
# 75

# %% [markdown]
# <h4>Conditions

# %% [markdown]
# <b>Loan Approval Amount Ranges to Determine Lender Percent/Profit </b><br>
# https://home.treasury.gov/system/files/136/PPP%20Lender%20Information%20Fact%20Sheet.pdf

# %%
loan_conditions = [
(ppp_df_23.CurrentApprovalAmount <= 350000) & (ppp_df_23.CurrentApprovalAmount >= 150000),
(ppp_df_23.CurrentApprovalAmount <= 2000000) & (ppp_df_23.CurrentApprovalAmount > 350000),
(ppp_df_23.CurrentApprovalAmount > 2000000)
]
loan_values = [.05,.03,.01]
ppp_df_23['LenderPercent'] = np.select(loan_conditions, loan_values)
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...                                      FullAdd  \
# ...

# %% [markdown]
# <b>Determining Lender Profit based on Percent of Current Approval

# %%
ppp_df_23["EstimatedLenderProfit"] = ppp_df_23['CurrentApprovalAmount'] * ppp_df_23['LenderPercent']
ppp_df_23["EstimatedLenderProfit"] = ppp_df_23["EstimatedLenderProfit"].apply(lambda x: '{:.2f}'.format(x) if type(x) is int or type(x) is float else x)
ppp_df_23['LenderPercent'] = pd.Series(["{0:.0f}%".format(val * 100) for val in ppp_df_23['LenderPercent']], index = ppp_df_23.index)
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...              ServicingLenderFullAddress  \
# ...

# %% [markdown]
# <b>Determining Approval Ranges for Each Loan

# %%
loan_conditions = [
(ppp_df_23.CurrentApprovalAmount <= 350000) & (ppp_df_23.CurrentApprovalAmount >= 150000),
(ppp_df_23.CurrentApprovalAmount <= 1000000) & (ppp_df_23.CurrentApprovalAmount > 350000),
(ppp_df_23.CurrentApprovalAmount <= 2000000) & (ppp_df_23.CurrentApprovalAmount > 1000000),
(ppp_df_23.CurrentApprovalAmount <= 5000000) & (ppp_df_23.CurrentApprovalAmount > 2000000),
(ppp_df_23.CurrentApprovalAmount <= 10000000) & (ppp_df_23.CurrentApprovalAmount > 5000000),  
]
loan_values = ["a $150,000-350,000","b $350,000-1 million", "c $1-2 million","d $2-5 million", "e $5-10 million"]
ppp_df_23['LoanRange'] = np.select(loan_conditions, loan_values)
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  DateApprovedTS  ForgivenessDateTS  \
# ...

# %% [markdown]
# <b>Determining Job Report Ranges for Each Loan

# %% [markdown]
# JobsReported Formatting

# %%
ppp_df_23.loc[ppp_df_23["JobsReported"] == "0", 'JobsReported'] = 0
ppp_df_23.loc[ppp_df_23["JobsReported"].isnull(), 'JobsReported'] = 0
ppp_df_23['JobsReported']=ppp_df_23['JobsReported'].astype(int)

# %% [markdown]
# https://data.bls.gov/cew/apps/data_views/data_views.htm#tab=Tables

# %%
job_conditions = [
(ppp_df_23.JobsReported <= 5),
(ppp_df_23.JobsReported <= 9) & (ppp_df_23.JobsReported > 5),
(ppp_df_23.JobsReported <= 19) & (ppp_df_23.JobsReported > 9),
(ppp_df_23.JobsReported <= 49) & (ppp_df_23.JobsReported > 19),
(ppp_df_23.JobsReported <= 99) & (ppp_df_23.JobsReported > 49), 
(ppp_df_23.JobsReported <= 249) & (ppp_df_23.JobsReported > 99),
(ppp_df_23.JobsReported <= 499) & (ppp_df_23.JobsReported > 249),
(ppp_df_23.JobsReported > 499)
]
job_values = ["Fewer than 5","5 to 9", "10 to 19","20 to 49", "50 to 99", "100 to 249", "250 to 499", "500 or more"]
ppp_df_23['JobRange'] = np.select(job_conditions, job_values)
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  ForgivenessDateTS  LoanStatusDateTS  \
# ...

# %%
ppp_df_23['JobRange'].value_counts()
# Out:
# JobRange
# 20 to 49        416149
# 10 to 19        241148
# 50 to 99        161163
# 100 to 249       84575
# 5 to 9           31080
# 250 to 499       21987
# Fewer than 5      5093
# 500 or more       4357
# Name: count, dtype: int64

# %%
ppp_df_23.loc[ppp_df_23["JobRange"] == "0", 'JobRange'] = "Fewer than 5"
ppp_df_23['JobRange'].value_counts()
# Out:
# JobRange
# 20 to 49        416149
# 10 to 19        241148
# 50 to 99        161163
# 100 to 249       84575
# 5 to 9           31080
# 250 to 499       21987
# Fewer than 5      5093
# 500 or more       4357
# Name: count, dtype: int64

# %%
ppp_df_23['JobRange'].isnull().sum() #check
# Out:
# 0

# %% [markdown]
# <h4>Naming Consistency

# %% [markdown]
# <b>Naming Consistency: Business Age, Type

# %% [markdown]
# Counts

# %%
listbusiness =ppp_df_23["BusinessType"].value_counts()
listbusiness
# Out:
# BusinessType
# Corporation                            415684
# Limited  Liability Company(LLC)        261058
# Subchapter S Corporation               174799
# Non-Profit Organization                 55904
# Partnership                             18158
# Limited Liability Partnership           12724
# Sole Proprietorship                     12255
# Professional Association                 6270
# Cooperative                              2435
# 501(c)3 – Non Profit                     1772
# Non-Profit Childcare Center               900
# 501(c)6 – Non Profit Membership           762
# Employee Stock Ownership Plan(ESOP)       641
# Self-Employed Individuals                 494
# Trust                                     397
# Housing Co-op                             152
# Joint Venture                             125
# Independent Contractors                   112
# Single Member LLC                          78
# Tribal Concerns                            64
# ...

# %%
listbusinessage =ppp_df_23['BusinessAgeDescription'].value_counts()
listbusinessage
# Out:
# BusinessAgeDescription
# Existing or more than 2 years old         859324
# New Business or 2 years or less            54479
# Unanswered                                 51051
# Change of Ownership                          422
# Startup, Loan Funds will Open Business       275
# Name: count, dtype: int64

# %% [markdown]
# Updates

# %%
ppp_df_23["BusinessType"] = ppp_df_23["BusinessType"].replace({'Limited  Liability Company(LLC)': 'Limited Liability Company(LLC)'}) #extra space in text

ppp_df_23.loc[ppp_df_23['BusinessAgeDescription'] == 'Unanswered', 'BusinessAgeDescription'] = 'Not Available'

ppp_df_23['BusinessAgeDescription'] = ppp_df_23['BusinessAgeDescription'].fillna('Not Available')
ppp_df_23["BusinessType"] = ppp_df_23["BusinessType"].fillna('Not Available')
ppp_df_23["FranchiseName"] = ppp_df_23["FranchiseName"].fillna('Not Available')
ppp_df_23.head()
# Out:
#    LoanNumber  SBAOfficeCode ProcessingMethod              BorrowerName  \
# 0  9547507704            464              PPP     SUMTER COATINGS, INC.
# 1  9777677704            464              PPP     PLEASANT PLACES, INC.
# 2  5791407702           1013              PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700            920              PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702            101              PPP              AERO BOX LLC
#
#          BorrowerAddress      BorrowerCity  BorrowerState BorrowerZip  \
# 0  2410 Highway 15 South            Sumter             SC  29150-9662
# 1    7684 Southrail Road  North Charleston             SC  29420-9000
# 2       1850 BOYER AVE E           SEATTLE             WA  98112-2922
# 3   1661 MARTIN RANCH RD    SAN BERNARDINO             CA  92407-1740
# 4          Not Available     Not Available  Not Available         NaN
#
#      LoanStatus  Term  ...  ForgivenessDateTS  LoanStatusDateTS  \
# ...

# %% [markdown]
# Verification

# %%
listbusiness =ppp_df_23["BusinessType"].value_counts()
listbusiness
# Out:
# BusinessType
# Corporation                            415684
# Limited Liability Company(LLC)         261058
# Subchapter S Corporation               174799
# Non-Profit Organization                 55904
# Partnership                             18158
# Limited Liability Partnership           12724
# Sole Proprietorship                     12255
# Professional Association                 6270
# Cooperative                              2435
# 501(c)3 – Non Profit                     1772
# Non-Profit Childcare Center               900
# 501(c)6 – Non Profit Membership           762
# Not Available                             720
# Employee Stock Ownership Plan(ESOP)       641
# Self-Employed Individuals                 494
# Trust                                     397
# Housing Co-op                             152
# Joint Venture                             125
# Independent Contractors                   112
# Single Member LLC                          78
# ...

# %%
listbusinessage =ppp_df_23['BusinessAgeDescription'].value_counts()
listbusinessage
# Out:
# BusinessAgeDescription
# Existing or more than 2 years old         859324
# New Business or 2 years or less            54479
# Not Available                              51052
# Change of Ownership                          422
# Startup, Loan Funds will Open Business       275
# Name: count, dtype: int64

# %% [markdown]
# <b>Naming Consistency: NonProfit

# %%
listnonprofit = ppp_df_23["NonProfit"].value_counts()
listnonprofit
# Out:
# NonProfit
# Y    59350
# Name: count, dtype: int64

# %% [markdown]
# Updates

# %%
ppp_df_23["NonProfit"] = ppp_df_23["NonProfit"].fillna('N')

# %% [markdown]
# Verification

# %% [markdown]
# Verify that all NonProfits = Y have listed NonProfit as BusinessType<br>

# %%
nonprofit_yes = ppp_df_23.loc[ppp_df_23["NonProfit"] == "Y"]
nonprofit_yes["BusinessType"].value_counts()
# Out:
# BusinessType
# Non-Profit Organization              55904
# 501(c)3 – Non Profit                  1772
# Non-Profit Childcare Center            900
# 501(c)6 – Non Profit Membership        762
# 501(c) – Non Profit except 3,4,6,       10
# 501(c)19 – Non Profit Veterans           2
# Name: count, dtype: int64

# %% [markdown]
# Verify that all NonProfits = N do not have NonProfit as BusinessType<br>

# %%
nonprofit_no= ppp_df_23.loc[ppp_df_23["NonProfit"] == "N"]
nonprofit_no["BusinessType"].value_counts()
# Out:
# BusinessType
# Corporation                            415684
# Limited Liability Company(LLC)         261058
# Subchapter S Corporation               174799
# Partnership                             18158
# Limited Liability Partnership           12724
# Sole Proprietorship                     12255
# Professional Association                 6270
# Cooperative                              2435
# Not Available                             720
# Employee Stock Ownership Plan(ESOP)       641
# Self-Employed Individuals                 494
# Trust                                     397
# Housing Co-op                             152
# Joint Venture                             125
# Independent Contractors                   112
# Single Member LLC                          78
# Tribal Concerns                            64
# Tenant in Common                           30
# Rollover as Business Start-Ups (ROB         4
# Qualified Joint-Venture (spouses)           2
# ...

# %% [markdown]
# <b>Naming Consistency: Borrower Name

# %% [markdown]
# Check: &AMP;

# %%
cleanamp_check = ppp_df_23[ppp_df_23['BorrowerName'].astype(str).str.contains("&AMP;")]
cleanamp_check.head()
# Out:
#       LoanNumber  SBAOfficeCode ProcessingMethod  \
# 56    6570687706           1084              PPP
# 1876  6707308401           1084              PPS
# 2361  2556438507           1084              PPS
# 2425  3840357709           1084              PPP
# 4861  9610747710            459              PPP
#
#                                            BorrowerName  \
# 56    AHTNA CONSTRUCTION &AMP; PRIMARY PRODUCTS COMP...
# 1876              ALLURE DAY SPA &AMP; HAIR DESIGN LLC.
# 2361  360 CONSTRUCTION &AMP; DESIGN LLC  FKA TRAILBO...
# 2425                         FRAMPTON &AMP; OPINSKY LLC
# 4861                          R &AMP; D ELECTRONICS INC
#
#                     BorrowerAddress BorrowerCity BorrowerState BorrowerZip  \
# 56           110 W 38th Ave Ste 100    Anchorage            AK       99503
# 1876                  142 W 5th Ave    Anchorage            AK  99501-2522
# 2361              3330 C St Ste 100    Anchorage            AK  99503-3957
# ...

# %% [markdown]
# Update & Verify I: &

# %%
ppp_df_23['BorrowerName']=ppp_df_23['BorrowerName'].astype(str).str.replace('&AMP;', '&', regex=True)
cleanamp_verify = ppp_df_23[ppp_df_23['BorrowerName'].astype(str).str.contains("&AMP;")]
cleanamp_verify
# Out:
#         LoanNumber  SBAOfficeCode ProcessingMethod  \
# 806347  9712177706            474              PPP
#
#                                   BorrowerName           BorrowerAddress  \
# 806347  COMPLETE WELDING &AMP; FABRICATION INC  112 E INDUSTRIAL PARK DR
#
#        BorrowerCity BorrowerState BorrowerZip    LoanStatus  Term  ...  \
# 806347    JACKSBORO            TN       37757  Paid in Full    24  ...
#
#         ForgivenessDateTS  LoanStatusDateTS  \
# 806347           20201103          20201216
#
#                                              Industry  \
# 806347  Other Services (except Public Administration)
#
#                                         IndustrySubsector  \
# 806347  8113 Commercial and Industrial Machinery and E...
#
#                                                  LongName  \
# 806347  Commercial and Industrial Machinery and Equipm...
#
#                       SBAOfficeLabel LenderPercent EstimatedLenderProfit  \
# ...

# %% [markdown]
# Update & Verify II: &

# %%
ppp_df_23.loc[ppp_df_23["LoanNumber"] == 9712177706, 'BorrowerName'] = "COMPLETE WELDING & FABRICATION INC"
cleanamp_verify = ppp_df_23[ppp_df_23['BorrowerName'].astype(str).str.contains("&AMP;")]
cleanamp_verify
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Check: SBA SMALL 7A TERM

# %%
cleansba_check = ppp_df_23[ppp_df_23['BorrowerName'].astype(str).str.contains("SBA SMALL 7A TERM")]
cleansba_check.head()
# Out:
#         LoanNumber  SBAOfficeCode ProcessingMethod  \
# 30443   3513127702            988              PPP
# 186221  3321607710            156              PPP
# 186938  4202817705            156              PPP
# 186985  4249147702            156              PPP
# 187477  4190277700            156              PPP
#
#                                              BorrowerName  \
# 30443   SOUTHWEST PRIVATE INVESTMENTS LLC-SBA SMALL 7A...
# 186221                BRISTOL HOTEL LLC-SBA SMALL 7A TERM
# 186938   ATLANTIC MASONRY PRODUCTS CORP-SBA SMALL 7A TERM
# 186985  MACKENZIE RESTORATION COMPANY LLC-SBA SMALL 7A...
# 187477  CENTRAL CONNECTICUT ACOUSTICS INC-SBA SMALL 7A...
#
#                 BorrowerAddress   BorrowerCity BorrowerState BorrowerZip  \
# 30443        2728 N 24TH STREET        PHOENIX            AZ       85008
# 186221         42 Century Drive        Bristol            CT       06010
# 186938       67 Quinnipiac Ave.  North Haven ,            CT       06473
# ...

# %% [markdown]
# Update & Verify: SBA SMALL 7A TERM

# %%
ppp_df_23['BorrowerName']=ppp_df_23['BorrowerName'].astype(str).str.replace('SBA SMALL 7A TERM', '', regex=True)
cleansba_verify = ppp_df_23[ppp_df_23['BorrowerName'].astype(str).str.contains("SBA SMALL 7A TERM")]
cleansba_verify
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# <b>Remove Leading / Trailing Whitespaces from string columns

# %%
beforetrails = ppp_df_23.loc[ppp_df_23["Industry"] == "Utilities"]
beforetrails["IndustrySubsector"].sort_values().unique().tolist()
# Out:
# ['2211 Electric Power Generation, Transmission and Distribution',
#  '2212 Natural Gas Distribution ',
#  '2213 Water, Sewage and Other Systems ']

# %%
ppp_df_23 = ppp_df_23.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
aftertrails = ppp_df_23.loc[ppp_df_23["Industry"] == "Utilities"]
aftertrails["IndustrySubsector"].sort_values().unique().tolist()
# Out:
# ['2211 Electric Power Generation, Transmission and Distribution',
#  '2212 Natural Gas Distribution',
#  '2213 Water, Sewage and Other Systems']

# %% [markdown]
# <h4>DataFrame Finalization

# %% [markdown]
# Final Null, Dtype Check

# %%
pd.set_option('display.max_rows', 70)
print(ppp_df_23.isnull().sum())
# Out:
# LoanNumber                          0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        0
# BorrowerAddress                     0
# BorrowerCity                        0
# BorrowerState                       0
# BorrowerZip                        13
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                   0
# FranchiseName                       0
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              0
# ...

# %%
ppp_df_23.dtypes
# Out:
# LoanNumber                       int64
# SBAOfficeCode                    int64
# ProcessingMethod                object
# BorrowerName                    object
# BorrowerAddress                 object
# BorrowerCity                    object
# BorrowerState                   object
# BorrowerZip                     object
# LoanStatus                      object
# Term                             int64
# SBAGuarantyPercentage            int64
# InitialApprovalAmount          float64
# CurrentApprovalAmount          float64
# UndisbursedAmount              float64
# FranchiseName                   object
# ServicingLenderLocationID        int64
# ServicingLenderName             object
# ServicingLenderAddress          object
# ServicingLenderCity             object
# ServicingLenderState            object
# ServicingLenderZip              object
# RuralUrbanIndicator             object
# HubzoneIndicator                object
# LMIIndicator                    object
# ...

# %%
pd.reset_option('display.max_rows', silent=True)

# %% [markdown]
# <b>Determining Necessary Columns<br></b>
# <h6>Drop Columns that would provide inconclusive analysis results based on significant Null Count<br>
# *potential for filter to be added based on these attributes at later time

# %%
#keep track of columns removed
removed = ['BorrowerAddress', 'BorrowerCity', 'BorrowerZip', 'SBAGuarantyPercentage', 'InitialApprovalAmount', 'FranchiseName',
 'BusinessAgeDescription', 'ProjectCity','ProjectCountyName', 'ProjectState', 'ProjectZip','Race', 'Ethnicity', 'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState', 'ServicingLenderZip', 
 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'DateApproved_ts', 'ForgivenessDate_ts',
 'HEALTH_CARE_PROCEED','DEBT_INTEREST_PROCEED', 'Gender', 'Veteran', 'NA', '4DigitNAICS','TRIIndustrySector']

cols =['LoanNumber','DateApprovedTS','SBAOfficeCode','ProcessingMethod','BorrowerName','BorrowerState',
       'LoanStatusDateTS','LoanStatus','Term','CurrentApprovalAmount','UndisbursedAmount', 
       'ServicingLenderLocationID','ServicingLenderName','ServicingLenderState',
       'RuralUrbanIndicator','HubzoneIndicator','LMIIndicator','BusinessAgeDescription','CD','JobsReported', 
       'NAICSCode','BusinessType','OriginatingLenderLocationID','OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
       'NonProfit', 'ForgivenessAmount', 'ForgivenessDateTS',
       'SBAOfficeLabel', 'ServicingLenderFullAddress','LenderPercent', 'EstimatedLenderProfit', 
       'LoanRange', 'JobRange','Industry', 'IndustrySubsector','LongName', 'FullAdd'] #39

ppp_df_23 = ppp_df_23[cols]
ppp_df_23.head()
# Out:
#    LoanNumber  DateApprovedTS  SBAOfficeCode ProcessingMethod  \
# 0  9547507704        20200501            464              PPP
# 1  9777677704        20200501            464              PPP
# 2  5791407702        20200501           1013              PPP
# 3  6223567700        20200501            920              PPP
# 4  9662437702        20200501            101              PPP
#
#                BorrowerName  BorrowerState LoanStatusDateTS    LoanStatus  \
# 0     SUMTER COATINGS, INC.             SC         20201218  Paid in Full
# 1     PLEASANT PLACES, INC.             SC         20210928  Paid in Full
# 2   BOYER CHILDREN'S CLINIC             WA         20210317  Paid in Full
# 3  KIRTLEY CONSTRUCTION INC             CA         20211016  Paid in Full
# 4              AERO BOX LLC  Not Available         20210817  Paid in Full
#
#    Term  CurrentApprovalAmount  ...                  SBAOfficeLabel  \
# 0    24              769358.78  ...  SOUTH CAROLINA DISTRICT OFFICE
# ...

# %%
ppp_df_23.to_csv("../data/ppp_pipe23.csv")

# %% [markdown]
# <b>Pipeline IN/OUT comp

# %%
csv_path = "../data/raw/>150K/public_150k_plus_230630.csv"
ppp_df_23raw = pd.read_csv(csv_path)
print(set(ppp_df_23raw.columns).symmetric_difference(ppp_df_23.columns))
# Out:
# {'LoanStatusDateTS', 'BorrowerAddress', 'Veteran', 'ServicingLenderCity', 'Industry', 'UTILITIES_PROCEED', 'HEALTH_CARE_PROCEED', 'LenderPercent', 'EstimatedLenderProfit', 'RENT_PROCEED', 'ProjectCountyName', 'Ethnicity', 'Gender', 'ForgivenessDateTS', 'DEBT_INTEREST_PROCEED', 'LoanRange', 'ForgivenessDate', 'IndustrySubsector', 'MORTGAGE_INTEREST_PROCEED', 'JobRange', 'FranchiseName', 'Race', 'ProjectCity', 'SBAOfficeLabel', 'ProjectState', 'BorrowerZip', 'ServicingLenderFullAddress', 'ServicingLenderZip', 'PAYROLL_PROCEED', 'ServicingLenderAddress', 'DateApproved', 'DateApprovedTS', 'REFINANCE_EIDL_PROCEED', 'LoanStatusDate', 'LongName', 'ProjectZip', 'SBAGuarantyPercentage', 'FullAdd', 'BorrowerCity', 'InitialApprovalAmount'}

# %%
nullraw = ppp_df_23raw.isnull().sum()
nullraw_df = pd.DataFrame({"column": nullraw.index, "nulls_r": nullraw.values})

typesraw = ppp_df_23raw.dtypes
typesraw_df = pd.DataFrame({"column": typesraw.index, "dtype_r": typesraw.values})

rawnulltypes = nullraw_df.merge(typesraw_df, on="column", how="left")
rawnulltypes
# Out:
#                          column  nulls_r  dtype_r
# 0                    LoanNumber        0    int64
# 1                  DateApproved        0   object
# 2                 SBAOfficeCode        0    int64
# 3              ProcessingMethod        0   object
# 4                  BorrowerName        4   object
# 5               BorrowerAddress       14   object
# 6                  BorrowerCity       12   object
# 7                 BorrowerState       13   object
# 8                   BorrowerZip       13   object
# 9                LoanStatusDate    16825   object
# 10                   LoanStatus        0   object
# 11                         Term        0    int64
# 12        SBAGuarantyPercentage        0    int64
# 13        InitialApprovalAmount        0  float64
# 14        CurrentApprovalAmount        0  float64
# 15            UndisbursedAmount       46  float64
# 16                FranchiseName   930147   object
# 17    ServicingLenderLocationID        0    int64
# ...

# %%
nullpipe = ppp_df_23.isnull().sum()
nullpipe_df = pd.DataFrame({"column": nullpipe.index, "nulls_r": nullpipe.values})

typespipe = ppp_df_23.dtypes
typespipe_df = pd.DataFrame({"column": typespipe.index, "dtype_r": typespipe.values})

piped_nulltypes = nullpipe_df.merge(typespipe_df, on="column", how="left")
piped_nulltypes
# Out:
#                          column  nulls_r  dtype_r
# 0                    LoanNumber        0    int64
# 1                DateApprovedTS        0    int64
# 2                 SBAOfficeCode        0    int64
# 3              ProcessingMethod        0   object
# 4                  BorrowerName        0   object
# 5                 BorrowerState        0   object
# 6              LoanStatusDateTS        0   object
# 7                    LoanStatus        0   object
# 8                          Term        0    int64
# 9         CurrentApprovalAmount        0  float64
# 10            UndisbursedAmount        0  float64
# 11    ServicingLenderLocationID        0    int64
# 12          ServicingLenderName        0   object
# 13         ServicingLenderState        0   object
# 14          RuralUrbanIndicator        0   object
# 15             HubzoneIndicator        0   object
# 16                 LMIIndicator        0   object
# 17       BusinessAgeDescription        0   object
# ...
