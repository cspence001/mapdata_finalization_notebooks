# %%
import requests
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %% [markdown]
# <b>Merge Pipe to Current Geo

# %%
geo_path = "../../data/state_data/geo/ppp_geo.csv" #data as of 11/21/21
ppp_geo= pd.read_csv(geo_path)
ppp_geo.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
ppp_geonull=ppp_geo.loc[ppp_geo["Lat"].isnull()] #479586
ppp_geonull.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod                                BorrowerName       BorrowerAddress    BorrowerCity BorrowerState  BorrowerZip LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount FranchiseName  ServicingLenderLocationID ServicingLenderName ServicingLenderAddress ServicingLenderCity ServicingLenderState ServicingLenderZip RuralUrbanIndicator HubzoneIndicator LMIIndicator             BusinessAgeDescription     ProjectCity    ProjectCountyName ProjectState  ProjectZip   CD  JobsReported  NAICSCode        Race               Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED                    BusinessType  OriginatingLenderLocationID OriginatingLend
# ...

# %%
ppp_geonull["full_add"].nunique() #64407
# Out:
# 31804

# %%
ppp_geonull["BorrowerState"].value_counts()
# Out:
# OR    13456
# UT     9295
# ID     4416
# PR     2952
# SD     2695
# VI      218
# WY       90
# MP       82
# IN       28
# MI       14
# NC       11
# PA        8
# GU        8
# AL        8
# AK        5
# WA        4
# NM        4
# AZ        4
# TX        4
# NJ        3
# MA        3
# FL        3
# TN        3
# ME        2
# CO        2
# IL        2
# WI        2
# AR        2
# WV        1
# GA        1
# CT        1
# OH        1
# NY        1
# NE        1
# HI        1
# IA        1
# MN        1
# MS        1
# Name: BorrowerState, dtype: int64

# %% [markdown]
# <h4> Process by State

# %%
ppp_togeo_comb= ppp_geonull[ppp_geonull["BorrowerState"] == "ID"] 
ppp_togeo_comb
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod                         BorrowerName               BorrowerAddress BorrowerCity BorrowerState  BorrowerZip LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount FranchiseName  ServicingLenderLocationID           ServicingLenderName ServicingLenderAddress ServicingLenderCity ServicingLenderState ServicingLenderZip RuralUrbanIndicator HubzoneIndicator LMIIndicator             BusinessAgeDescription ProjectCity ProjectCountyName ProjectState  ProjectZip     CD  JobsReported  NAICSCode        Race               Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED              BusinessType  OriginatingLenderLocationID             Orig
# ...

# %%
#process to identify and code for unique addresses 
ppp_togeo = ppp_togeo_comb["full_add"]
ppp_togeo_unique = ppp_togeo.drop_duplicates()
ppp_togeo_unique
# Out:
# 305502               700 E FRANKLIN RD, MERIDIAN, ID
# 305503                  1111 JEFFERSON ST, BOISE, ID
# 305504    3330 E. Louise Dr, Suite 300, MERIDIAN, ID
# 305505       2095 E. Commercial Street, MERIDIAN, ID
# 305506        250 S. Beechwood Ave., #201, BOISE, ID
#                              ...
# 309913                    108 Airport Rd, Kamiah, ID
# 309914          313 N Spokane Street, POST FALLS, ID
# 309915                       PO BOX 3869, HAILEY, ID
# 309916            13403 W GOVERNMENT WAY, HAYDEN, ID
# 309917                     1603 N MAIN, MERIDIAN, ID
# Name: full_add, Length: 4245, dtype: object

# %% [markdown]
# Google Geocoding API

# %%
API_KEY = "AIzaSyB1VgzISCRoQ1hh-ARhR0rzXtQmSKA4TkI" # c.s = 40017
# "AIzaSyC7hhwM4qlfkU8zfiq1_MR-n4BWktUxxMo" #c.d.s = 40017

# %%
params = {
    "key":API_KEY
}
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
addresses = ppp_togeo_unique #STATE
lat = []
lng = []
notfound = []
for address in tqdm(addresses):
    params['address'] = f"{address}"
    response = requests.get(base_url, params=params).json()
    results = response['results']
    try:
        #print(f"{address} is {results[0]['geometry']['location']}")
        #geometry = results[0]['geometry']
        lat.append(results[0]['geometry']['location']['lat'])
        lng.append(results[0]['geometry']['location']['lng'])
        
    except (KeyError, IndexError):
        print(f"{address} Not Found")
        notfound.append(address)
        lat.append(None)
        lng.append(None)
# Out:
#   0%|          | 0/4245 [00:00<?, ?it/s]

# %%
print(notfound)
notfound_df = pd.DataFrame({"Not_Found":notfound})
notfound_df.count()
# Out:
# ['806 PO Box, MELVIN, TX', '325, DALLAS, TX', '156 ENCANTADA, HORSESHOE LANE, TX', '2715 HANCOCK DR, AUSTIN, TX']
# Not_Found    4
# dtype: int64

# %%
addresses = ppp_togeo_unique

# %%
addresses
# Out:
# 840482                           806 PO Box, MELVIN, TX
# 850869                                  325, DALLAS, TX
# 852416                  20311 Kuykendahl Rd, SPRING, TX
# 857428      3245 Main Street Suite #235-329, Frisco, TX
# 857429               5913 Patton St, Corpus Christi, TX
#                               ...
# 886818                      401 South Parker, Bryan, TX
# 886819    1386 Industrial Dr Ste 125, New Braunfels, TX
# 886820                    4305 N. Garfield, Midland, TX
# 886821                   1801 Magoffin Ave, El Paso, TX
# 886822                      5800 Heiser St, Houston, TX
# Name: full_add, Length: 27398, dtype: object

# %%
addresses.head()
# Out:
# 840482                         806 PO Box, MELVIN, TX
# 850869                                325, DALLAS, TX
# 852416                20311 Kuykendahl Rd, SPRING, TX
# 857428    3245 Main Street Suite #235-329, Frisco, TX
# 857429             5913 Patton St, Corpus Christi, TX
# Name: full_add, dtype: object

# %%
lat_df= pd.DataFrame(lat)
lat_df
# Out:
#                0
# 0            NaN
# 1            NaN
# 2      30.065226
# 3      33.153386
# 4      27.691322
# ...          ...
# 27393  30.670456
# 27394  29.716146
# 27395  32.032663
# 27396  31.767618
# 27397  29.680681
#
# [27398 rows x 1 columns]

# %%
tx_add = addresses.iloc[:5212]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)
location_df = pd.DataFrame({"full_add": addresses, "Lat": lat, "Long":lng})
location_df.head()
# Out:
#                                            full_add        Lat       Long
# 840482                       806 PO Box, MELVIN, TX        NaN        NaN
# 850869                              325, DALLAS, TX        NaN        NaN
# 852416              20311 Kuykendahl Rd, SPRING, TX  30.065226 -95.504452
# 857428  3245 Main Street Suite #235-329, Frisco, TX  33.153386 -96.890042
# 857429           5913 Patton St, Corpus Christi, TX  27.691322 -97.372991

# %%
location_null = location_df.loc[location_df["Lat"].isnull()]
location_null.count()
# Out:
# full_add    4
# Lat         0
# Long        0
# dtype: int64

# %%
location_df.to_csv("../../data/state_data/geo/verify/location_verify_id.csv")

# %% [markdown]
# #ref point 1/7

# %%
location_df= pd.read_csv("../../data/state_data/geo/verify/location_verify_id.csv")
location_df
# Out:
#        Unnamed: 0                                       full_add        Lat        Long
# 0          840482                         806 PO Box, MELVIN, TX        NaN         NaN
# 1          850869                                325, DALLAS, TX        NaN         NaN
# 2          852416                20311 Kuykendahl Rd, SPRING, TX  30.065226  -95.504452
# 3          857428    3245 Main Street Suite #235-329, Frisco, TX  33.153386  -96.890042
# 4          857429             5913 Patton St, Corpus Christi, TX  27.691322  -97.372991
# ...           ...                                            ...        ...         ...
# 27393      886818                    401 South Parker, Bryan, TX  30.670456  -96.374926
# 27394      886819  1386 Industrial Dr Ste 125, New Braunfels, TX  29.716146  -98.096696
# 27395      886820                  4305 N. Garfield, Midland, TX  32.032663 -102.112495
# 27396      886821                 1801 Magoffin Ave, El Paso, TX  31.767618 -106.468716
# ...

# %%
#ppp_geo["BorrowerState"].value_counts()

# %%
#mapping coordinates to NaN values in main ppp_geo
m = dict(zip(location_df.full_add,location_df.Lat))
ppp_geo.Lat = ppp_geo.Lat.fillna(ppp_geo.full_add.map(m))
n = dict(zip(location_df.full_add,location_df.Long))
ppp_geo.Long = ppp_geo.Long.fillna(ppp_geo.full_add.map(n))

# %%
#ppp_geoVT[ppp_geoVT.duplicated(keep=False)]

# %%
null_check =ppp_geo.loc[ppp_geo["Lat"].isnull()] #93877 > 66711 > 61268 > 33334
null_check
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod                                        BorrowerName                BorrowerAddress    BorrowerCity BorrowerState  BorrowerZip LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount FranchiseName  ServicingLenderLocationID    ServicingLenderName ServicingLenderAddress ServicingLenderCity ServicingLenderState ServicingLenderZip RuralUrbanIndicator HubzoneIndicator LMIIndicator             BusinessAgeDescription     ProjectCity    ProjectCountyName ProjectState  ProjectZip   CD  JobsReported  NAICSCode        Race               Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED                    BusinessType  OriginatingLenderLocationID      OriginatingL
# ...

# %% [markdown]
# Writing to main Geo File

# %%
ppp_geo.to_csv("../../data/state_data/geo/ppp_geo.csv")

# %%
ppp_df = ppp_geo

# %% [markdown]
# Parsing Geo DataFrame for State Geo Files

# %%
ak_df = ppp_df.loc[ppp_df["BorrowerState"] == "AK", :]
al_df = ppp_df.loc[ppp_df["BorrowerState"] == "AL", :]
ar_df = ppp_df.loc[ppp_df["BorrowerState"] == "AR", :]
as_df = ppp_df.loc[ppp_df["BorrowerState"] == "AS", :] #American Samoa
az_df = ppp_df.loc[ppp_df["BorrowerState"] == "AZ", :]
ca_df = ppp_df.loc[ppp_df["BorrowerState"] == "CA", :]
co_df = ppp_df.loc[ppp_df["BorrowerState"] == "CO", :]
ct_df = ppp_df.loc[ppp_df["BorrowerState"] == "CT", :]
dc_df = ppp_df.loc[ppp_df["BorrowerState"] == "DC", :] #D.C.
de_df = ppp_df.loc[ppp_df["BorrowerState"] == "DE", :]
fl_df = ppp_df.loc[ppp_df["BorrowerState"] == "FL", :]
ga_df = ppp_df.loc[ppp_df["BorrowerState"] == "GA", :]
gu_df = ppp_df.loc[ppp_df["BorrowerState"] == "GU", :] #Guam
hi_df = ppp_df.loc[ppp_df["BorrowerState"] == "HI", :]
ia_df = ppp_df.loc[ppp_df["BorrowerState"] == "IA", :]
id_df = ppp_df.loc[ppp_df["BorrowerState"] == "ID", :]
il_df = ppp_df.loc[ppp_df["BorrowerState"] == "IL", :]
in_df = ppp_df.loc[ppp_df["BorrowerState"] == "IN", :]
ks_df = ppp_df.loc[ppp_df["BorrowerState"] == "KS", :]
ky_df = ppp_df.loc[ppp_df["BorrowerState"] == "KY", :]
la_df = ppp_df.loc[ppp_df["BorrowerState"] == "LA", :]
ma_df = ppp_df.loc[ppp_df["BorrowerState"] == "MA", :]
md_df = ppp_df.loc[ppp_df["BorrowerState"] == "MD", :]
me_df = ppp_df.loc[ppp_df["BorrowerState"] == "ME", :]
mi_df = ppp_df.loc[ppp_df["BorrowerState"] == "MI", :]
mn_df = ppp_df.loc[ppp_df["BorrowerState"] == "MN", :]
mo_df = ppp_df.loc[ppp_df["BorrowerState"] == "MO", :]
mp_df = ppp_df.loc[ppp_df["BorrowerState"] == "MP", :] #Saipan Member of Parliament
ms_df = ppp_df.loc[ppp_df["BorrowerState"] == "MS", :]
mt_df = ppp_df.loc[ppp_df["BorrowerState"] == "MT", :]
nc_df = ppp_df.loc[ppp_df["BorrowerState"] == "NC", :]
nd_df = ppp_df.loc[ppp_df["BorrowerState"] == "ND", :]
ne_df = ppp_df.loc[ppp_df["BorrowerState"] == "NE", :]
nh_df = ppp_df.loc[ppp_df["BorrowerState"] == "NH", :]
nj_df = ppp_df.loc[ppp_df["BorrowerState"] == "NJ", :]
nm_df = ppp_df.loc[ppp_df["BorrowerState"] == "NM", :]
nv_df = ppp_df.loc[ppp_df["BorrowerState"] == "NV", :]
ny_df = ppp_df.loc[ppp_df["BorrowerState"] == "NY", :]
oh_df = ppp_df.loc[ppp_df["BorrowerState"] == "OH", :]
ok_df = ppp_df.loc[ppp_df["BorrowerState"] == "OK", :]
or_df = ppp_df.loc[ppp_df["BorrowerState"] == "OR", :]
pa_df = ppp_df.loc[ppp_df["BorrowerState"] == "PA", :]
pr_df = ppp_df.loc[ppp_df["BorrowerState"] == "PR", :] #Puerto Rico
ri_df = ppp_df.loc[ppp_df["BorrowerState"] == "RI", :]
sc_df = ppp_df.loc[ppp_df["BorrowerState"] == "SC", :]
sd_df = ppp_df.loc[ppp_df["BorrowerState"] == "SD", :]
tn_df = ppp_df.loc[ppp_df["BorrowerState"] == "TN", :]
tx_df = ppp_df.loc[ppp_df["BorrowerState"] == "TX", :]
ut_df = ppp_df.loc[ppp_df["BorrowerState"] == "UT", :]
va_df = ppp_df.loc[ppp_df["BorrowerState"] == "VA", :]
vi_df = ppp_df.loc[ppp_df["BorrowerState"] == "VI", :] #Virgin Islands
vt_df = ppp_df.loc[ppp_df["BorrowerState"] == "VT", :]
wa_df = ppp_df.loc[ppp_df["BorrowerState"] == "WA", :]
wi_df = ppp_df.loc[ppp_df["BorrowerState"] == "WI", :]
wv_df = ppp_df.loc[ppp_df["BorrowerState"] == "WV", :]
wy_df = ppp_df.loc[ppp_df["BorrowerState"] == "WY", :]

# %% [markdown]
# Geocoded States

# %%
ak_df.to_csv("../../data/state_data/geo/geocoded/geo_ak.csv") 
al_df.to_csv("../../data/state_data/geo/geocoded/geo_al.csv")
ar_df.to_csv("../../data/state_data/geo/geocoded/geo_ar.csv") 
as_df.to_csv("../../data/state_data/geo/geocoded/geo_as.csv")
az_df.to_csv("../../data/state_data/geo/geocoded/geo_az.csv")  
ca_df.to_csv("../../data/state_data/geo/geocoded/geo_ca.csv")
co_df.to_csv("../../data/state_data/geo/geocoded/geo_co.csv") 
ct_df.to_csv("../../data/state_data/geo/geocoded/geo_ct.csv")  


dc_df.to_csv("../../data/state_data/geo/geocoded/geo_dc.csv")
de_df.to_csv("../../data/state_data/geo/geocoded/geo_de.csv") 
ga_df.to_csv("../../data/state_data/geo/geocoded/geo_ga.csv")
gu_df.to_csv("../../data/state_data/geo/geocoded/geo_gu.csv")
hi_df.to_csv("../../data/state_data/geo/geocoded/geo_hi.csv") 
fl_df.to_csv("../../data/state_data/geo/geocoded/geo_fl.csv") 
ia_df.to_csv("../../data/state_data/geo/geocoded/geo_ia.csv")
id_df.to_csv("../../data/state_data/geo/geocoded/geo_id.csv")   
il_df.to_csv("../../data/state_data/geo/geocoded/geo_il.csv")
in_df.to_csv("../../data/state_data/geo/geocoded/geo_in.csv") 
ks_df.to_csv("../../data/state_data/geo/geocoded/geo_ks.csv")
ky_df.to_csv("../../data/state_data/geo/geocoded/geo_ky.csv")
la_df.to_csv("../../data/state_data/geo/geocoded/geo_la.csv")
nc_df.to_csv("../../data/state_data/geo/geocoded/geo_nc.csv") 
nd_df.to_csv("../../data/state_data/geo/geocoded/geo_nd.csv")
ne_df.to_csv("../../data/state_data/geo/geocoded/geo_ne.csv")
ma_df.to_csv("../../data/state_data/geo/geocoded/geo_ma.csv") 
md_df.to_csv("../../data/state_data/geo/geocoded/geo_md.csv")
me_df.to_csv("../../data/state_data/geo/geocoded/geo_me.csv")
mi_df.to_csv("../../data/state_data/geo/geocoded/geo_mi.csv") 
mn_df.to_csv("../../data/state_data/geo/geocoded/geo_mn.csv") 
mo_df.to_csv("../../data/state_data/geo/geocoded/geo_mo.csv")
ms_df.to_csv("../../data/state_data/geo/geocoded/geo_ms.csv")
mt_df.to_csv("../../data/state_data/geo/geocoded/geo_mt.csv")
nc_df.to_csv("../../data/state_data/geo/geocoded/geo_nc.csv")
nh_df.to_csv("../../data/state_data/geo/geocoded/geo_nh.csv")  
nj_df.to_csv("../../data/state_data/geo/geocoded/geo_nj.csv")
nm_df.to_csv("../../data/state_data/geo/geocoded/geo_nm.csv") 
nv_df.to_csv("../../data/state_data/geo/geocoded/geo_nv.csv")  
ny_df.to_csv("../../data/state_data/geo/geocoded/geo_ny.csv")  
oh_df.to_csv("../../data/state_data/geo/geocoded/geo_oh.csv")
ok_df.to_csv("../../data/state_data/geo/geocoded/geo_ok.csv")
pa_df.to_csv("../../data/state_data/geo/geocoded/geo_pa.csv")
ri_df.to_csv("../../data/state_data/geo/geocoded/geo_ri.csv")
sc_df.to_csv("../../data/state_data/geo/geocoded/geo_sc.csv")
tn_df.to_csv("../../data/state_data/geo/geocoded/geo_tn.csv")  
tx_df.to_csv("../../data/state_data/geo/geocoded/geo_tx.csv")  
va_df.to_csv("../../data/state_data/geo/geocoded/geo_va.csv") 
vi_df.to_csv("../../data/state_data/geo/geocoded/geo_vi.csv")  
vt_df.to_csv("../../data/state_data/geo/geocoded/geo_vt.csv")
wa_df.to_csv("../../data/state_data/geo/geocoded/geo_wa.csv")
wi_df.to_csv("../../data/state_data/geo/geocoded/geo_wi.csv")  
wv_df.to_csv("../../data/state_data/geo/geocoded/geo_wv.csv")

# %% [markdown]
# All States

# %%
ak_df.to_csv("../../data/state_data/geo_ak.csv") 
al_df.to_csv("../../data/state_data/geo_al.csv")
ar_df.to_csv("../../data/state_data/geo_ar.csv") 
as_df.to_csv("../../data/state_data/geo_as.csv")
az_df.to_csv("../../data/state_data/geo_az.csv")  
ca_df.to_csv("../../data/state_data/geo_ca.csv")  
co_df.to_csv("../../data/state_data/geo_co.csv") 
ct_df.to_csv("../../data/state_data/geo_ct.csv")  
dc_df.to_csv("../../data/state_data/geo_dc.csv")
de_df.to_csv("../../data/state_data/geo_de.csv") 
fl_df.to_csv("../../data/state_data/geo_fl.csv") 
ga_df.to_csv("../../data/state_data/geo_ga.csv") 
gu_df.to_csv("../../data/state_data/geo_gu.csv")
hi_df.to_csv("../../data/state_data/geo_hi.csv") 
ia_df.to_csv("../../data/state_data/geo_ia.csv")  
id_df.to_csv("../../data/state_data/geo_id.csv")  
il_df.to_csv("../../data/state_data/geo_il.csv")  
in_df.to_csv("../../data/state_data/geo_in.csv") 
ks_df.to_csv("../../data/state_data/geo_ks.csv")  
ky_df.to_csv("../../data/state_data/geo_ky.csv")  
la_df.to_csv("../../data/state_data/geo_la.csv")
ma_df.to_csv("../../data/state_data/geo_ma.csv") 
md_df.to_csv("../../data/state_data/geo_md.csv")
me_df.to_csv("../../data/state_data/geo_me.csv")  
mi_df.to_csv("../../data/state_data/geo_mi.csv") 
mn_df.to_csv("../../data/state_data/geo_mn.csv") 
mo_df.to_csv("../../data/state_data/geo_mo.csv")  
mp_df.to_csv("../../data/state_data/geo_mp.csv") 
ms_df.to_csv("../../data/state_data/geo_ms.csv")
mt_df.to_csv("../../data/state_data/geo_mt.csv")
nc_df.to_csv("../../data/state_data/geo_nc.csv") 
nd_df.to_csv("../../data/state_data/geo_nd.csv")  
ne_df.to_csv("../../data/state_data/geo_ne.csv")
nh_df.to_csv("../../data/state_data/geo_nh.csv")  
nj_df.to_csv("../../data/state_data/geo_nj.csv")
nm_df.to_csv("../../data/state_data/geo_nm.csv") 
nv_df.to_csv("../../data/state_data/geo_nv.csv")  
ny_df.to_csv("../../data/state_data/geo_ny.csv")  
oh_df.to_csv("../../data/state_data/geo_oh.csv")
ok_df.to_csv("../../data/state_data/geo_ok.csv") 
or_df.to_csv("../../data/state_data/geo_or.csv")  
pa_df.to_csv("../../data/state_data/geo_pa.csv")
pr_df.to_csv("../../data/state_data/geo_pr.csv")  
ri_df.to_csv("../../data/state_data/geo_ri.csv") 
sc_df.to_csv("../../data/state_data/geo_sc.csv") 
sd_df.to_csv("../../data/state_data/geo_sd.csv") 
tn_df.to_csv("../../data/state_data/geo_tn.csv")  
tx_df.to_csv("../../data/state_data/geo_tx.csv")  
ut_df.to_csv("../../data/state_data/geo_ut.csv")  
va_df.to_csv("../../data/state_data/geo_va.csv")  
vi_df.to_csv("../../data/state_data/geo_vi.csv")  
vt_df.to_csv("../../data/state_data/geo_vt.csv")
wa_df.to_csv("../../data/state_data/geo_wa.csv")  
wi_df.to_csv("../../data/state_data/geo_wi.csv")  
wv_df.to_csv("../../data/state_data/geo_wv.csv") 
wy_df.to_csv("../../data/state_data/geo_wy.csv")
