# %%
import requests
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %% [markdown]
# <b>Merge Pipe to Current Geo

# %%
geo_path = "../turbo-octo-goggles/data/state_data/geo/ppp_geo.csv" #data as of 11/21/21
ppp_geo= pd.read_csv(geo_path)
ppp_geo
# Out:
# /Users/ciaraspencer/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (70) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0                0             0               0  9547507704       5/1/20
# 1                1             1               1  9777677704       5/1/20
# 2                2             2               2  5791407702       5/1/20
# 3                3             3               3  6223567700       5/1/20
# 4                4             4               4  9662437702       5/1/20
# ...            ...           ...             ...         ...          ...
# 968552      968552        968552          968552  4395967002       4/3/20
# 968553      968553        968553          968553  6985647108      4/14/20
# ...

# %%
ppp_geonull=ppp_geo.loc[ppp_geo["Lat"].isnull()] #479586
ppp_geonull.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 369          369           369             369  5048318601      3/20/21
# 428          428           428             428  5085327008       4/5/20
# 1865        1865          1865            1865  4637628408       2/6/21
# 2274        2274          2274            2274  5337318401       2/8/21
# 2379        2379          2379            2379  9891427104      4/15/20
#
#       SBAOfficeCode ProcessingMethod  \
# 369            1084              PPS
# 428            1084              PPP
# 1865           1084              PPS
# 2274           1084              PPS
# 2379           1084              PPP
#
#                                     BorrowerName       BorrowerAddress  \
# 369               DELTA INDUSTRIAL SERVICES INC.   1229 RICHARDSON HWY
# 428              DELTA INDUSTRIAL SERVICES, INC.   1229 Richardson Hwy
# 1865                MCKINLEY FIRE PROTECTION LLC         1706 Ship Ave
# ...

# %%
ppp_geonull["full_add"].nunique() #477363
# Out:
# 103374

# %%
ppp_geonull["BorrowerState"].value_counts()
# Out:
# TX    76183
# OR    13456
# UT     9295
# ID     4416
# PR     2952
# SD     2695
# VI      218
# WY       90
# MP       82
# IN       28
# MI       14
# NC       11
# PA        8
# GU        8
# AL        8
# AK        5
# NM        4
# WA        4
# AZ        4
# TN        3
# MA        3
# NJ        3
# FL        3
# ME        2
# IL        2
# WI        2
# AR        2
# CO        2
# WV        1
# GA        1
# CT        1
# MN        1
# HI        1
# OH        1
# NY        1
# NE        1
# IA        1
# MS        1
# Name: BorrowerState, dtype: int64

# %% [markdown]
# <h4> Process by State

# %%
ppp_togeo_comb= ppp_geonull[ppp_geonull["BorrowerState"] == "WI"]
ppp_togeo_comb
# Out:
#         Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 945699      945699        945699  1040127103       4/9/20            563
# 945700      945700        945700  1299787308      4/28/20            563
# 945701      945701        945701  1525827110      4/10/20            563
# 945702      945702        945702  2572157107      4/10/20            563
# 945703      945703        945703  3943447203      4/27/20            563
# ...            ...           ...         ...          ...            ...
# 963048      963048        963048  9282518304      1/30/21            563
# 963049      963049        963049  9361087700       5/1/20            563
# 963050      963050        963050  9411997102      4/15/20            563
# 963051      963051        963051  9453378305      1/30/21            563
# 963052      963052        963052  9478227110      4/15/20            563
#
#        ProcessingMethod                        BorrowerName  \
# ...

# %%
#process to identify and code for unique addresses 
ppp_togeo = ppp_togeo_comb["full_add"]
ppp_togeo_unique = ppp_togeo.drop_duplicates()
ppp_togeo_unique
# Out:
# 945699      5100 Eastpark Blvd, Suite 210 0.0, Madison, WI
# 945700            221 W. COLLEGE AVE Floor 2, APPLETON, WI
# 945701           2700 National Drive Ste 100, ONALASKA, WI
# 945702    W6390 Challenger Dr, Suite 203 0.0, Appleton, WI
# 945703                       10889 E PENNY LN, BARABOO, WI
#                                 ...
# 963048             W229N5065 Duplainville Rd, Pewaukee, WI
# 963049                     3806 DOUGLAS AVENUE, RACINE, WI
# 963050                      6101 W VLIET ST, WAUWATOSA, WI
# 963051                  E5690 County Road D, Menomonie, WI
# 963052                      1015 CAMPBELL ST, PRESCOTT, WI
# Name: full_add, Length: 16677, dtype: object

# %% [markdown]
# Google Geocoding API

# %%
API_KEY = "AIzaSyB1VgzISCRoQ1hh-ARhR0rzXtQmSKA4TkI" # c.s = 22897 + 16677
# "AIzaSyC7hhwM4qlfkU8zfiq1_MR-n4BWktUxxMo" #c.d.s = 28718 + 1977 = 30534

# %%
params = {
    "key":API_KEY
}
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
addresses = ppp_togeo_unique #STATE
lat = []
lng = []
notfound = []
for address in tqdm(addresses):
    params['address'] = f"{address}"
    response = requests.get(base_url, params=params).json()
    results = response['results']
    try:
        #print(f"{address} is {results[0]['geometry']['location']}")
        #geometry = results[0]['geometry']
        lat.append(results[0]['geometry']['location']['lat'])
        lng.append(results[0]['geometry']['location']['lng'])
        
    except (KeyError, IndexError):
        print(f"{address} Not Found")
        notfound.append(address)
        lat.append(None)
        lng.append(None)
# Out:
#   0%|          | 0/16677 [00:00<?, ?it/s]
# 320 10th Ave., PO Box 96, BALDWIN, WI Not Found
# 715 MORGAN ST PO BOX 247, CLYMAN, WI Not Found

# %%
print(notfound)
notfound_df = pd.DataFrame({"Not_Found":notfound})
notfound_df.count()
# Out:
# ['320 10th Ave., PO Box 96, BALDWIN, WI', '715 MORGAN ST PO BOX 247, CLYMAN, WI']
# Not_Found    2
# dtype: int64

# %%
addresses = ppp_togeo_unique

# %%
addresses
# Out:
# 945699      5100 Eastpark Blvd, Suite 210 0.0, Madison, WI
# 945700            221 W. COLLEGE AVE Floor 2, APPLETON, WI
# 945701           2700 National Drive Ste 100, ONALASKA, WI
# 945702    W6390 Challenger Dr, Suite 203 0.0, Appleton, WI
# 945703                       10889 E PENNY LN, BARABOO, WI
#                                 ...
# 963048             W229N5065 Duplainville Rd, Pewaukee, WI
# 963049                     3806 DOUGLAS AVENUE, RACINE, WI
# 963050                      6101 W VLIET ST, WAUWATOSA, WI
# 963051                  E5690 County Road D, Menomonie, WI
# 963052                      1015 CAMPBELL ST, PRESCOTT, WI
# Name: full_add, Length: 16677, dtype: object

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)
location_df = pd.DataFrame({"full_add": addresses, "Lat": lat, "Long":lng})
location_df
# Out:
#                                                 full_add        Lat       Long
# 945699    5100 Eastpark Blvd, Suite 210 0.0, Madison, WI  43.144787 -89.294690
# 945700          221 W. COLLEGE AVE Floor 2, APPLETON, WI  44.261498 -88.408348
# 945701         2700 National Drive Ste 100, ONALASKA, WI  43.879726 -91.189984
# 945702  W6390 Challenger Dr, Suite 203 0.0, Appleton, WI  44.260292 -88.511351
# 945703                     10889 E PENNY LN, BARABOO, WI  43.522722 -89.780254
# ...                                                  ...        ...        ...
# 963048           W229N5065 Duplainville Rd, Pewaukee, WI  43.109408 -88.203886
# 963049                   3806 DOUGLAS AVENUE, RACINE, WI  42.767675 -87.803579
# 963050                    6101 W VLIET ST, WAUWATOSA, WI  43.050101 -87.988944
# 963051                E5690 County Road D, Menomonie, WI  44.968805 -91.875247
# 963052                    1015 CAMPBELL ST, PRESCOTT, WI  44.759818 -92.792021
#
# ...

# %%
location_null = location_df.loc[location_df["Lat"].isnull()]
location_null.count()
# Out:
# full_add    2
# Lat         0
# Long        0
# dtype: int64

# %%
location_df.to_csv("../turbo-octo-goggles/data/state_data/geo/verify/location_verify_wi.csv")

# %% [markdown]
# #ref point 1/7

# %%
location_df= pd.read_csv("../turbo-octo-goggles/data/state_data/geo/verify/location_verify_wi.csv")
location_df
# Out:
#        Unnamed: 0                                          full_add        Lat       Long
# 0          945699    5100 Eastpark Blvd, Suite 210 0.0, Madison, WI  43.144787 -89.294690
# 1          945700          221 W. COLLEGE AVE Floor 2, APPLETON, WI  44.261498 -88.408348
# 2          945701         2700 National Drive Ste 100, ONALASKA, WI  43.879726 -91.189984
# 3          945702  W6390 Challenger Dr, Suite 203 0.0, Appleton, WI  44.260292 -88.511351
# 4          945703                     10889 E PENNY LN, BARABOO, WI  43.522722 -89.780254
# ...           ...                                               ...        ...        ...
# 16672      963048           W229N5065 Duplainville Rd, Pewaukee, WI  43.109408 -88.203886
# 16673      963049                   3806 DOUGLAS AVENUE, RACINE, WI  42.767675 -87.803579
# 16674      963050                    6101 W VLIET ST, WAUWATOSA, WI  43.050101 -87.988944
# ...

# %%
#ppp_geo["BorrowerState"].value_counts()

# %%
#mapping coordinates to NaN values in main ppp_geo
m = dict(zip(location_df.full_add,location_df.Lat))
ppp_geo.Lat = ppp_geo.Lat.fillna(ppp_geo.full_add.map(m))
n = dict(zip(location_df.full_add,location_df.Long))
ppp_geo.Long = ppp_geo.Long.fillna(ppp_geo.full_add.map(n))

# %%
#ppp_geoVT[ppp_geoVT.duplicated(keep=False)]

# %%
null_check =ppp_geo.loc[ppp_geo["Lat"].isnull()] #292233 - 280150
null_check
# Out:
#         Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod                                        BorrowerName                BorrowerAddress    BorrowerCity BorrowerState  BorrowerZip LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount FranchiseName  ServicingLenderLocationID    ServicingLenderName ServicingLenderAddress ServicingLenderCity ServicingLenderState ServicingLenderZip RuralUrbanIndicator HubzoneIndicator LMIIndicator             BusinessAgeDescription     ProjectCity    ProjectCountyName ProjectState  ProjectZip   CD  JobsReported  NAICSCode        Race               Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED                    BusinessType  OriginatingLenderLocationID      OriginatingLender OriginatingLenderCity OriginatingLenderState        Gender      Vetera
# ...

# %%
ppp_geo.to_csv("../turbo-octo-goggles/data/state_data/geo/ppp_geo.csv")

# %%
ppp_df = ppp_geo

# %%
ak_df = ppp_df.loc[ppp_df["BorrowerState"] == "AK", :]
al_df = ppp_df.loc[ppp_df["BorrowerState"] == "AL", :]
ar_df = ppp_df.loc[ppp_df["BorrowerState"] == "AR", :]
as_df = ppp_df.loc[ppp_df["BorrowerState"] == "AS", :] #American Samoa
az_df = ppp_df.loc[ppp_df["BorrowerState"] == "AZ", :]
ca_df = ppp_df.loc[ppp_df["BorrowerState"] == "CA", :]
co_df = ppp_df.loc[ppp_df["BorrowerState"] == "CO", :]
ct_df = ppp_df.loc[ppp_df["BorrowerState"] == "CT", :]
dc_df = ppp_df.loc[ppp_df["BorrowerState"] == "DC", :] #D.C.
de_df = ppp_df.loc[ppp_df["BorrowerState"] == "DE", :]
fl_df = ppp_df.loc[ppp_df["BorrowerState"] == "FL", :]
ga_df = ppp_df.loc[ppp_df["BorrowerState"] == "GA", :]
gu_df = ppp_df.loc[ppp_df["BorrowerState"] == "GU", :] #Guam
hi_df = ppp_df.loc[ppp_df["BorrowerState"] == "HI", :]
ia_df = ppp_df.loc[ppp_df["BorrowerState"] == "IA", :]
id_df = ppp_df.loc[ppp_df["BorrowerState"] == "ID", :]
il_df = ppp_df.loc[ppp_df["BorrowerState"] == "IL", :]
in_df = ppp_df.loc[ppp_df["BorrowerState"] == "IN", :]
ks_df = ppp_df.loc[ppp_df["BorrowerState"] == "KS", :]
ky_df = ppp_df.loc[ppp_df["BorrowerState"] == "KY", :]
la_df = ppp_df.loc[ppp_df["BorrowerState"] == "LA", :]
ma_df = ppp_df.loc[ppp_df["BorrowerState"] == "MA", :]
md_df = ppp_df.loc[ppp_df["BorrowerState"] == "MD", :]
me_df = ppp_df.loc[ppp_df["BorrowerState"] == "ME", :]
mi_df = ppp_df.loc[ppp_df["BorrowerState"] == "MI", :]
mn_df = ppp_df.loc[ppp_df["BorrowerState"] == "MN", :]
mo_df = ppp_df.loc[ppp_df["BorrowerState"] == "MO", :]
mp_df = ppp_df.loc[ppp_df["BorrowerState"] == "MP", :] #Saipan Member of Parliament
ms_df = ppp_df.loc[ppp_df["BorrowerState"] == "MS", :]
mt_df = ppp_df.loc[ppp_df["BorrowerState"] == "MT", :]
nc_df = ppp_df.loc[ppp_df["BorrowerState"] == "NC", :]
nd_df = ppp_df.loc[ppp_df["BorrowerState"] == "ND", :]
ne_df = ppp_df.loc[ppp_df["BorrowerState"] == "NE", :]
nh_df = ppp_df.loc[ppp_df["BorrowerState"] == "NH", :]
nj_df = ppp_df.loc[ppp_df["BorrowerState"] == "NJ", :]
nm_df = ppp_df.loc[ppp_df["BorrowerState"] == "NM", :]
nv_df = ppp_df.loc[ppp_df["BorrowerState"] == "NV", :]
ny_df = ppp_df.loc[ppp_df["BorrowerState"] == "NY", :]
oh_df = ppp_df.loc[ppp_df["BorrowerState"] == "OH", :]
ok_df = ppp_df.loc[ppp_df["BorrowerState"] == "OK", :]
or_df = ppp_df.loc[ppp_df["BorrowerState"] == "OR", :]
pa_df = ppp_df.loc[ppp_df["BorrowerState"] == "PA", :]
pr_df = ppp_df.loc[ppp_df["BorrowerState"] == "PR", :] #Puerto Rico
ri_df = ppp_df.loc[ppp_df["BorrowerState"] == "RI", :]
sc_df = ppp_df.loc[ppp_df["BorrowerState"] == "SC", :]
sd_df = ppp_df.loc[ppp_df["BorrowerState"] == "SD", :]
tn_df = ppp_df.loc[ppp_df["BorrowerState"] == "TN", :]
tx_df = ppp_df.loc[ppp_df["BorrowerState"] == "TX", :]
ut_df = ppp_df.loc[ppp_df["BorrowerState"] == "UT", :]
va_df = ppp_df.loc[ppp_df["BorrowerState"] == "VA", :]
vi_df = ppp_df.loc[ppp_df["BorrowerState"] == "VI", :] #Virgin Islands
vt_df = ppp_df.loc[ppp_df["BorrowerState"] == "VT", :]
wa_df = ppp_df.loc[ppp_df["BorrowerState"] == "WA", :]
wi_df = ppp_df.loc[ppp_df["BorrowerState"] == "WI", :]
wv_df = ppp_df.loc[ppp_df["BorrowerState"] == "WV", :]
wy_df = ppp_df.loc[ppp_df["BorrowerState"] == "WY", :]

# %%
ak_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ak.csv") 
al_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_al.csv")
ar_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ar.csv") 
as_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_as.csv")
az_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_az.csv")  
ca_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ca.csv")
co_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_co.csv") 
ct_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ct.csv")  


dc_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_dc.csv")
de_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_de.csv") 
ga_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ga.csv")
gu_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_gu.csv")
hi_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_hi.csv") 
fl_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_fl.csv") 
ia_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ia.csv")  
il_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_il.csv")
in_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_in.csv") 
ks_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ks.csv")
ky_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ky.csv")
la_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_la.csv")
nc_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nc.csv") 
nd_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nd.csv")
ne_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ne.csv")
ma_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ma.csv") 
md_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_md.csv")
me_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_me.csv")
mi_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_mi.csv") 
mn_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_mn.csv") 
mo_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_mo.csv")
ms_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ms.csv")
mt_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_mt.csv")
nc_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nc.csv")
nh_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nh.csv")  
nj_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nj.csv")
nm_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nm.csv") 
nv_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_nv.csv")  
ny_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ny.csv")  
oh_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_oh.csv")
ok_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ok.csv")
pa_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_pa.csv")
ri_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_ri.csv")
sc_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_sc.csv")
tn_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_tn.csv")  
va_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_va.csv") 
vi_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_vi.csv")  
vt_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_vt.csv")
wa_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_wa.csv")
wi_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_wi.csv")  
wv_df.to_csv("../turbo-octo-goggles/data/state_data/geo/geocoded/geo_wv.csv")

# %%
ak_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ak.csv") 
al_df.to_csv("../turbo-octo-goggles/data/state_data/geo_al.csv")
ar_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ar.csv") 
as_df.to_csv("../turbo-octo-goggles/data/state_data/geo_as.csv")
az_df.to_csv("../turbo-octo-goggles/data/state_data/geo_az.csv")  
ca_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ca.csv")  
co_df.to_csv("../turbo-octo-goggles/data/state_data/geo_co.csv") 
ct_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ct.csv")  
dc_df.to_csv("../turbo-octo-goggles/data/state_data/geo_dc.csv")
de_df.to_csv("../turbo-octo-goggles/data/state_data/geo_de.csv") 
fl_df.to_csv("../turbo-octo-goggles/data/state_data/geo_fl.csv") 
ga_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ga.csv") 
gu_df.to_csv("../turbo-octo-goggles/data/state_data/geo_gu.csv")
hi_df.to_csv("../turbo-octo-goggles/data/state_data/geo_hi.csv") 
ia_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ia.csv")  
id_df.to_csv("../turbo-octo-goggles/data/state_data/geo_id.csv")  
il_df.to_csv("../turbo-octo-goggles/data/state_data/geo_il.csv")  
in_df.to_csv("../turbo-octo-goggles/data/state_data/geo_in.csv") 
ks_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ks.csv")  
ky_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ky.csv")  
la_df.to_csv("../turbo-octo-goggles/data/state_data/geo_la.csv")
ma_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ma.csv") 
md_df.to_csv("../turbo-octo-goggles/data/state_data/geo_md.csv")
me_df.to_csv("../turbo-octo-goggles/data/state_data/geo_me.csv")  
mi_df.to_csv("../turbo-octo-goggles/data/state_data/geo_mi.csv") 
mn_df.to_csv("../turbo-octo-goggles/data/state_data/geo_mn.csv") 
mo_df.to_csv("../turbo-octo-goggles/data/state_data/geo_mo.csv")  
mp_df.to_csv("../turbo-octo-goggles/data/state_data/geo_mp.csv") 
ms_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ms.csv")
mt_df.to_csv("../turbo-octo-goggles/data/state_data/geo_mt.csv")
nc_df.to_csv("../turbo-octo-goggles/data/state_data/geo_nc.csv") 
nd_df.to_csv("../turbo-octo-goggles/data/state_data/geo_nd.csv")  
ne_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ne.csv")
nh_df.to_csv("../turbo-octo-goggles/data/state_data/geo_nh.csv")  
nj_df.to_csv("../turbo-octo-goggles/data/state_data/geo_nj.csv")
nm_df.to_csv("../turbo-octo-goggles/data/state_data/geo_nm.csv") 
nv_df.to_csv("../turbo-octo-goggles/data/state_data/geo_nv.csv")  
ny_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ny.csv")  
oh_df.to_csv("../turbo-octo-goggles/data/state_data/geo_oh.csv")
ok_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ok.csv") 
or_df.to_csv("../turbo-octo-goggles/data/state_data/geo_or.csv")  
pa_df.to_csv("../turbo-octo-goggles/data/state_data/geo_pa.csv")
pr_df.to_csv("../turbo-octo-goggles/data/state_data/geo_pr.csv")  
ri_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ri.csv") 
sc_df.to_csv("../turbo-octo-goggles/data/state_data/geo_sc.csv") 
sd_df.to_csv("../turbo-octo-goggles/data/state_data/geo_sd.csv") 
tn_df.to_csv("../turbo-octo-goggles/data/state_data/geo_tn.csv")  
tx_df.to_csv("../turbo-octo-goggles/data/state_data/geo_tx.csv")  
ut_df.to_csv("../turbo-octo-goggles/data/state_data/geo_ut.csv")  
va_df.to_csv("../turbo-octo-goggles/data/state_data/geo_va.csv")  
vi_df.to_csv("../turbo-octo-goggles/data/state_data/geo_vi.csv")  
vt_df.to_csv("../turbo-octo-goggles/data/state_data/geo_vt.csv")
wa_df.to_csv("../turbo-octo-goggles/data/state_data/geo_wa.csv")  
wi_df.to_csv("../turbo-octo-goggles/data/state_data/geo_wi.csv")  
wv_df.to_csv("../turbo-octo-goggles/data/state_data/geo_wv.csv") 
wy_df.to_csv("../turbo-octo-goggles/data/state_data/geo_wy.csv")
