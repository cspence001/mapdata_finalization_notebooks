# %%
import pandas as pd
import numpy as np
import os

# %%
ppp_hpgf = pd.read_csv("../../data/pipe_hpgf.csv")
ppp_hpgf.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0  LoanNumber                 HASHcodePM       Industry  \
# 0           0  3894287707  IND00SS00LR1JR1BT01BA1PPP  Not Available
# 1           1  3910757707  IND00SS00LR1JR1BT01BA1PPP  Not Available
# 2           2  4559867701  IND00SS00LR1JR1BT01BA1PPP  Not Available
# 3           3  4533907702  IND00SS00LR1JR1BT01BA1PPP  Not Available
# 4           4  9925367708  IND00SS00LR1JR1BT01BA1PPP  Not Available
#
#   IndustrySubsector DateApproved  SBAOfficeCode  \
# 0     Not Available       5/1/20            912
# 1     Not Available       5/1/20            914
# 2     Not Available       5/1/20            954
# 3     Not Available       5/1/20            920
# 4     Not Available       5/1/20            920
#
#                   SBAOfficeLabel ProcessingMethod  \
# 0  SAN FRANCISCO DISTRICT OFFICE              PPP
# 1    LOS ANGELES DISTRICT OFFICE              PPP
# 2      SAN DIEGO DISTRICT OFFICE              PPP
# 3      SANTA ANA DISTRICT OFFICE              PPP
# 4      SANTA ANA DISTRICT OFFICE              PPP
#
#                          BorrowerName  ... NonProfit ForgivenessAmount  \
# 0                         PHD UROLOGY  ...         N               NaN
# 1  DIGITAL GRAPHIC SERVICE CENTER INC  ...         N         159125.94
# 2          ANDREW M BLUMENFELD MD APC  ...         N               NaN
# 3      REVENUE MANAGEMENT CONSULTANTS  ...         N         161589.29
# 4           TVP GLOBAL SERVICES, INC.  ...         N         154087.67
#
#   ForgivenessDate  Estimated_LenderPercent  Estimated_LenderProfit  LongName  \
# 0             NaN                       5%                12069.30       NaN
# 1         6/11/21                       5%                 8790.00       NaN
# 2             NaN                       5%                 8383.35       NaN
# 3         8/20/21                       5%                 7976.75       NaN
# 4         5/21/21                       5%                 7625.00       NaN
#
#                                             full_add        Lat        Long  \
# 0      1240 S. ELISEO DRIVE SUITE 200, GREENBRAE, CA  37.944510 -122.535984
# 1               35440 THOMAS ROAD, SANTA CLARITA, CA  34.521182 -118.259663
# 2                    336 OCEAN VIEW AVE, DEL MAR, CA  32.942704 -117.260217
# 3  2040 SOUTH SANTA CRUZ STREET SUITE 240, ANAHEI...  33.797606 -117.894151
# 4                       1 YELLOWWOOD WAY, IRVINE, CA  33.658618 -117.822648
#
#          FIPS_z
# 0  6.041119e+13
# 1  6.037911e+13
# 2  6.073017e+13
# 3  6.059086e+13
# 4  6.059063e+13
#
# [5 rows x 37 columns]

# %%
ppp_hpgf['FIPS_z'].nunique()
# Out:
# 188291

# %%
hash_obj = ppp_hpgf['HASHcodePM'].unique()
for obj in hash_obj:
    outfilename = 'hash_obj/' + obj + '.csv'
    print(outfilename)
    ppp_hpgf[ppp_hpgf['HASHcodePM'] == obj].to_csv(outfilename)

# %%
va_hpgf = pd.read_csv("../../data/state_data/hash_states/hpgf_va.csv")
va_hpgf.tail()
# Out:
#        Unnamed: 0  LoanNumber                 HASHcodePM  \
# 23261      968226  1791167301  IND99SS00LR2JR5BT02BA2PPP
# 23262      968252  6923697705  IND99SS00LR2JR5BT01BA3PPP
# 23263      968524  7941517205  IND99SS00LR3JR8BT03BA2PPP
# 23264      968526  7115607707  IND99SS00LR4JR4BT01BA2PPP
# 23265      968529  6570227708  IND99SS00LR4JR6BT01BA2PPP
#
#                              Industry               IndustrySubsector  \
# 23261  Nonclassifiable Establishments  Nonclassifiable Establishments
# 23262  Nonclassifiable Establishments  Nonclassifiable Establishments
# 23263  Nonclassifiable Establishments  Nonclassifiable Establishments
# 23264  Nonclassifiable Establishments  Nonclassifiable Establishments
# 23265  Nonclassifiable Establishments  Nonclassifiable Establishments
#
#       DateApproved  SBAOfficeCode              SBAOfficeLabel  \
# 23261      4/28/20            304    RICHMOND DISTRICT OFFICE
# 23262       5/1/20            353  WASHINGTON DISTRICT OFFICE
# 23263      4/28/20            353  WASHINGTON DISTRICT OFFICE
# 23264       5/1/20            353  WASHINGTON DISTRICT OFFICE
# 23265       5/1/20            353  WASHINGTON DISTRICT OFFICE
#
#       ProcessingMethod              BorrowerName  ... NonProfit  \
# 23261              PPP      PRMC OPERATIONS, LLC  ...         N
# 23262              PPP  HOP & WINE BEVERAGE LLC.  ...         N
# 23263              PPP            PJ&AMP;HR, INC  ...         N
# 23264              PPP         PAPILLON AIR INC.  ...         N
# 23265              PPP                   NHM INC  ...         N
#
#       ForgivenessAmount ForgivenessDate  Estimated_LenderPercent  \
# 23261         428697.56         6/11/21                       3%
# 23262         951408.33         5/18/21                       3%
# 23263        1312681.64         6/23/21                       3%
# 23264               NaN             NaN                       1%
# 23265        2091707.47         8/19/21                       1%
#
#        Estimated_LenderProfit  LongName  \
# 23261                12719.10       NaN
# 23262                28248.00       NaN
# 23263                38937.00       NaN
# 23264                21267.53       NaN
# 23265                20658.42       NaN
#
#                                               full_add        Lat       Long  \
# 23261  4423 PHEASANT RIDGE ROAD SUITE 301, ROANOKE, VA  37.222562 -79.963779
# 23262      4605 BROOKFIELD CORPORATE DR, CHANTILLY, VA  38.880329 -77.448236
# 23263             3901 CENTERVIEW DRIVE, CHANTILLY, VA  38.897400 -77.430843
# 23264                     44728 MALDEN PL, ASHBURN, VA  39.040601 -77.452778
# 23265           9408 GUNSTON COVE RD STE E, LORTON, VA  38.702582 -77.223419
#
#              FIPS_z
# 23261  5.177000e+14
# 23262  5.105949e+14
# 23263  5.105948e+14
# 23264  5.110761e+14
# 23265  5.105942e+14
#
# [5 rows x 37 columns]

# %%
ind_slice_ = va_hpgf['HASHcodePM'].str[0:9] #298 /313
#ind_slice_ = va_hpgf['HASHcodePM'].str[0:9].nunique()
lr_slice_ = va_hpgf['HASHcodePM'].str[9:12] #5
jr_slice_ = va_hpgf['HASHcodePM'].str[12:15] #8
bt_slice_ = va_hpgf['HASHcodePM'].str[15:19] #19
ba_slice_ = va_hpgf['HASHcodePM'].str[19:22] #5
pm_slice_ = va_hpgf['HASHcodePM'].str[22:25] #2
#st_slice_ = va_hpgf['FIPS_z'].str[0:2].nunique()

print(ind_slice_)
print(lr_slice_)
print(jr_slice_)
print(bt_slice_)
print(ba_slice_)
print(pm_slice_)
#print(st_slice_)
# Out:
# 5
# 8
# 19
# 5
# 2

# %%
print(va_hpgf['HASHcodePM'].nunique())

# %%
hash_obj = va_hpgf['HASHcodePM'].str[0:9].unique()
for obj in hash_obj:
    outfilename = '../../data/state_data/hash_obj/va/' + obj + '.csv'
    print(outfilename)
    va_hpgf[va_hpgf['HASHcodePM'] == obj].to_csv(outfilename)
# Out:
# ../../data/state_data/hash_obj/va/IND00SS00.csv
# ../../data/state_data/hash_obj/va/IND11SS11.csv
# ../../data/state_data/hash_obj/va/IND11SS12.csv
# ../../data/state_data/hash_obj/va/IND11SS13.csv
# ../../data/state_data/hash_obj/va/IND11SS14.csv
# ../../data/state_data/hash_obj/va/IND11SS19.csv
# ../../data/state_data/hash_obj/va/IND11SS21.csv
# ../../data/state_data/hash_obj/va/IND11SS23.csv
# ../../data/state_data/hash_obj/va/IND11SS25.csv
# ../../data/state_data/hash_obj/va/IND11SS29.csv
# ../../data/state_data/hash_obj/va/IND11SS31.csv
# ../../data/state_data/hash_obj/va/IND11SS32.csv
# ../../data/state_data/hash_obj/va/IND11SS33.csv
# ../../data/state_data/hash_obj/va/IND11SS41.csv
# ../../data/state_data/hash_obj/va/IND11SS42.csv
# ../../data/state_data/hash_obj/va/IND11SS51.csv
# ../../data/state_data/hash_obj/va/IND11SS52.csv
# ../../data/state_data/hash_obj/va/IND11SS53.csv
# ../../data/state_data/hash_obj/va/IND21SS11.csv
# ../../data/state_data/hash_obj/va/IND21SS21.csv
# ../../data/state_data/hash_obj/va/IND21SS22.csv
# ../../data/state_data/hash_obj/va/IND21SS23.csv
# ../../data/state_data/hash_obj/va/IND21SS31.csv
# ../../data/state_data/hash_obj/va/IND22SS11.csv
# ../../data/state_data/hash_obj/va/IND22SS13.csv
# ../../data/state_data/hash_obj/va/IND23SS61.csv
# ../../data/state_data/hash_obj/va/IND23SS62.csv
# ../../data/state_data/hash_obj/va/IND23SS71.csv
# ../../data/state_data/hash_obj/va/IND23SS72.csv
# ../../data/state_data/hash_obj/va/IND23SS73.csv
# ../../data/state_data/hash_obj/va/IND23SS79.csv
# ../../data/state_data/hash_obj/va/IND23SS81.csv
# ../../data/state_data/hash_obj/va/IND23SS82.csv
# ../../data/state_data/hash_obj/va/IND23SS83.csv
# ../../data/state_data/hash_obj/va/IND23SS89.csv
# ../../data/state_data/hash_obj/va/IND31SS11.csv
# ../../data/state_data/hash_obj/va/IND31SS13.csv
# ../../data/state_data/hash_obj/va/IND31SS14.csv
# ../../data/state_data/hash_obj/va/IND31SS15.csv
# ../../data/state_data/hash_obj/va/IND31SS16.csv
# ../../data/state_data/hash_obj/va/IND31SS17.csv
# ../../data/state_data/hash_obj/va/IND31SS18.csv
# ../../data/state_data/hash_obj/va/IND31SS19.csv
# ../../data/state_data/hash_obj/va/IND31SS21.csv
# ../../data/state_data/hash_obj/va/IND31SS22.csv
# ../../data/state_data/hash_obj/va/IND31SS31.csv
# ../../data/state_data/hash_obj/va/IND31SS32.csv
# ../../data/state_data/hash_obj/va/IND31SS33.csv
# ../../data/state_data/hash_obj/va/IND31SS41.csv
# ../../data/state_data/hash_obj/va/IND31SS49.csv
# ../../data/state_data/hash_obj/va/IND31SS52.csv
# ../../data/state_data/hash_obj/va/IND31SS59.csv
# ../../data/state_data/hash_obj/va/IND31SS62.csv
# ../../data/state_data/hash_obj/va/IND31SS69.csv
# ../../data/state_data/hash_obj/va/IND32SS11.csv
# ../../data/state_data/hash_obj/va/IND32SS12.csv
# ../../data/state_data/hash_obj/va/IND32SS19.csv
# ../../data/state_data/hash_obj/va/IND32SS21.csv
# ../../data/state_data/hash_obj/va/IND32SS22.csv
# ../../data/state_data/hash_obj/va/IND32SS31.csv
# ../../data/state_data/hash_obj/va/IND32SS41.csv
# ../../data/state_data/hash_obj/va/IND32SS51.csv
# ../../data/state_data/hash_obj/va/IND32SS52.csv
# ../../data/state_data/hash_obj/va/IND32SS53.csv
# ../../data/state_data/hash_obj/va/IND32SS54.csv
# ../../data/state_data/hash_obj/va/IND32SS55.csv
# ../../data/state_data/hash_obj/va/IND32SS56.csv
# ../../data/state_data/hash_obj/va/IND32SS59.csv
# ../../data/state_data/hash_obj/va/IND32SS61.csv
# ../../data/state_data/hash_obj/va/IND32SS62.csv
# ../../data/state_data/hash_obj/va/IND32SS71.csv
# ../../data/state_data/hash_obj/va/IND32SS72.csv
# ../../data/state_data/hash_obj/va/IND32SS73.csv
# ../../data/state_data/hash_obj/va/IND32SS79.csv
# ../../data/state_data/hash_obj/va/IND33SS11.csv
# ../../data/state_data/hash_obj/va/IND33SS12.csv
# ../../data/state_data/hash_obj/va/IND33SS13.csv
# ../../data/state_data/hash_obj/va/IND33SS14.csv
# ../../data/state_data/hash_obj/va/IND33SS15.csv
# ../../data/state_data/hash_obj/va/IND33SS21.csv
# ../../data/state_data/hash_obj/va/IND33SS22.csv
# ../../data/state_data/hash_obj/va/IND33SS23.csv
# ../../data/state_data/hash_obj/va/IND33SS24.csv
# ../../data/state_data/hash_obj/va/IND33SS25.csv
# ../../data/state_data/hash_obj/va/IND33SS26.csv
# ../../data/state_data/hash_obj/va/IND33SS27.csv
# ../../data/state_data/hash_obj/va/IND33SS28.csv
# ../../data/state_data/hash_obj/va/IND33SS29.csv
# ../../data/state_data/hash_obj/va/IND33SS31.csv
# ../../data/state_data/hash_obj/va/IND33SS32.csv
# ../../data/state_data/hash_obj/va/IND33SS33.csv
# ../../data/state_data/hash_obj/va/IND33SS34.csv
# ../../data/state_data/hash_obj/va/IND33SS35.csv
# ../../data/state_data/hash_obj/va/IND33SS36.csv
# ../../data/state_data/hash_obj/va/IND33SS39.csv
# ../../data/state_data/hash_obj/va/IND33SS41.csv
# ../../data/state_data/hash_obj/va/IND33SS42.csv
# ../../data/state_data/hash_obj/va/IND33SS43.csv
# ../../data/state_data/hash_obj/va/IND33SS44.csv
# ../../data/state_data/hash_obj/va/IND33SS45.csv
# ../../data/state_data/hash_obj/va/IND33SS46.csv
# ../../data/state_data/hash_obj/va/IND33SS51.csv
# ../../data/state_data/hash_obj/va/IND33SS52.csv
# ../../data/state_data/hash_obj/va/IND33SS53.csv
# ../../data/state_data/hash_obj/va/IND33SS59.csv
# ../../data/state_data/hash_obj/va/IND33SS61.csv
# ../../data/state_data/hash_obj/va/IND33SS62.csv
# ../../data/state_data/hash_obj/va/IND33SS63.csv
# ../../data/state_data/hash_obj/va/IND33SS64.csv
# ../../data/state_data/hash_obj/va/IND33SS66.csv
# ../../data/state_data/hash_obj/va/IND33SS69.csv
# ../../data/state_data/hash_obj/va/IND33SS71.csv
# ../../data/state_data/hash_obj/va/IND33SS72.csv
# ../../data/state_data/hash_obj/va/IND33SS79.csv
# ../../data/state_data/hash_obj/va/IND33SS91.csv
# ../../data/state_data/hash_obj/va/IND33SS99.csv
# ../../data/state_data/hash_obj/va/IND42SS31.csv
# ../../data/state_data/hash_obj/va/IND42SS32.csv
# ../../data/state_data/hash_obj/va/IND42SS33.csv
# ../../data/state_data/hash_obj/va/IND42SS34.csv
# ../../data/state_data/hash_obj/va/IND42SS35.csv
# ../../data/state_data/hash_obj/va/IND42SS36.csv
# ../../data/state_data/hash_obj/va/IND42SS37.csv
# ../../data/state_data/hash_obj/va/IND42SS38.csv
# ../../data/state_data/hash_obj/va/IND42SS39.csv
# ../../data/state_data/hash_obj/va/IND42SS41.csv
# ../../data/state_data/hash_obj/va/IND42SS42.csv
# ../../data/state_data/hash_obj/va/IND42SS43.csv
# ../../data/state_data/hash_obj/va/IND42SS44.csv
# ../../data/state_data/hash_obj/va/IND42SS45.csv
# ../../data/state_data/hash_obj/va/IND42SS46.csv
# ../../data/state_data/hash_obj/va/IND42SS47.csv
# ../../data/state_data/hash_obj/va/IND42SS48.csv
# ../../data/state_data/hash_obj/va/IND42SS49.csv
# ../../data/state_data/hash_obj/va/IND42SS51.csv
# ../../data/state_data/hash_obj/va/IND44SS11.csv
# ../../data/state_data/hash_obj/va/IND44SS12.csv
# ../../data/state_data/hash_obj/va/IND44SS13.csv
# ../../data/state_data/hash_obj/va/IND44SS21.csv
# ../../data/state_data/hash_obj/va/IND44SS22.csv
# ../../data/state_data/hash_obj/va/IND44SS31.csv
# ../../data/state_data/hash_obj/va/IND44SS41.csv
# ../../data/state_data/hash_obj/va/IND44SS42.csv
# ../../data/state_data/hash_obj/va/IND44SS51.csv
# ../../data/state_data/hash_obj/va/IND44SS52.csv
# ../../data/state_data/hash_obj/va/IND44SS53.csv
# ../../data/state_data/hash_obj/va/IND44SS61.csv
# ../../data/state_data/hash_obj/va/IND44SS71.csv
# ../../data/state_data/hash_obj/va/IND44SS81.csv
# ../../data/state_data/hash_obj/va/IND44SS82.csv
# ../../data/state_data/hash_obj/va/IND44SS83.csv
# ../../data/state_data/hash_obj/va/IND45SS11.csv
# ../../data/state_data/hash_obj/va/IND45SS12.csv
# ../../data/state_data/hash_obj/va/IND45SS23.csv
# ../../data/state_data/hash_obj/va/IND45SS31.csv
# ../../data/state_data/hash_obj/va/IND45SS32.csv
# ../../data/state_data/hash_obj/va/IND45SS33.csv
# ../../data/state_data/hash_obj/va/IND45SS39.csv
# ../../data/state_data/hash_obj/va/IND45SS41.csv
# ../../data/state_data/hash_obj/va/IND45SS42.csv
# ../../data/state_data/hash_obj/va/IND45SS43.csv
# ../../data/state_data/hash_obj/va/IND48SS11.csv
# ../../data/state_data/hash_obj/va/IND48SS12.csv
# ../../data/state_data/hash_obj/va/IND48SS21.csv
# ../../data/state_data/hash_obj/va/IND48SS31.csv
# ../../data/state_data/hash_obj/va/IND48SS32.csv
# ../../data/state_data/hash_obj/va/IND48SS41.csv
# ../../data/state_data/hash_obj/va/IND48SS42.csv
# ../../data/state_data/hash_obj/va/IND48SS51.csv
# ../../data/state_data/hash_obj/va/IND48SS52.csv
# ../../data/state_data/hash_obj/va/IND48SS53.csv
# ../../data/state_data/hash_obj/va/IND48SS54.csv
# ../../data/state_data/hash_obj/va/IND48SS55.csv
# ../../data/state_data/hash_obj/va/IND48SS59.csv
# ../../data/state_data/hash_obj/va/IND48SS69.csv
# ../../data/state_data/hash_obj/va/IND48SS71.csv
# ../../data/state_data/hash_obj/va/IND48SS79.csv
# ../../data/state_data/hash_obj/va/IND48SS81.csv
# ../../data/state_data/hash_obj/va/IND48SS82.csv
# ../../data/state_data/hash_obj/va/IND48SS83.csv
# ../../data/state_data/hash_obj/va/IND48SS84.csv
# ../../data/state_data/hash_obj/va/IND48SS85.csv
# ../../data/state_data/hash_obj/va/IND48SS89.csv
# ../../data/state_data/hash_obj/va/IND49SS11.csv
# ../../data/state_data/hash_obj/va/IND49SS21.csv
# ../../data/state_data/hash_obj/va/IND49SS22.csv
# ../../data/state_data/hash_obj/va/IND49SS31.csv
# ../../data/state_data/hash_obj/va/IND51SS11.csv
# ../../data/state_data/hash_obj/va/IND51SS12.csv
# ../../data/state_data/hash_obj/va/IND51SS21.csv
# ../../data/state_data/hash_obj/va/IND51SS22.csv
# ../../data/state_data/hash_obj/va/IND51SS51.csv
# ../../data/state_data/hash_obj/va/IND51SS52.csv
# ../../data/state_data/hash_obj/va/IND51SS73.csv
# ../../data/state_data/hash_obj/va/IND51SS74.csv
# ../../data/state_data/hash_obj/va/IND51SS79.csv
# ../../data/state_data/hash_obj/va/IND51SS82.csv
# ../../data/state_data/hash_obj/va/IND51SS91.csv
# ../../data/state_data/hash_obj/va/IND52SS22.csv
# ../../data/state_data/hash_obj/va/IND52SS23.csv
# ../../data/state_data/hash_obj/va/IND52SS31.csv
# ../../data/state_data/hash_obj/va/IND52SS32.csv
# ../../data/state_data/hash_obj/va/IND52SS39.csv
# ../../data/state_data/hash_obj/va/IND52SS41.csv
# ../../data/state_data/hash_obj/va/IND52SS42.csv
# ../../data/state_data/hash_obj/va/IND52SS51.csv
# ../../data/state_data/hash_obj/va/IND52SS59.csv
# ../../data/state_data/hash_obj/va/IND53SS11.csv
# ../../data/state_data/hash_obj/va/IND53SS12.csv
# ../../data/state_data/hash_obj/va/IND53SS13.csv
# ../../data/state_data/hash_obj/va/IND53SS21.csv
# ../../data/state_data/hash_obj/va/IND53SS22.csv
# ../../data/state_data/hash_obj/va/IND53SS23.csv
# ../../data/state_data/hash_obj/va/IND53SS24.csv
# ../../data/state_data/hash_obj/va/IND53SS31.csv
# ../../data/state_data/hash_obj/va/IND54SS11.csv
# ../../data/state_data/hash_obj/va/IND54SS12.csv
# ../../data/state_data/hash_obj/va/IND54SS13.csv
# ../../data/state_data/hash_obj/va/IND54SS14.csv
# ../../data/state_data/hash_obj/va/IND54SS15.csv
# ../../data/state_data/hash_obj/va/IND54SS16.csv
# ../../data/state_data/hash_obj/va/IND54SS17.csv
# ../../data/state_data/hash_obj/va/IND54SS18.csv
# ../../data/state_data/hash_obj/va/IND54SS19.csv
# ../../data/state_data/hash_obj/va/IND55SS11.csv
# ../../data/state_data/hash_obj/va/IND56SS11.csv
# ../../data/state_data/hash_obj/va/IND56SS12.csv
# ../../data/state_data/hash_obj/va/IND56SS13.csv
# ../../data/state_data/hash_obj/va/IND56SS14.csv
# ../../data/state_data/hash_obj/va/IND56SS15.csv
# ../../data/state_data/hash_obj/va/IND56SS16.csv
# ../../data/state_data/hash_obj/va/IND56SS17.csv
# ../../data/state_data/hash_obj/va/IND56SS19.csv
# ../../data/state_data/hash_obj/va/IND56SS21.csv
# ../../data/state_data/hash_obj/va/IND56SS22.csv
# ../../data/state_data/hash_obj/va/IND56SS29.csv
# ../../data/state_data/hash_obj/va/IND61SS11.csv
# ../../data/state_data/hash_obj/va/IND61SS13.csv
# ../../data/state_data/hash_obj/va/IND61SS14.csv
# ../../data/state_data/hash_obj/va/IND61SS15.csv
# ../../data/state_data/hash_obj/va/IND61SS16.csv
# ../../data/state_data/hash_obj/va/IND61SS17.csv
# ../../data/state_data/hash_obj/va/IND62SS11.csv
# ../../data/state_data/hash_obj/va/IND62SS12.csv
# ../../data/state_data/hash_obj/va/IND62SS13.csv
# ../../data/state_data/hash_obj/va/IND62SS14.csv
# ../../data/state_data/hash_obj/va/IND62SS15.csv
# ../../data/state_data/hash_obj/va/IND62SS16.csv
# ../../data/state_data/hash_obj/va/IND62SS19.csv
# ../../data/state_data/hash_obj/va/IND62SS21.csv
# ../../data/state_data/hash_obj/va/IND62SS22.csv
# ../../data/state_data/hash_obj/va/IND62SS23.csv
# ../../data/state_data/hash_obj/va/IND62SS31.csv
# ../../data/state_data/hash_obj/va/IND62SS32.csv
# ../../data/state_data/hash_obj/va/IND62SS33.csv
# ../../data/state_data/hash_obj/va/IND62SS39.csv
# ../../data/state_data/hash_obj/va/IND62SS41.csv
# ../../data/state_data/hash_obj/va/IND62SS42.csv
# ../../data/state_data/hash_obj/va/IND62SS43.csv
# ../../data/state_data/hash_obj/va/IND62SS44.csv
# ../../data/state_data/hash_obj/va/IND71SS11.csv
# ../../data/state_data/hash_obj/va/IND71SS12.csv
# ../../data/state_data/hash_obj/va/IND71SS13.csv
# ../../data/state_data/hash_obj/va/IND71SS14.csv
# ../../data/state_data/hash_obj/va/IND71SS15.csv
# ../../data/state_data/hash_obj/va/IND71SS21.csv
# ../../data/state_data/hash_obj/va/IND71SS31.csv
# ../../data/state_data/hash_obj/va/IND71SS32.csv
# ../../data/state_data/hash_obj/va/IND71SS39.csv
# ../../data/state_data/hash_obj/va/IND72SS11.csv
# ../../data/state_data/hash_obj/va/IND72SS12.csv
# ../../data/state_data/hash_obj/va/IND72SS13.csv
# ../../data/state_data/hash_obj/va/IND72SS23.csv
# ../../data/state_data/hash_obj/va/IND72SS24.csv
# ../../data/state_data/hash_obj/va/IND72SS25.csv
# ../../data/state_data/hash_obj/va/IND81SS11.csv
# ../../data/state_data/hash_obj/va/IND81SS12.csv
# ../../data/state_data/hash_obj/va/IND81SS13.csv
# ../../data/state_data/hash_obj/va/IND81SS14.csv
# ../../data/state_data/hash_obj/va/IND81SS21.csv
# ../../data/state_data/hash_obj/va/IND81SS22.csv
# ../../data/state_data/hash_obj/va/IND81SS23.csv
# ../../data/state_data/hash_obj/va/IND81SS29.csv
# ../../data/state_data/hash_obj/va/IND81SS31.csv
# ../../data/state_data/hash_obj/va/IND81SS32.csv
# ../../data/state_data/hash_obj/va/IND81SS33.csv
# ../../data/state_data/hash_obj/va/IND81SS34.csv
# ../../data/state_data/hash_obj/va/IND81SS39.csv
# ../../data/state_data/hash_obj/va/IND81SS41.csv
# ../../data/state_data/hash_obj/va/IND92SS11.csv
# ../../data/state_data/hash_obj/va/IND92SS21.csv
# ../../data/state_data/hash_obj/va/IND92SS31.csv
# ../../data/state_data/hash_obj/va/IND92SS41.csv
# ../../data/state_data/hash_obj/va/IND92SS51.csv
# ../../data/state_data/hash_obj/va/IND92SS61.csv
# ../../data/state_data/hash_obj/va/IND92SS71.csv
# ../../data/state_data/hash_obj/va/IND92SS81.csv
# ../../data/state_data/hash_obj/va/IND99SS00.csv

# %%
#ppp_hpgf_states = pd.read_csv("../../data/state_data/hash_states/")
path = "../../data/state_data/hash_states/" 
filelist = os.listdir(path)     #All of my .csv files I am working with
file_count = len(filelist) 
for file in filelist:
    df = pd.read_csv(file)
    hash_obj = df['HASHcodePM'].unique()
    for obj in hash_obj:
        outfilename = 'hash_obj/' + obj + '.csv'
        print(outfilename)
        ppp_hpgf[ppp_hpgf['HASHcodePM'] == obj].to_csv(outfilename)
