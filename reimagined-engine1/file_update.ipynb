# %%
import pandas as pd

# %%
csv_path = "data/raw/>150K/public_150k_plus_211121_add.csv"
csv_path_update = "data/raw/>150K/public_150k_plus_220102.csv"
csv_raw = "data/raw/>150K/public_150k_plus_211121.csv"

# %%
df1 = pd.read_csv(csv_path)
df2 = pd.read_csv(csv_path_update)
df3 = pd.read_csv(csv_raw)

# %%
df1
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9547507704       5/1/20            464              PPP
# 1       9777677704       5/1/20            464              PPP
# 2       5791407702       5/1/20           1013              PPP
# 3       6223567700       5/1/20            920              PPP
# 4       9662437702       5/1/20            101              PPP
# ...            ...          ...            ...              ...
# 968552  4395967002       4/3/20            897              PPP
# 968553  6985647108      4/14/20            897              PPP
# 968554  7996438405      2/12/21            897              PPS
# 968555  9054647103      4/15/20            897              PPP
# 968556  9184687004       4/9/20            897              PPP
#
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# ...

# %%
df2["NA"] = df2["NAICSCode"].astype(str).str[:2]
df2
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9547507704   05/01/2020            464              PPP
# 1       9777677704   05/01/2020            464              PPP
# 2       5791407702   05/01/2020           1013              PPP
# 3       6223567700   05/01/2020            920              PPP
# 4       9662437702   05/01/2020            101              PPP
# ...            ...          ...            ...              ...
# 968533  4395967002   04/03/2020            897              PPP
# 968534  6985647108   04/14/2020            897              PPP
# 968535  7996438405   02/12/2021            897              PPS
# 968536  9054647103   04/15/2020            897              PPP
# 968537  9184687004   04/09/2020            897              PPP
#
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# ...

# %%
df3["NA"] = df3["NAICSCode"].astype(str).str[:2]
df3
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9547507704       5/1/20            464              PPP
# 1       9777677704       5/1/20            464              PPP
# 2       5791407702       5/1/20           1013              PPP
# 3       6223567700       5/1/20            920              PPP
# 4       9662437702       5/1/20            101              PPP
# ...            ...          ...            ...              ...
# 968552  4395967002       4/3/20            897              PPP
# 968553  6985647108      4/14/20            897              PPP
# 968554  7996438405      2/12/21            897              PPS
# 968555  9054647103      4/15/20            897              PPP
# 968556  9184687004       4/9/20            897              PPP
#
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# ...

# %% [markdown]
# https://stackoverflow.com/questions/17095101/compare-two-dataframes-and-output-their-differences-side-by-side <br>
# https://stackoverflow.com/questions/18548370/pandas-can-only-compare-identically-labeled-dataframe-objects-error
