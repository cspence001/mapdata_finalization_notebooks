# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# <b>PIPE

# %%
ppp_pipe = pd.read_csv("data/ppp_pipe.csv")
ppp_pipe.head()
ppp_pipe.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'LoanNumber', 'DateApproved',
#        'SBAOfficeCode', 'ProcessingMethod', 'BorrowerName', 'BorrowerAddress',
#        'BorrowerCity', 'BorrowerState', 'BorrowerZip', 'LoanStatusDate',
#        'LoanStatus', 'Term', 'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
#        'DEBT_INTEREST_PROCEED', 'BusinessType', 'OriginatingLenderLocationID',
#        'OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
#        'Gender', 'Veteran', 'NonProfit', 'ForgivenessAmount',
#        'ForgivenessDate', 'Estimated_LenderPercent', 'Estimated_LenderProfit',
#        'DateApproved_ts', 'ForgivenessDate_ts', 'LongName',
#        'TRIIndustrySector', 'IndustrySubsector', '4DigitNAICS', 'NA',
#        'Industry', 'SBAOfficeLabel', 'Loan_Range', 'job_Range', 'full_add'],
#       dtype='object')

# %%
#ppp_pipe['ServicingLenderLocationID'].nunique()#can haave option to display markers for servicing lender, radius by $
#ppp_pipe['TRIIndustrySector'].value_counts() #Alternate display by

# %% [markdown]
# Determining Necessary Columns for Final DataFrame

# %%
#keep track of columns removed
dele = ['Unnamed: 0', 'BorrowerAddress', 'BorrowerCity', 'BorrowerZip', 'SBAGuarantyPercentage', 'InitialApprovalAmount', 'RuralUrbanIndicator', 'HubzoneIndicator',  'LMIIndicator', 
 'BusinessAgeDescription', 'ProjectCity','ProjectCountyName', 'ProjectState', 'ProjectZip','Race', 'Ethnicity', 'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState', 'ServicingLenderZip', 
 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'DateApproved_ts', 'ForgivenessDate_ts',
 'HEALTH_CARE_PROCEED','DEBT_INTEREST_PROCEED', 'NA', '4DigitNAICS', 'NAICSCode', 'Industry', 'IndustrySubsector', 'TRIIndustrySector', 'Loan_Range', 'job_Range', 'Gender', 'Veteran']
#Industry and Industry Subsector taken from HASH file 
cols =['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'SBAOfficeLabel','ProcessingMethod', 'BorrowerName', 
       'BorrowerState', 'LoanStatusDate', 'LoanStatus', 'Term', 'CurrentApprovalAmount', 'UndisbursedAmount', 
       'FranchiseName','ServicingLenderLocationID', 'ServicingLenderName', 
       'CD', 'JobsReported', 'OriginatingLenderLocationID', 'OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
       'BusinessType', 'BusinessAgeDescription', 'NonProfit', 'ForgivenessAmount', 'ForgivenessDate', 'Estimated_LenderPercent', 'Estimated_LenderProfit', 
       'LongName', 'full_add']

ppp_pipe = ppp_pipe[cols]
ppp_pipe.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode                  SBAOfficeLabel  \
# 0  9547507704       5/1/20            464  SOUTH CAROLINA DISTRICT OFFICE
# 1  9777677704       5/1/20            464  SOUTH CAROLINA DISTRICT OFFICE
# 2  5791407702       5/1/20           1013         SEATTLE DISTRICT OFFICE
# 3  6223567700       5/1/20            920       SANTA ANA DISTRICT OFFICE
# 4  9662437702       5/1/20            101   MASSACHUSETTS DISTRICT OFFICE
#
#   ProcessingMethod              BorrowerName BorrowerState LoanStatusDate  \
# 0              PPP     SUMTER COATINGS, INC.            SC       12/18/20
# 1              PPP     PLEASANT PLACES, INC.            SC        9/28/21
# 2              PPP   BOYER CHILDREN'S CLINIC            WA        3/17/21
# 3              PPP  KIRTLEY CONSTRUCTION INC            CA       10/16/21
# 4              PPP              AERO BOX LLC            MI        8/17/21
#
#      LoanStatus  Term  ...  OriginatingLenderState             BusinessType  \
# 0  Paid in Full    24  ...                      GA              Corporation
# 1  Paid in Full    24  ...                      GA      Sole Proprietorship
# 2  Paid in Full    24  ...                      NC  Non-Profit Organization
# 3  Paid in Full    24  ...                      NC              Corporation
# 4  Paid in Full    24  ...                      OH            Not Available
#
#               BusinessAgeDescription  NonProfit ForgivenessAmount  \
# 0  Existing or more than 2 years old          N         773553.37
# 1  Existing or more than 2 years old          N         746336.24
# 2    New Business or 2 years or less          Y         696677.49
# 3    New Business or 2 years or less          N         395264.11
# 4                         Unanswered          N         370819.35
#
#   ForgivenessDate  Estimated_LenderPercent  Estimated_LenderProfit  \
# 0        11/20/20                       3%              23080.7634
# 1         8/12/21                       3%              22107.8337
# 2         2/10/21                       3%              20740.6500
# 3         9/10/21                       3%              14996.1300
# 4          4/8/21                       3%              11023.1100
#
#                                             LongName  \
# 0                    Paint and Coating Manufacturing
# 1                               Landscaping Services
# 2                                                NaN
# 3  New Single-Family Housing Construction (except...
# 4             Used Household and Office Goods Moving
#
#                                     full_add
# 0          2410 Highway 15 South, Sumter, SC
# 1  7684 Southrail Road, North Charleston, SC
# 2              1850 BOYER AVE E, SEATTLE, WA
# 3   1661 MARTIN RANCH RD, SAN BERNARDINO, CA
# 4          20101 Cornillie Dr, Roseville, MI
#
# [5 rows x 30 columns]

# %% [markdown]
# <b>GEO

# %%
#ppp_geo = pd.read_csv("data/state_data/geo/ppp_geo.csv")
#cols = ["LoanNumber", "Lat", "Long"]
#ppp_geo = ppp_geo[cols]
#ppp_geo.head()

# %% [markdown]
# <b>HASH file addition

# %%
ppp_hash = pd.read_csv("data/ppp_hashSort.csv")
cols = ["LoanNumber", "HASHcodePM", "Industry", "IndustrySubsector"]
ppp_hash = ppp_hash[cols]
ppp_hash
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
#                      IndustrySubsector
# 0                        Not Available
# 1                        Not Available
# 2                        Not Available
# 3                        Not Available
# 4                        Not Available
# ...                                ...
# 968552  Nonclassifiable Establishments
# 968553  Nonclassifiable Establishments
# 968554  Nonclassifiable Establishments
# 968555  Nonclassifiable Establishments
# 968556  Nonclassifiable Establishments
#
# [968557 rows x 4 columns]

# %% [markdown]
# <b>FIPS file addition

# %%
ppp_fips_ak = pd.read_csv("data/state_data/geo/geo_fips/AK_fips_scraped.csv")
ppp_fips_al = pd.read_csv("data/state_data/geo/geo_fips/AL_fips_scraped.csv")
ppp_fips_ar = pd.read_csv("data/state_data/geo/geo_fips/AR_fips_scraped.csv")
ppp_fips_az = pd.read_csv("data/state_data/geo/geo_fips/AZ_fips_scraped.csv")

ppp_fips_ca = pd.read_csv("data/state_data/geo/geo_fips/CA_fips_scraped.csv")
ppp_fips_ct = pd.read_csv("data/state_data/geo/geo_fips/CT_fips_scraped.csv")
ppp_fips_dc = pd.read_csv("data/state_data/geo/geo_fips/DC_fips_scraped.csv")
ppp_fips_de = pd.read_csv("data/state_data/geo/geo_fips/DE_fips_scraped.csv")
ppp_fips_ga = pd.read_csv("data/state_data/geo/geo_fips/GA_fips_scraped.csv")
ppp_fips_il = pd.read_csv("data/state_data/geo/geo_fips/IL_fips_scraped.csv")
ppp_fips_ky = pd.read_csv("data/state_data/geo/geo_fips/KY_fips_scraped.csv")

ppp_fips_ma = pd.read_csv("data/state_data/geo/geo_fips/MA_fips_scraped.csv")
ppp_fips_md = pd.read_csv("data/state_data/geo/geo_fips/MD_fips_scraped.csv")
ppp_fips_me = pd.read_csv("data/state_data/geo/geo_fips/ME_fips_scraped.csv")
ppp_fips_nc = pd.read_csv("data/state_data/geo/geo_fips/NC_fips_scraped.csv")
ppp_fips_nh = pd.read_csv("data/state_data/geo/geo_fips/NH_fips_scraped.csv") 
ppp_fips_nj = pd.read_csv("data/state_data/geo/geo_fips/NJ_fips_scraped.csv")
ppp_fips_oh = pd.read_csv("data/state_data/geo/geo_fips/OH_fips_scraped.csv")
ppp_fips_pa = pd.read_csv("data/state_data/geo/geo_fips/PA_fips_scraped.csv")

ppp_fips_tn = pd.read_csv("data/state_data/geo/geo_fips/TN_fips_scraped.csv")
ppp_fips_vt = pd.read_csv("data/state_data/geo/geo_fips/VT_fips_scraped.csv")
ppp_fips_wv = pd.read_csv("data/state_data/geo/geo_fips/WV_fips_scraped.csv")
ppp_fips_va = pd.read_csv("data/state_data/geo/geo_fips/VA_fips_scraped.csv")

# %%
#get FIPS, LoanNumber from each file
cols= ["LoanNumber", "Lat", "Long", "FIPS_z"]

ppp_fips_ak = ppp_fips_ak[cols]
ppp_fips_al = ppp_fips_al[cols]
ppp_fips_ar = ppp_fips_ar[cols]
ppp_fips_az = ppp_fips_az[cols]

ppp_fips_ca = ppp_fips_ca[cols]
ppp_fips_ct = ppp_fips_ct[cols]
ppp_fips_dc = ppp_fips_dc[cols]
ppp_fips_de = ppp_fips_de[cols]
ppp_fips_ga = ppp_fips_ga[cols]
ppp_fips_il = ppp_fips_il[cols]
ppp_fips_ky = ppp_fips_ky[cols]

ppp_fips_ma = ppp_fips_ma[cols]
ppp_fips_md = ppp_fips_md[cols]
ppp_fips_me = ppp_fips_me[cols]
ppp_fips_nc = ppp_fips_nc[cols]
ppp_fips_nh = ppp_fips_nh[cols]
ppp_fips_nj = ppp_fips_nj[cols]
ppp_fips_oh = ppp_fips_oh[cols]
ppp_fips_pa = ppp_fips_pa[cols]

ppp_fips_tn = ppp_fips_tn[cols]
ppp_fips_vt = ppp_fips_vt[cols]
ppp_fips_wv = ppp_fips_wv[cols]
ppp_fips_va = ppp_fips_va[cols] 

frames = [ppp_fips_ak, ppp_fips_al, ppp_fips_ar, ppp_fips_az, 
ppp_fips_ca, ppp_fips_ct, ppp_fips_dc, ppp_fips_de, ppp_fips_ga, ppp_fips_il, ppp_fips_ky, 
ppp_fips_ma, ppp_fips_md, ppp_fips_me, ppp_fips_nc, ppp_fips_nh, ppp_fips_nj, ppp_fips_oh, ppp_fips_pa, 
ppp_fips_tn, ppp_fips_vt, ppp_fips_wv, ppp_fips_va]

result = pd.concat(frames)
result
# Out:
#        LoanNumber        Lat        Long        FIPS_z
# 0      5502308207  61.174949 -149.888309  2.020002e+13
# 1      6110847106  71.297290 -156.728897  2.185000e+13
# 2      4539098204  61.173232 -149.972718  2.020002e+13
# 3      5120868804  61.173164 -149.893283  2.020003e+13
# 4      6650277102  59.652704 -151.549793  2.122001e+13
# ...           ...        ...         ...           ...
# 23263  9512327001  37.371059  -79.194838  5.168000e+14
# 23264  9677417002  38.406665  -78.913133  5.116501e+14
# 23265  9715167306  38.761194  -77.454184  5.168391e+14
# 23266  9767568404  37.022287  -76.319882  5.165001e+14
# 23267  9872047407  38.823017  -77.057818  5.151020e+14
#
# [488994 rows x 4 columns]

# %% [markdown]
# Merged DataFrame

# %%
#merge 
ppp_hash_pipe = ppp_hash.merge(ppp_pipe, on="LoanNumber", how="left")
#ppp_hash_pipe_geo = ppp_hash_pipe.merge(ppp_geo, on="LoanNumber", how="left")
ppp_hash_pipe
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
#                      IndustrySubsector DateApproved  SBAOfficeCode  \
# 0                        Not Available       5/1/20            912
# 1                        Not Available       5/1/20            914
# 2                        Not Available       5/1/20            954
# 3                        Not Available       5/1/20            920
# 4                        Not Available       5/1/20            920
# ...                                ...          ...            ...
# 968552  Nonclassifiable Establishments      4/11/20            610
# 968553  Nonclassifiable Establishments       5/1/20           1013
# 968554  Nonclassifiable Establishments      4/14/20            455
# 968555  Nonclassifiable Establishments       5/1/20            455
# 968556  Nonclassifiable Establishments       5/1/20            944
#
#                            SBAOfficeLabel ProcessingMethod  \
# 0           SAN FRANCISCO DISTRICT OFFICE              PPP
# 1             LOS ANGELES DISTRICT OFFICE              PPP
# 2               SAN DIEGO DISTRICT OFFICE              PPP
# 3               SANTA ANA DISTRICT OFFICE              PPP
# 4               SANTA ANA DISTRICT OFFICE              PPP
# ...                                   ...              ...
# 968552  DALLAS / FT WORTH DISTRICT OFFICE              PPP
# 968553            SEATTLE DISTRICT OFFICE              PPP
# 968554      SOUTH FLORIDA DISTRICT OFFICE              PPP
# 968555      SOUTH FLORIDA DISTRICT OFFICE              PPP
# 968556             NEVADA DISTRICT OFFICE              PPP
#
#                               BorrowerName BorrowerState  ...  \
# 0                              PHD UROLOGY            CA  ...
# 1       DIGITAL GRAPHIC SERVICE CENTER INC            CA  ...
# 2               ANDREW M BLUMENFELD MD APC            CA  ...
# 3           REVENUE MANAGEMENT CONSULTANTS            CA  ...
# 4                TVP GLOBAL SERVICES, INC.            CA  ...
# ...                                    ...           ...  ...
# 968552                      ASTROCHEF, LLC            TX  ...
# 968553               UW PHYSICIANS NETWORK            WA  ...
# 968554  PHASE THREE STAR, LLC DBA HARDEE'S            FL  ...
# 968555                   KNA SOLUTIONS LLC            FL  ...
# 968556               SILVER STATE BELL LLC            NV  ...
#
#        OriginatingLenderState                    BusinessType  \
# 0                          SD                     Corporation
# 1                          SD                     Corporation
# 2                          SD                     Corporation
# 3                          SD                     Corporation
# 4                          CA                     Corporation
# ...                       ...                             ...
# 968552                     CA  Limited Liability Company(LLC)
# 968553                     NC         Non-Profit Organization
# 968554                     MS  Limited Liability Company(LLC)
# 968555                     NC  Limited Liability Company(LLC)
# 968556                     NC  Limited Liability Company(LLC)
#
#                    BusinessAgeDescription  NonProfit  ForgivenessAmount  \
# 0       Existing or more than 2 years old          N                NaN
# 1       Existing or more than 2 years old          N          159125.94
# 2       Existing or more than 2 years old          N                NaN
# 3       Existing or more than 2 years old          N          161589.29
# 4       Existing or more than 2 years old          N          154087.67
# ...                                   ...        ...                ...
# 968552  Existing or more than 2 years old          N                NaN
# 968553    New Business or 2 years or less          Y         5366395.05
# 968554  Existing or more than 2 years old          N         6362785.00
# 968555    New Business or 2 years or less          N                NaN
# 968556    New Business or 2 years or less          N         6600200.69
#
#        ForgivenessDate  Estimated_LenderPercent Estimated_LenderProfit  \
# 0                  NaN                       5%               12069.30
# 1              6/11/21                       5%                8790.00
# 2                  NaN                       5%                8383.35
# 3              8/20/21                       5%                7976.75
# 4              5/21/21                       5%                7625.00
# ...                ...                      ...                    ...
# 968552             NaN                       1%               55527.49
# 968553         9/20/21                       1%               52934.47
# 968554         6/23/21                       1%               62920.00
# 968555             NaN                       1%               84989.77
# 968556         6/18/21                       1%               65268.85
#
#        LongName                                           full_add
# 0           NaN      1240 S. ELISEO DRIVE SUITE 200, GREENBRAE, CA
# 1           NaN               35440 THOMAS ROAD, SANTA CLARITA, CA
# 2           NaN                    336 OCEAN VIEW AVE, DEL MAR, CA
# 3           NaN  2040 SOUTH SANTA CRUZ STREET SUITE 240, ANAHEI...
# 4           NaN                       1 YELLOWWOOD WAY, IRVINE, CA
# ...         ...                                                ...
# 968552      NaN                   1635 Innovation Dr, ROCKWALL, TX
# 968553      NaN               1100 NE 45th St Ste 500, Seattle, WA
# 968554      NaN                     4029 HENDERSON BLVD, TAMPA, FL
# 968555      NaN               11031 WATERCREST CIR W, PARKLAND, FL
# 968556      NaN        3225A S Rainbow Blvd Ste 102, Las Vegas, NV
#
# [968557 rows x 33 columns]

# %%
ppp_hpgf = ppp_hash_pipe.merge(result, on="LoanNumber", how="left")
ppp_hpgf
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
#                      IndustrySubsector DateApproved  SBAOfficeCode  \
# 0                        Not Available       5/1/20            912
# 1                        Not Available       5/1/20            914
# 2                        Not Available       5/1/20            954
# 3                        Not Available       5/1/20            920
# 4                        Not Available       5/1/20            920
# ...                                ...          ...            ...
# 968552  Nonclassifiable Establishments      4/11/20            610
# 968553  Nonclassifiable Establishments       5/1/20           1013
# 968554  Nonclassifiable Establishments      4/14/20            455
# 968555  Nonclassifiable Establishments       5/1/20            455
# 968556  Nonclassifiable Establishments       5/1/20            944
#
#                            SBAOfficeLabel ProcessingMethod  \
# 0           SAN FRANCISCO DISTRICT OFFICE              PPP
# 1             LOS ANGELES DISTRICT OFFICE              PPP
# 2               SAN DIEGO DISTRICT OFFICE              PPP
# 3               SANTA ANA DISTRICT OFFICE              PPP
# 4               SANTA ANA DISTRICT OFFICE              PPP
# ...                                   ...              ...
# 968552  DALLAS / FT WORTH DISTRICT OFFICE              PPP
# 968553            SEATTLE DISTRICT OFFICE              PPP
# 968554      SOUTH FLORIDA DISTRICT OFFICE              PPP
# 968555      SOUTH FLORIDA DISTRICT OFFICE              PPP
# 968556             NEVADA DISTRICT OFFICE              PPP
#
#                               BorrowerName BorrowerState  ... NonProfit  \
# 0                              PHD UROLOGY            CA  ...         N
# 1       DIGITAL GRAPHIC SERVICE CENTER INC            CA  ...         N
# 2               ANDREW M BLUMENFELD MD APC            CA  ...         N
# 3           REVENUE MANAGEMENT CONSULTANTS            CA  ...         N
# 4                TVP GLOBAL SERVICES, INC.            CA  ...         N
# ...                                    ...           ...  ...       ...
# 968552                      ASTROCHEF, LLC            TX  ...         N
# 968553               UW PHYSICIANS NETWORK            WA  ...         Y
# 968554  PHASE THREE STAR, LLC DBA HARDEE'S            FL  ...         N
# 968555                   KNA SOLUTIONS LLC            FL  ...         N
# 968556               SILVER STATE BELL LLC            NV  ...         N
#
#        ForgivenessAmount  ForgivenessDate  Estimated_LenderPercent  \
# 0                    NaN              NaN                       5%
# 1              159125.94          6/11/21                       5%
# 2                    NaN              NaN                       5%
# 3              161589.29          8/20/21                       5%
# 4              154087.67          5/21/21                       5%
# ...                  ...              ...                      ...
# 968552               NaN              NaN                       1%
# 968553        5366395.05          9/20/21                       1%
# 968554        6362785.00          6/23/21                       1%
# 968555               NaN              NaN                       1%
# 968556        6600200.69          6/18/21                       1%
#
#         Estimated_LenderProfit LongName  \
# 0                     12069.30      NaN
# 1                      8790.00      NaN
# 2                      8383.35      NaN
# 3                      7976.75      NaN
# 4                      7625.00      NaN
# ...                        ...      ...
# 968552                55527.49      NaN
# 968553                52934.47      NaN
# 968554                62920.00      NaN
# 968555                84989.77      NaN
# 968556                65268.85      NaN
#
#                                                  full_add        Lat  \
# 0           1240 S. ELISEO DRIVE SUITE 200, GREENBRAE, CA  37.944510
# 1                    35440 THOMAS ROAD, SANTA CLARITA, CA  34.521182
# 2                         336 OCEAN VIEW AVE, DEL MAR, CA  32.942704
# 3       2040 SOUTH SANTA CRUZ STREET SUITE 240, ANAHEI...  33.797606
# 4                            1 YELLOWWOOD WAY, IRVINE, CA  33.658618
# ...                                                   ...        ...
# 968552                   1635 Innovation Dr, ROCKWALL, TX        NaN
# 968553               1100 NE 45th St Ste 500, Seattle, WA        NaN
# 968554                     4029 HENDERSON BLVD, TAMPA, FL        NaN
# 968555               11031 WATERCREST CIR W, PARKLAND, FL        NaN
# 968556        3225A S Rainbow Blvd Ste 102, Las Vegas, NV        NaN
#
#               Long        FIPS_z
# 0      -122.535984  6.041119e+13
# 1      -118.259663  6.037911e+13
# 2      -117.260217  6.073017e+13
# 3      -117.894151  6.059086e+13
# 4      -117.822648  6.059063e+13
# ...            ...           ...
# 968552         NaN           NaN
# 968553         NaN           NaN
# 968554         NaN           NaN
# 968555         NaN           NaN
# 968556         NaN           NaN
#
# [968557 rows x 36 columns]

# %%
ppp_hpgf.loc[ppp_hpgf["Lat"].isnull()] #479618 merge from fips / #479586 merge from geo
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 5       4158237710  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 6       3321447710  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 8       3191927702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 10      7521657706  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 16      1526937709  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
#                      IndustrySubsector DateApproved  SBAOfficeCode  \
# 5                        Not Available       5/1/20            811
# 6                        Not Available       5/1/20            455
# 8                        Not Available       5/1/20            562
# 10                       Not Available       5/1/20            768
# 16                       Not Available       5/1/20            202
# ...                                ...          ...            ...
# 968552  Nonclassifiable Establishments      4/11/20            610
# 968553  Nonclassifiable Establishments       5/1/20           1013
# 968554  Nonclassifiable Establishments      4/14/20            455
# 968555  Nonclassifiable Establishments       5/1/20            455
# 968556  Nonclassifiable Establishments       5/1/20            944
#
#                            SBAOfficeLabel ProcessingMethod  \
# 5                COLORADO DISTRICT OFFICE              PPP
# 6           SOUTH FLORIDA DISTRICT OFFICE              PPP
# 8                 INDIANA DISTRICT OFFICE              PPP
# 10              ST. LOUIS DISTRICT OFFICE              PPP
# 16               NEW YORK DISTRICT OFFICE              PPP
# ...                                   ...              ...
# 968552  DALLAS / FT WORTH DISTRICT OFFICE              PPP
# 968553            SEATTLE DISTRICT OFFICE              PPP
# 968554      SOUTH FLORIDA DISTRICT OFFICE              PPP
# 968555      SOUTH FLORIDA DISTRICT OFFICE              PPP
# 968556             NEVADA DISTRICT OFFICE              PPP
#
#                               BorrowerName BorrowerState  ... NonProfit  \
# 5                            HALEPASKA LAW            CO  ...         N
# 6          OUTRIGGER INC-SBA SMALL 7A TERM            FL  ...         N
# 8                             ANAGIN, INC.            IN  ...         N
# 10                B & C TRANSPORTATION INC            MO  ...         N
# 16                     STANZA TRUCKING INC            NY  ...         N
# ...                                    ...           ...  ...       ...
# 968552                      ASTROCHEF, LLC            TX  ...         N
# 968553               UW PHYSICIANS NETWORK            WA  ...         Y
# 968554  PHASE THREE STAR, LLC DBA HARDEE'S            FL  ...         N
# 968555                   KNA SOLUTIONS LLC            FL  ...         N
# 968556               SILVER STATE BELL LLC            NV  ...         N
#
#        ForgivenessAmount  ForgivenessDate  Estimated_LenderPercent  \
# 5                    NaN              NaN                       5%
# 6              176962.31           8/2/21                       5%
# 8              166752.08          5/21/21                       5%
# 10                   NaN              NaN                       5%
# 16             202629.67          8/30/21                       5%
# ...                  ...              ...                      ...
# 968552               NaN              NaN                       1%
# 968553        5366395.05          9/20/21                       1%
# 968554        6362785.00          6/23/21                       1%
# 968555               NaN              NaN                       1%
# 968556        6600200.69          6/18/21                       1%
#
#         Estimated_LenderProfit LongName  \
# 5                      7646.05      NaN
# 6                     15000.00      NaN
# 8                      8251.35      NaN
# 10                     8485.20      NaN
# 16                    10000.00      NaN
# ...                        ...      ...
# 968552                55527.49      NaN
# 968553                52934.47      NaN
# 968554                62920.00      NaN
# 968555                84989.77      NaN
# 968556                65268.85      NaN
#
#                                                  full_add Lat Long  FIPS_z
# 5            600 17TH STREET SUITE 2800 SOUTH, DENVER, CO NaN  NaN     NaN
# 6                     1701 Mabbette Street, Kissimmee, FL NaN  NaN     NaN
# 8       INDIANA CENTER FOR BIOMEDICAL INNOVATION NOYES... NaN  NaN     NaN
# 10                        832 LAMPLIGHT LN, HAZELWOOD, MO NaN  NaN     NaN
# 16      CO JOHN COSTANZA 157-28 20TH RD 2ND FL, WHITES... NaN  NaN     NaN
# ...                                                   ...  ..  ...     ...
# 968552                   1635 Innovation Dr, ROCKWALL, TX NaN  NaN     NaN
# 968553               1100 NE 45th St Ste 500, Seattle, WA NaN  NaN     NaN
# 968554                     4029 HENDERSON BLVD, TAMPA, FL NaN  NaN     NaN
# 968555               11031 WATERCREST CIR W, PARKLAND, FL NaN  NaN     NaN
# 968556        3225A S Rainbow Blvd Ste 102, Las Vegas, NV NaN  NaN     NaN
#
# [479618 rows x 36 columns]

# %% [markdown]
# Output for Labeled, Hashed, Geocoded, FIPS file

# %%
ppp_hpgf.to_csv("data/pipe_hpgf.csv")

# %%
lat_null = ppp_hpgf.loc[ppp_hpgf["Lat"].isnull()] #587569
print(lat_null.shape[0])
fips_null = ppp_hpgf.loc[ppp_hpgf["FIPS_z"].isnull()] #628616
print(fips_null.shape[0])
# Out:
# 479618
# 479907

# %% [markdown]
# Parsing by State Output for Labeled, Hashed, Geocoded, FIPS file

# %%
#compute file for each state
ak_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AK", :]
al_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AL", :]
ar_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AR", :]
as_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AS", :] #American Samoa
az_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AZ", :]
ca_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CA", :]
co_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CO", :]
ct_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CT", :]
dc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DC", :] #D.C.
de_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DE", :]
fl_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "FL", :]
ga_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GA", :]
gu_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GU", :] #Guam
hi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "HI", :]
ia_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IA", :]
id_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ID", :]
il_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IL", :]
in_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IN", :]
ks_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KS", :]
ky_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KY", :]
la_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "LA", :]
ma_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MA", :]
md_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MD", :]
me_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ME", :]
mi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MI", :]
mn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MN", :]
mo_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MO", :]
mp_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MP", :] #Saipan Member of Parliament
ms_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MS", :]
mt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MT", :]
nc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NC", :]
nd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ND", :]
ne_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NE", :]
nh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NH", :]
nj_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NJ", :]
nm_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NM", :]
nv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NV", :]
ny_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NY", :]
oh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OH", :]
ok_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OK", :]
or_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OR", :]
pa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PA", :]
pr_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PR", :] #Puerto Rico
ri_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "RI", :]
sc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SC", :]
sd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SD", :]
tn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TN", :]
tx_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TX", :]
ut_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "UT", :]
va_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VA", :]
vi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VI", :] #Virgin Islands
vt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VT", :]
wa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WA", :]
wi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WI", :]
wv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WV", :]
wy_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WY", :]

# %% [markdown]
# FIPS states

# %%
#have fips
ak_hpgf.to_csv("data/state_data/hash_states/hpgf_ak.csv") 
al_hpgf.to_csv("data/state_data/hash_states/hpgf_al.csv")
ar_hpgf.to_csv("data/state_data/hash_states/hpgf_ar.csv") 
az_hpgf.to_csv("data/state_data/hash_states/hpgf_az.csv")

ca_hpgf.to_csv("data/state_data/hash_states/hpgf_ca.csv")  
ct_hpgf.to_csv("data/state_data/hash_states/hpgf_ct.csv")  
dc_hpgf.to_csv("data/state_data/hash_states/hpgf_dc.csv")
de_hpgf.to_csv("data/state_data/hash_states/hpgf_de.csv")
ga_hpgf.to_csv("data/state_data/hash_states/hpgf_ga.csv") 
il_hpgf.to_csv("data/state_data/hash_states/hpgf_il.csv")  
ky_hpgf.to_csv("data/state_data/hash_states/hpgf_ky.csv")

ma_hpgf.to_csv("data/state_data/hash_states/hpgf_ma.csv")
md_hpgf.to_csv("data/state_data/hash_states/hpgf_md.csv")
me_hpgf.to_csv("data/state_data/hash_states/hpgf_me.csv")  
nc_hpgf.to_csv("data/state_data/hash_states/hpgf_nc.csv")
nh_hpgf.to_csv("data/state_data/hash_states/hpgf_nh.csv")
nj_hpgf.to_csv("data/state_data/hash_states/hpgf_nj.csv")
oh_hpgf.to_csv("data/state_data/hash_states/hpgf_oh.csv")
pa_hpgf.to_csv("data/state_data/hash_states/hpgf_pa.csv")

tn_hpgf.to_csv("data/state_data/hash_states/hpgf_tn.csv")  
va_hpgf.to_csv("data/state_data/hash_states/hpgf_va.csv")  
vt_hpgf.to_csv("data/state_data/hash_states/hpgf_vt.csv")
wv_hpgf.to_csv("data/state_data/hash_states/hpgf_wv.csv")

# %% [markdown]
# All States

# %%
#PointPair each state file separately in aggregation notebook
ak_hpgf.to_csv("data/state_data/hash_states/hpgf_ak.csv") 
al_hpgf.to_csv("data/state_data/hash_states/hpgf_al.csv")
ar_hpgf.to_csv("data/state_data/hash_states/hpgf_ar.csv") 
as_hpgf.to_csv("data/state_data/hash_states/hpgf_as.csv")
az_hpgf.to_csv("data/state_data/hash_states/hpgf_az.csv")  
ca_hpgf.to_csv("data/state_data/hash_states/hpgf_ca.csv")  
co_hpgf.to_csv("data/state_data/hash_states/hpgf_co.csv") 
ct_hpgf.to_csv("data/state_data/hash_states/hpgf_ct.csv")  
dc_hpgf.to_csv("data/state_data/hash_states/hpgf_dc.csv")
de_hpgf.to_csv("data/state_data/hash_states/hpgf_de.csv") 
fl_hpgf.to_csv("data/state_data/hash_states/hpgf_fl.csv") 
ga_hpgf.to_csv("data/state_data/hash_states/hpgf_ga.csv") 
gu_hpgf.to_csv("data/state_data/hash_states/hpgf_gu.csv")
hi_hpgf.to_csv("data/state_data/hash_states/hpgf_hi.csv") 
ia_hpgf.to_csv("data/state_data/hash_states/hpgf_ia.csv")  
id_hpgf.to_csv("data/state_data/hash_states/hpgf_id.csv")  
il_hpgf.to_csv("data/state_data/hash_states/hpgf_il.csv")  
in_hpgf.to_csv("data/state_data/hash_states/hpgf_in.csv") 
ks_hpgf.to_csv("data/state_data/hash_states/hpgf_ks.csv")  
ky_hpgf.to_csv("data/state_data/hash_states/hpgf_ky.csv")  
la_hpgf.to_csv("data/state_data/hash_states/hpgf_la.csv")
ma_hpgf.to_csv("data/state_data/hash_states/hpgf_ma.csv") 
md_hpgf.to_csv("data/state_data/hash_states/hpgf_md.csv")
me_hpgf.to_csv("data/state_data/hash_states/hpgf_me.csv")  
mi_hpgf.to_csv("data/state_data/hash_states/hpgf_mi.csv") 
mn_hpgf.to_csv("data/state_data/hash_states/hpgf_mn.csv") 
mo_hpgf.to_csv("data/state_data/hash_states/hpgf_mo.csv")  
mp_hpgf.to_csv("data/state_data/hash_states/hpgf_mp.csv") 
ms_hpgf.to_csv("data/state_data/hash_states/hpgf_ms.csv")
mt_hpgf.to_csv("data/state_data/hash_states/hpgf_mt.csv")
nc_hpgf.to_csv("data/state_data/hash_states/hpgf_nc.csv") 
nd_hpgf.to_csv("data/state_data/hash_states/hpgf_nd.csv")  
ne_hpgf.to_csv("data/state_data/hash_states/hpgf_ne.csv")
nh_hpgf.to_csv("data/state_data/hash_states/hpgf_nh.csv")  
nj_hpgf.to_csv("data/state_data/hash_states/hpgf_nj.csv")
nm_hpgf.to_csv("data/state_data/hash_states/hpgf_nm.csv") 
nv_hpgf.to_csv("data/state_data/hash_states/hpgf_nv.csv")  
ny_hpgf.to_csv("data/state_data/hash_states/hpgf_ny.csv")  
oh_hpgf.to_csv("data/state_data/hash_states/hpgf_oh.csv")
ok_hpgf.to_csv("data/state_data/hash_states/hpgf_ok.csv") 
or_hpgf.to_csv("data/state_data/hash_states/hpgf_or.csv")  
pa_hpgf.to_csv("data/state_data/hash_states/hpgf_pa.csv")
pr_hpgf.to_csv("data/state_data/hash_states/hpgf_pr.csv")  
ri_hpgf.to_csv("data/state_data/hash_states/hpgf_ri.csv") 
sc_hpgf.to_csv("data/state_data/hash_states/hpgf_sc.csv") 
sd_hpgf.to_csv("data/state_data/hash_states/hpgf_sd.csv") 
tn_hpgf.to_csv("data/state_data/hash_states/hpgf_tn.csv")  
tx_hpgf.to_csv("data/state_data/hash_states/hpgf_tx.csv")  
ut_hpgf.to_csv("data/state_data/hash_states/hpgf_ut.csv")  
va_hpgf.to_csv("data/state_data/hash_states/hpgf_va.csv")  
vi_hpgf.to_csv("data/state_data/hash_states/hpgf_vi.csv")  
vt_hpgf.to_csv("data/state_data/hash_states/hpgf_vt.csv")
wa_hpgf.to_csv("data/state_data/hash_states/hpgf_wa.csv")  
wi_hpgf.to_csv("data/state_data/hash_states/hpgf_wi.csv")  
wv_hpgf.to_csv("data/state_data/hash_states/hpgf_wv.csv") 
wy_hpgf.to_csv("data/state_data/hash_states/hpgf_wy.csv")
