# %%
import pandas as pd
import numpy as np

# %%
orig_23add=pd.read_csv("../../data/raw/>150K/public_150k_plus_230630.csv")
orig_23add.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# ...

# %%
update_23add = pd.read_csv("../../data/pipe_hpgf23.csv", index_col=0)
update_23add.head()
# Out:
# /var/folders/vy/qdp8xcfj4s3dd5c6d1xp_y3w0000gn/T/ipykernel_6402/1575710681.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   update_23add = pd.read_csv("../data/pipe_hpgf23.csv", index_col=0)
#    LoanNumber  DateApprovedTS  SBAOfficeCode                  SBAOfficeLabel  \
# 0  9547507704        20200501            464  SOUTH CAROLINA DISTRICT OFFICE
# 1  9777677704        20200501            464  SOUTH CAROLINA DISTRICT OFFICE
# 2  5791407702        20200501           1013         SEATTLE DISTRICT OFFICE
# 3  6223567700        20200501            920       SANTA ANA DISTRICT OFFICE
# 4  9662437702        20200501            101   MASSACHUSETTS DISTRICT OFFICE
#
#   ProcessingMethod              BorrowerName LoanStatusDateTS    LoanStatus  \
# 0              PPP     SUMTER COATINGS, INC.         20201218  Paid in Full
# 1              PPP     PLEASANT PLACES, INC.         20210928  Paid in Full
# ...

# %% [markdown]
# Address Compare

# %%
orig_23add['full_add'] = orig_23add.BorrowerAddress + ", " + orig_23add.BorrowerCity + ", " + orig_23add.BorrowerState
cols=["LoanNumber", "full_add"]
orig_parse = orig_23add[cols]
orig_parse
# Out:
#         LoanNumber                                     full_add
# 0       9547507704                                          NaN
# 1       9777677704                                          NaN
# 2       5791407702                                          NaN
# 3       6223567700                                          NaN
# 4       9662437702                                          NaN
# ...            ...                                          ...
# 965547  4395967002                   102 N. Kenwood, CASPER, WY
# 965548  6985647108       1715 HITCHING POST DR, GREEN RIVER, WY
# 965549  7996438405                      1105 Adon Rd, Rozet, WY
# 965550  9054647103  30 N. Gould Street Suite 4000, SHERIDAN, WY
# 965551  9184687004      7342 Granite Loop Rd, TETON VILLAGE, WY
#
# [965552 rows x 2 columns]

# %%
update_23add['Match'] = (update_23add['full_add'].isin(orig_parse['full_add']))
update_23add
# Out:
#         LoanNumber  DateApprovedTS  SBAOfficeCode  \
# 0       9547507704        20200501            464
# 1       9777677704        20200501            464
# 2       5791407702        20200501           1013
# 3       6223567700        20200501            920
# 4       9662437702        20200501            101
# ...            ...             ...            ...
# 965547  4395967002        20200403            897
# 965548  6985647108        20200414            897
# 965549  7996438405        20210212            897
# 965550  9054647103        20200415            897
# 965551  9184687004        20200409            897
#
#                         SBAOfficeLabel ProcessingMethod  \
# 0       SOUTH CAROLINA DISTRICT OFFICE              PPP
# 1       SOUTH CAROLINA DISTRICT OFFICE              PPP
# 2              SEATTLE DISTRICT OFFICE              PPP
# 3            SANTA ANA DISTRICT OFFICE              PPP
# 4        MASSACHUSETTS DISTRICT OFFICE              PPP
# ...

# %% [markdown]
# Addresses Changed/Added (raw>final)

# %%
diff_add = update_23add.loc[update_23add['Match'] == False]
diff_add.shape[0]
# Out:
# 713
