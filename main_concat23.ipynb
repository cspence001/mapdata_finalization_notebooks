# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# <b>PIPE

# %%
ppp_pipe23 = pd.read_csv("../data/ppp_pipe23.csv")
ppp_pipe23.head()
ppp_pipe23.columns
# Out:
# Index(['Unnamed: 0', 'LoanNumber', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState',
#        'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
#        'DEBT_INTEREST_PROCEED', 'BusinessType', 'OriginatingLenderLocationID',
# ...

# %%
#ppp_pipe23['ServicingLenderLocationID'].nunique()#can haave option to display markers for servicing lender, radius by $
#ppp_pipe23['TRIIndustrySector'].value_counts() #Alternate display by

# %% [markdown]
# Determining Necessary Columns for Final DataFrame

# %%
#keep track of columns removed
dele = ['Unnamed: 0', 'BorrowerAddress', 'BorrowerCity', 'BorrowerZip', 'SBAGuarantyPercentage', 'InitialApprovalAmount', 'RuralUrbanIndicator', 'HubzoneIndicator',  'LMIIndicator', 
 'BusinessAgeDescription', 'ProjectCity','ProjectCountyName', 'ProjectState', 'ProjectZip','Race', 'Ethnicity', 'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState', 'ServicingLenderZip', 
 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'DateApproved_ts', 'ForgivenessDate_ts',
 'HEALTH_CARE_PROCEED','DEBT_INTEREST_PROCEED', 'NA', '4DigitNAICS', 'NAICSCode', 'Industry', 'IndustrySubsector', 'TRIIndustrySector', 'Loan_Range', 'job_Range', 'Gender', 'Veteran']
#Industry and Industry Subsector taken from HASH file (NAICS)
cols =['LoanNumber', 'DateApprovedTS', 'SBAOfficeCode', 'SBAOfficeLabel','ProcessingMethod', 'BorrowerName', 
       'BorrowerState', 'LoanStatusDate', 'LoanStatus', 'Term', 'CurrentApprovalAmount', 'UndisbursedAmount', 
       'FranchiseName','ServicingLenderLocationID', 'ServicingLenderName', 
       'CD', 'JobsReported', 'OriginatingLenderLocationID', 'OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
       'BusinessType', 'BusinessAgeDescription', 'NonProfit', 'ForgivenessAmount', 'ForgivenessDateTS', 'Estimated_LenderPercent', 'Estimated_LenderProfit', 
       'LongName', 'full_add']

ppp_pipe23 = ppp_pipe23[cols]
ppp_pipe23.head()
# Out:
#    LoanNumber  DateApprovedTS  SBAOfficeCode                  SBAOfficeLabel  \
# 0  9547507704        20200501            464  SOUTH CAROLINA DISTRICT OFFICE
# 1  9777677704        20200501            464  SOUTH CAROLINA DISTRICT OFFICE
# 2  5791407702        20200501           1013         SEATTLE DISTRICT OFFICE
# 3  6223567700        20200501            920       SANTA ANA DISTRICT OFFICE
# 4  9662437702        20200501            101   MASSACHUSETTS DISTRICT OFFICE
#
#   ProcessingMethod              BorrowerName BorrowerState LoanStatusDate  \
# 0              PPP     SUMTER COATINGS, INC.           NaN     12/18/2020
# 1              PPP     PLEASANT PLACES, INC.           NaN     09/28/2021
# 2              PPP   BOYER CHILDREN'S CLINIC           NaN     03/17/2021
# 3              PPP  KIRTLEY CONSTRUCTION INC           NaN     10/16/2021
# 4              PPP              AERO BOX LLC           NaN     08/17/2021
#
# ...

# %% [markdown]
# <b>GEO

# %%
#ppp_geo = pd.read_csv("../../../../../data/state_data/geo/ppp_geo.csv")
#cols = ["LoanNumber", "Lat", "Long"]
#ppp_geo = ppp_geo[cols]
#ppp_geo.head()

# %% [markdown]
# <b>HASH file addition

# %%
ppp_hash = pd.read_csv("../data/ppp_hashSort.csv") 
cols = ["LoanNumber", "HASHcodePM", "Industry", "IndustrySubsector"]
ppp_hash = ppp_hash[cols]
ppp_hash
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 968552  3488997103  IND99SS00LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 968553  5482257701  IND99SS00LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 968554  6699567107  IND99SS00LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 968555  5359597703  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 968556  5843777700  IND99SS00LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
# ...

# %% [markdown]
# <b>FIPS file addition

# %%
ppp_fips_ak = pd.read_csv("../data/state_data/geo/geo_fips/AK_fips_scraped.csv")  
ppp_fips_al = pd.read_csv("../data/state_data/geo/geo_fips/AL_fips_scraped.csv") 
ppp_fips_ar = pd.read_csv("../data/state_data/geo/geo_fips/AR_fips_scraped.csv") 
ppp_fips_as = pd.read_csv("../data/state_data/geo/geo_fips/AS_fips_scraped.csv") 
ppp_fips_az = pd.read_csv("../data/state_data/geo/geo_fips/AZ_fips_scraped.csv") 

ppp_fips_ca = pd.read_csv("../data/state_data/geo/geo_fips/CA_fips_scraped.csv") 
ppp_fips_co = pd.read_csv("../data/state_data/geo/geo_fips/CO_fips_scraped.csv") 
ppp_fips_ct = pd.read_csv("../data/state_data/geo/geo_fips/CT_fips_scraped.csv") 
ppp_fips_dc = pd.read_csv("../data/state_data/geo/geo_fips/DC_fips_scraped.csv") 
ppp_fips_de = pd.read_csv("../data/state_data/geo/geo_fips/DE_fips_scraped.csv") 

ppp_fips_fl = pd.read_csv("../data/state_data/geo/geo_fips/FL_fips_scraped.csv") 
ppp_fips_ga = pd.read_csv("../data/state_data/geo/geo_fips/GA_fips_scraped.csv") 
ppp_fips_gu = pd.read_csv("../data/state_data/geo/geo_fips/GU_fips_scraped.csv") 
ppp_fips_hi = pd.read_csv("../data/state_data/geo/geo_fips/HI_fips_scraped.csv") 
ppp_fips_ia = pd.read_csv("../data/state_data/geo/geo_fips/IA_fips_scraped.csv") 

ppp_fips_id = pd.read_csv("../data/state_data/geo/geo_fips/ID_fips_scraped.csv") 
ppp_fips_il = pd.read_csv("../data/state_data/geo/geo_fips/IL_fips_scraped.csv") 
ppp_fips_in = pd.read_csv("../data/state_data/geo/geo_fips/IN_fips_scraped.csv") 
ppp_fips_ks = pd.read_csv("../data/state_data/geo/geo_fips/KS_fips_scraped.csv")
ppp_fips_ky = pd.read_csv("../data/state_data/geo/geo_fips/KY_fips_scraped.csv") 

ppp_fips_la = pd.read_csv("../data/state_data/geo/geo_fips/LA_fips_scraped.csv")
ppp_fips_ma = pd.read_csv("../data/state_data/geo/geo_fips/MA_fips_scraped.csv") 
ppp_fips_md = pd.read_csv("../data/state_data/geo/geo_fips/MD_fips_scraped.csv") 
ppp_fips_me = pd.read_csv("../data/state_data/geo/geo_fips/ME_fips_scraped.csv") 
ppp_fips_mi = pd.read_csv("../data/state_data/geo/geo_fips/MI_fips_scraped.csv")

ppp_fips_mn = pd.read_csv("../data/state_data/geo/geo_fips/MN_fips_scraped.csv")
ppp_fips_mo = pd.read_csv("../data/state_data/geo/geo_fips/MO_fips_scraped.csv")
ppp_fips_mp = pd.read_csv("../data/state_data/geo/geo_fips/MP_fips_scraped.csv")
ppp_fips_ms = pd.read_csv("../data/state_data/geo/geo_fips/MS_fips_scraped.csv")
ppp_fips_mt = pd.read_csv("../data/state_data/geo/geo_fips/MT_fips_scraped.csv")

ppp_fips_nc = pd.read_csv("../data/state_data/geo/geo_fips/NC_fips_scraped.csv") 
ppp_fips_nd = pd.read_csv("../data/state_data/geo/geo_fips/ND_fips_scraped.csv")
ppp_fips_ne = pd.read_csv("../data/state_data/geo/geo_fips/NE_fips_scraped.csv")
ppp_fips_nh = pd.read_csv("../data/state_data/geo/geo_fips/NH_fips_scraped.csv") 
ppp_fips_nj = pd.read_csv("../data/state_data/geo/geo_fips/NJ_fips_scraped.csv") 

ppp_fips_nm = pd.read_csv("../data/state_data/geo/geo_fips/NM_fips_scraped.csv") 
ppp_fips_nv = pd.read_csv("../data/state_data/geo/geo_fips/NV_fips_scraped.csv") 
ppp_fips_ny = pd.read_csv("../data/state_data/geo/geo_fips/NY_fips_scraped.csv") 
ppp_fips_oh = pd.read_csv("../data/state_data/geo/geo_fips/OH_fips_scraped.csv") 
ppp_fips_ok = pd.read_csv("../data/state_data/geo/geo_fips/OK_fips_scraped.csv") 

ppp_fips_or = pd.read_csv("../data/state_data/geo/geo_fips/OR_fips_scraped.csv") 
ppp_fips_pa = pd.read_csv("../data/state_data/geo/geo_fips/PA_fips_scraped.csv") 
ppp_fips_pr = pd.read_csv("../data/state_data/geo/geo_fips/PR_fips_scraped.csv") 
ppp_fips_ri = pd.read_csv("../data/state_data/geo/geo_fips/RI_fips_scraped.csv") 
ppp_fips_sc = pd.read_csv("../data/state_data/geo/geo_fips/SC_fips_scraped.csv") 

ppp_fips_sd = pd.read_csv("../data/state_data/geo/geo_fips/SD_fips_scraped.csv") 
ppp_fips_tn = pd.read_csv("../data/state_data/geo/geo_fips/TN_fips_scraped.csv")  
ppp_fips_tx = pd.read_csv("../data/state_data/geo/geo_fips/TX_fips_scraped.csv")
ppp_fips_ut = pd.read_csv("../data/state_data/geo/geo_fips/UT_fips_scraped.csv") 
ppp_fips_vi = pd.read_csv("../data/state_data/geo/geo_fips/VI_fips_scraped.csv")
ppp_fips_va = pd.read_csv("../data/state_data/geo/geo_fips/VA_fips_scraped.csv")

ppp_fips_vt = pd.read_csv("../data/state_data/geo/geo_fips/VT_fips_scraped.csv")
ppp_fips_wa = pd.read_csv("../data/state_data/geo/geo_fips/WA_fips_scraped.csv")
ppp_fips_wi = pd.read_csv("../data/state_data/geo/geo_fips/WI_fips_scraped.csv")
ppp_fips_wv = pd.read_csv("../data/state_data/geo/geo_fips/WV_fips_scraped.csv")
ppp_fips_wy = pd.read_csv("../data/state_data/geo/geo_fips/WY_fips_scraped.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (71) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ppp_fips_as.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0           19445             19445
# 1           1             1           19446             19446
# 2           2             2           19447             19447
# 3           3             3           19448             19448
# 4           4             4           19449             19449
#
#    Unnamed: 0.1.1.1.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0               19445  6927458108      7/22/20            951
# 1               19446  7124948005      6/30/20            951
# 2               19447  1760228005      6/23/20            951
# 3               19448  2530867306      4/29/20            951
# 4               19449  2121297104      4/10/20            951
#
#   ProcessingMethod                BorrowerName  ... TRIIndustrySector  \
# 0              PPP             AST TELECOM LLC  ...         999 Other
# 1              PPP           MC CONNELL DOWELL  ...         999 Other
# ...

# %%
#get FIPS, LoanNumber from each file
cols= ["LoanNumber", "Lat", "Long", "FIPS_z"]

ppp_fips_ak = ppp_fips_ak[cols]
ppp_fips_al = ppp_fips_al[cols]
ppp_fips_ar = ppp_fips_ar[cols]
ppp_fips_as = ppp_fips_as[cols]
ppp_fips_az = ppp_fips_az[cols]

ppp_fips_ca = ppp_fips_ca[cols]
ppp_fips_co = ppp_fips_co[cols]
ppp_fips_ct = ppp_fips_ct[cols]
ppp_fips_dc = ppp_fips_dc[cols]
ppp_fips_de = ppp_fips_de[cols]

ppp_fips_fl = ppp_fips_fl[cols]
ppp_fips_ga = ppp_fips_ga[cols]
ppp_fips_gu = ppp_fips_gu[cols]
ppp_fips_hi = ppp_fips_hi[cols]
ppp_fips_ia = ppp_fips_ia[cols]

ppp_fips_id = ppp_fips_id[cols]
ppp_fips_il = ppp_fips_il[cols]
ppp_fips_in = ppp_fips_in[cols]
ppp_fips_ks = ppp_fips_ks[cols]
ppp_fips_ky = ppp_fips_ky[cols]

ppp_fips_la = ppp_fips_la[cols]
ppp_fips_ma = ppp_fips_ma[cols]
ppp_fips_md = ppp_fips_md[cols]
ppp_fips_me = ppp_fips_me[cols]
ppp_fips_mi = ppp_fips_mi[cols]

ppp_fips_mn = ppp_fips_mn[cols]
ppp_fips_mo = ppp_fips_mo[cols]
ppp_fips_mp = ppp_fips_mp[cols]
ppp_fips_ms = ppp_fips_ms[cols]
ppp_fips_mt = ppp_fips_mt[cols]

ppp_fips_nc = ppp_fips_nc[cols]
ppp_fips_nd = ppp_fips_nd[cols]
ppp_fips_ne = ppp_fips_ne[cols]
ppp_fips_nh = ppp_fips_nh[cols]
ppp_fips_nj = ppp_fips_nj[cols]

ppp_fips_nm = ppp_fips_nm[cols]
ppp_fips_nv = ppp_fips_nv[cols]
ppp_fips_ny = ppp_fips_ny[cols]
ppp_fips_oh = ppp_fips_oh[cols]
ppp_fips_ok = ppp_fips_ok[cols]

ppp_fips_or = ppp_fips_or[cols]
ppp_fips_pa = ppp_fips_pa[cols]
ppp_fips_pr = ppp_fips_pr[cols]
ppp_fips_ri = ppp_fips_ri[cols]
ppp_fips_sc = ppp_fips_sc[cols]

ppp_fips_sd = ppp_fips_sd[cols]
ppp_fips_tn = ppp_fips_tn[cols]
ppp_fips_tx = ppp_fips_tx[cols]
ppp_fips_ut = ppp_fips_ut[cols]
ppp_fips_va = ppp_fips_va[cols] 

ppp_fips_vi = ppp_fips_vi[cols] 
ppp_fips_vt = ppp_fips_vt[cols]
ppp_fips_wa = ppp_fips_wa[cols]
ppp_fips_wi = ppp_fips_wi[cols]
ppp_fips_wv = ppp_fips_wv[cols]

ppp_fips_wy = ppp_fips_wy[cols]


frames = [ppp_fips_ak, ppp_fips_al, ppp_fips_ar, ppp_fips_as, ppp_fips_az, 
ppp_fips_ca, ppp_fips_co, ppp_fips_ct, ppp_fips_dc, ppp_fips_de, 
ppp_fips_fl, ppp_fips_ga, ppp_fips_gu, ppp_fips_hi, ppp_fips_ia, 
ppp_fips_id, ppp_fips_il, ppp_fips_in, ppp_fips_ks, ppp_fips_ky, 
ppp_fips_la, ppp_fips_ma, ppp_fips_md, ppp_fips_me, ppp_fips_mi, 
ppp_fips_mn, ppp_fips_mo, ppp_fips_mp, ppp_fips_ms, ppp_fips_mt, 
ppp_fips_nc, ppp_fips_nd, ppp_fips_ne, ppp_fips_nh, ppp_fips_nj, 
ppp_fips_nm, ppp_fips_nv, ppp_fips_ny, ppp_fips_oh, ppp_fips_ok, 
ppp_fips_or, ppp_fips_pa, ppp_fips_pr, ppp_fips_ri, ppp_fips_sc, 
ppp_fips_sd, ppp_fips_tn, ppp_fips_tx, ppp_fips_ut, ppp_fips_va, 
ppp_fips_vi, ppp_fips_vt, ppp_fips_wa, ppp_fips_wi, ppp_fips_wv, ppp_fips_wy]


result = pd.concat(frames)
result
# Out:
#       LoanNumber        Lat        Long        FIPS_z
# 0     5502308207  61.174949 -149.888309  2.020002e+13
# 1     6110847106   71.29729 -156.728897  2.185000e+13
# 2     4539098204  61.173232 -149.972718  2.020002e+13
# 3     5120868804  61.173164 -149.893283  2.020003e+13
# 4     6650277102  59.652704 -151.549793  2.122001e+13
# ...          ...        ...         ...           ...
# 2134  4395967002    42.8503 -106.304365  5.602500e+14
# 2135  6985647108  41.499071 -109.464675  5.603797e+14
# 2136  7996438405  44.435381 -105.226008  5.600500e+14
# 2137  9054647103  44.797763 -106.954952  5.603300e+14
# 2138  9184687004  43.587714 -110.822222  5.603997e+14
#
# [968558 rows x 4 columns]

# %% [markdown]
# Merged DataFrame

# %%
#merge 
ppp_hash_pipe23 = ppp_pipe23.merge(ppp_hash, on="LoanNumber", how="left")
#ppp_hash_pipe_geo = ppp_hash_pipe.merge(ppp_geo, on="LoanNumber", how="left")
ppp_hash_pipe23
# Out:
#         LoanNumber  DateApprovedTS  SBAOfficeCode  \
# 0       9547507704        20200501            464
# 1       9777677704        20200501            464
# 2       5791407702        20200501           1013
# 3       6223567700        20200501            920
# 4       9662437702        20200501            101
# ...            ...             ...            ...
# 965547  4395967002        20200403            897
# 965548  6985647108        20200414            897
# 965549  7996438405        20210212            897
# 965550  9054647103        20200415            897
# 965551  9184687004        20200409            897
#
#                         SBAOfficeLabel ProcessingMethod  \
# 0       SOUTH CAROLINA DISTRICT OFFICE              PPP
# 1       SOUTH CAROLINA DISTRICT OFFICE              PPP
# 2              SEATTLE DISTRICT OFFICE              PPP
# 3            SANTA ANA DISTRICT OFFICE              PPP
# 4        MASSACHUSETTS DISTRICT OFFICE              PPP
# ...

# %%
ppp_hpgf = ppp_hash_pipe23.merge(result, on="LoanNumber", how="left")
ppp_hpgf
# Out:
#         LoanNumber  DateApprovedTS  SBAOfficeCode  \
# 0       9547507704        20200501            464
# 1       9777677704        20200501            464
# 2       5791407702        20200501           1013
# 3       6223567700        20200501            920
# 4       9662437702        20200501            101
# ...            ...             ...            ...
# 965548  4395967002        20200403            897
# 965549  6985647108        20200414            897
# 965550  7996438405        20210212            897
# 965551  9054647103        20200415            897
# 965552  9184687004        20200409            897
#
#                         SBAOfficeLabel ProcessingMethod  \
# 0       SOUTH CAROLINA DISTRICT OFFICE              PPP
# 1       SOUTH CAROLINA DISTRICT OFFICE              PPP
# 2              SEATTLE DISTRICT OFFICE              PPP
# 3            SANTA ANA DISTRICT OFFICE              PPP
# 4        MASSACHUSETTS DISTRICT OFFICE              PPP
# ...

# %%
#Locate extra row 965553/965552
dups =ppp_hpgf["LoanNumber"]
ppp_hpgf[dups.isin(dups[dups.duplicated()])].sort_values("LoanNumber")
# Out:
#         LoanNumber  DateApprovedTS  SBAOfficeCode            SBAOfficeLabel  \
# 904805  1573407107        20200410            304  RICHMOND DISTRICT OFFICE
# 904806  1573407107        20200410            304  RICHMOND DISTRICT OFFICE
#
#        ProcessingMethod                    BorrowerName BorrowerState  \
# 904805              PPP  GRIGSBY'S CARPET SHOWROOM, INC            VA
# 904806              PPP  GRIGSBY'S CARPET SHOWROOM, INC            VA
#
#        LoanStatusDate    LoanStatus  Term  ...  Estimated_LenderPercent  \
# 904805     04/08/2021  Paid in Full    24  ...                       5%
# 904806     04/08/2021  Paid in Full    24  ...                       5%
#
#         Estimated_LenderProfit              LongName  \
# 904805                 14735.0  Flooring Contractors
# 904806                 14735.0  Flooring Contractors
#
#                                    full_add                 HASHcodePM  \
# ...

# %%
#Duplicated row does not have FIPS_z value
ppp_hpgf = ppp_hpgf.drop(index=904806).reset_index(drop=True)
ppp_hpgf

# %%
#verify
dups =ppp_hpgf["LoanNumber"]
ppp_hpgf[dups.isin(dups[dups.duplicated()])].sort_values("LoanNumber")
# Out:
# Empty DataFrame
# Columns: [LoanNumber, DateApprovedTS, SBAOfficeCode, SBAOfficeLabel, ProcessingMethod, BorrowerName, BorrowerState, LoanStatusDate, LoanStatus, Term, CurrentApprovalAmount, UndisbursedAmount, FranchiseName, ServicingLenderLocationID, ServicingLenderName, CD, JobsReported, OriginatingLenderLocationID, OriginatingLender, OriginatingLenderCity, OriginatingLenderState, BusinessType, BusinessAgeDescription, NonProfit, ForgivenessAmount, ForgivenessDateTS, Estimated_LenderPercent, Estimated_LenderProfit, LongName, full_add, HASHcodePM, Industry, IndustrySubsector, Lat, Long, FIPS_z]
# Index: []
#
# [0 rows x 36 columns]

# %%
#Lat='None'>NaN 
ppp_hpgf["Lat"].replace(r'None', np.nan, regex=True)
# Out:
# 0         33.853682
# 1         32.942332
# 2         47.636067
# 3         34.224719
# 4         42.521828
#             ...
# 965547      42.8503
# 965548    41.499071
# 965549    44.435381
# 965550    44.797763
# 965551    43.587714
# Name: Lat, Length: 965552, dtype: object

# %%
#pd.set_option('display.max_rows', None)
latlong_ch= ppp_hpgf.loc[ppp_hpgf["Long"].isnull()] #479618 merge from fips / #479586 merge from geo
latlong_ch
#144 compared to 130 in original21
# Out:
#         LoanNumber  DateApprovedTS  SBAOfficeCode  \
# 369     5048318601        20210320           1084
# 428     5085327008        20200405           1084
# 1864    4637628408        20210206           1084
# 2273    5337318401        20210208           1084
# 2378    9891427104        20200415           1084
# ...            ...             ...            ...
# 934767  6060237406        20200513           1013
# 940043  9777148302        20210131           1013
# 945946  5637407007        20200406            563
# 959024  1404407106        20200410            563
# 962060  7369837107        20200414            390
#
#                        SBAOfficeLabel ProcessingMethod  \
# 369            ALASKA DISTRICT OFFICE              PPS
# 428            ALASKA DISTRICT OFFICE              PPP
# 1864           ALASKA DISTRICT OFFICE              PPS
# 2273           ALASKA DISTRICT OFFICE              PPS
# 2378           ALASKA DISTRICT OFFICE              PPP
# ...

# %%
ppp_hpgf.loc[ppp_hpgf["FIPS_z"].isnull()]

# %% [markdown]
# Output for Labeled, Hashed, Geocoded, FIPS file

# %%
ppp_hpgf.to_csv("../data/pipe_hpgf23.csv")

# %%
lat_null = ppp_hpgf.loc[ppp_hpgf["Lat"].isnull()] #587569
long_null = ppp_hpgf.loc[ppp_hpgf["Long"].isnull()] #587569
print(lat_null.shape[0])
print(long_null.shape[0])
fips_null = ppp_hpgf.loc[ppp_hpgf["FIPS_z"].isnull()] #628616
print(fips_null.shape[0])
# Out:
# 129
# 130
# 1050

# %% [markdown]
# Parsing by State Output for Labeled, Hashed, Geocoded, FIPS file

# %%
#compute file for each state
ak_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AK", :]
al_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AL", :]
ar_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AR", :]
as_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AS", :] #American Samoa
az_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AZ", :]

ca_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CA", :]
co_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CO", :]
ct_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CT", :]
dc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DC", :] #D.C.
de_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DE", :]

fl_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "FL", :]
ga_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GA", :]
gu_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GU", :] #Guam
hi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "HI", :]
ia_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IA", :]

id_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ID", :]
il_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IL", :]
in_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IN", :]
ks_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KS", :]
ky_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KY", :]
la_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "LA", :]
ma_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MA", :]
md_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MD", :]
me_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ME", :]
mi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MI", :]
mn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MN", :]
mo_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MO", :]
mp_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MP", :] #Saipan Member of Parliament
ms_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MS", :]
mt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MT", :]
nc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NC", :]
nd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ND", :]
ne_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NE", :]
nh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NH", :]
nj_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NJ", :]
nm_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NM", :]
nv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NV", :]
ny_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NY", :]
oh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OH", :]
ok_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OK", :]
or_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OR", :]
pa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PA", :]
pr_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PR", :] #Puerto Rico
ri_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "RI", :]
sc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SC", :]
sd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SD", :]
tn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TN", :]
tx_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TX", :]
ut_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "UT", :]
va_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VA", :]
vi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VI", :] #Virgin Islands
vt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VT", :]
wa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WA", :]
wi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WI", :]
wv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WV", :]
wy_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WY", :]

# %% [markdown]
# FIPS states

# %% [markdown]
# All States

# %%
#PointPair each state file separately in aggregation notebook
ak_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ak.csv") 
al_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_al.csv")
ar_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ar.csv") 
as_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_as.csv")
az_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_az.csv")  
ca_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ca.csv")  
co_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_co.csv") 
ct_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ct.csv")  
dc_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_dc.csv")
de_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_de.csv") 
fl_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_fl.csv") 
ga_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ga.csv") 
gu_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_gu.csv")
hi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_hi.csv") 
ia_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ia.csv")  
id_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_id.csv")  
il_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_il.csv")  
in_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_in.csv") 
ks_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ks.csv")  
ky_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ky.csv")  
la_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_la.csv")
ma_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ma.csv") 
md_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_md.csv")
me_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_me.csv")  
mi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mi.csv") 
mn_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mn.csv") 
mo_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mo.csv")  
mp_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mp.csv") 
ms_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ms.csv")
mt_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mt.csv")
nc_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nc.csv") 
nd_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nd.csv")  
ne_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ne.csv")
nh_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nh.csv")  
nj_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nj.csv")
nm_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nm.csv") 
nv_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nv.csv")  
ny_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ny.csv")  
oh_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_oh.csv")
ok_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ok.csv") 
or_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_or.csv")  
pa_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_pa.csv")
pr_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_pr.csv")  
ri_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ri.csv") 
sc_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_sc.csv") 
sd_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_sd.csv") 
tn_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_tn.csv")  
tx_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_tx.csv")  
ut_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ut.csv")  
va_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_va.csv")  
vi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_vi.csv")  
vt_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_vt.csv")
wa_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wa.csv")  
wi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wi.csv")  
wv_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wv.csv") 
wy_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wy.csv")
