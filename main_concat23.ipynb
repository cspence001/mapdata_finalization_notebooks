# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# <b>PIPE

# %%
ppp_pipe23 = pd.read_csv("../data/ppp_pipe23.csv", index_col=0)
ppp_pipe23.head()
# Out:
#    LoanNumber DateApprovedTS  SBAOfficeCode ProcessingMethod  \
# 0  9547507704     2020-05-01            464              PPP
# 1  9777677704     2020-05-01            464              PPP
# 2  5791407702     2020-05-01           1013              PPP
# 3  6223567700     2020-05-01            920              PPP
# 4  9662437702     2020-05-01            101              PPP
#
#                BorrowerName  BorrowerState     LoanStatusDateTS    LoanStatus  \
# 0     SUMTER COATINGS, INC.             SC  2020-12-18 00:00:00  Paid in Full
# 1     PLEASANT PLACES, INC.             SC  2021-09-28 00:00:00  Paid in Full
# 2   BOYER CHILDREN'S CLINIC             WA  2021-03-17 00:00:00  Paid in Full
# 3  KIRTLEY CONSTRUCTION INC             CA  2021-10-16 00:00:00  Paid in Full
# 4              AERO BOX LLC  Not Available  2021-08-17 00:00:00  Paid in Full
#
#    Term  CurrentApprovalAmount  UndisbursedAmount  ServicingLenderLocationID  \
# 0    24              769358.78                0.0                      19248
# 1    24              736927.79                0.0                      19248
# 2    24              691355.00                0.0                       9551
# 3    24              499871.00                0.0                       9551
# 4    24              367437.00                0.0                      57328
#
#                      ServicingLenderName ServicingLenderState  \
# 0                           Synovus Bank                   GA
# 1                           Synovus Bank                   GA
# 2  Bank of America, National Association                   NC
# 3  Bank of America, National Association                   NC
# 4           The Huntington National Bank                   OH
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#                          BusinessAge     CD  JobsReported  NAICSCode  \
# 0  Existing or more than 2 years old  SC-05            62     325510
# 1  Existing or more than 2 years old  SC-06            73     561730
# 2    New Business or 2 years or less  WA-07            75          0
# 3    New Business or 2 years or less  CA-23            21     236115
# 4                      Not Available    NaN            25     484210
#
#               BusinessType  OriginatingLenderLocationID  \
# 0              Corporation                        19248
# 1      Sole Proprietorship                        19248
# 2  Non-Profit Organization                         9551
# 3              Corporation                         9551
# 4            Not Available                        57328
#
#                        OriginatingLender OriginatingLenderCity  \
# 0                           Synovus Bank              COLUMBUS
# 1                           Synovus Bank              COLUMBUS
# 2  Bank of America, National Association             CHARLOTTE
# 3  Bank of America, National Association             CHARLOTTE
# 4           The Huntington National Bank              COLUMBUS
#
#   OriginatingLenderState NonProfit  ForgivenessAmount    ForgivenessDateTS  \
# 0                     GA         N          773553.37  2020-11-20 00:00:00
# 1                     GA         N          746336.24  2021-08-12 00:00:00
# 2                     NC         Y          696677.49  2021-02-10 00:00:00
# 3                     NC         N          395264.11  2021-09-10 00:00:00
# 4                     OH         N          370819.35  2021-04-08 00:00:00
#
#                    SBAOfficeLabel              ServicingLenderFullAddress  \
# 0  SOUTH CAROLINA DISTRICT OFFICE             1148 Broadway, COLUMBUS, GA
# 1  SOUTH CAROLINA DISTRICT OFFICE             1148 Broadway, COLUMBUS, GA
# 2         SEATTLE DISTRICT OFFICE  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 3       SANTA ANA DISTRICT OFFICE  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 4   MASSACHUSETTS DISTRICT OFFICE             17 S High St., COLUMBUS, OH
#
#   LenderPercent  LenderProfit             LoanRange  JobRange  \
# 0            3%      23080.76  b $350,000-1 million  50 to 99
# 1            3%      22107.83  b $350,000-1 million  50 to 99
# 2            3%      20740.65  b $350,000-1 million  50 to 99
# 3            3%      14996.13  b $350,000-1 million  20 to 49
# 4            3%      11023.11  b $350,000-1 million  20 to 49
#
#                                             Industry  \
# 0                                      Manufacturing
# 1  Administrative and Support and Waste Managemen...
# 2                                      Not Available
# 3                                       Construction
# 4                     Transportation and Warehousing
#
#                                  IndustrySubsector  \
# 0  3255 Paint, Coating, and Adhesive Manufacturing
# 1         5617 Services to Buildings and Dwellings
# 2                                    Not Available
# 3           2361 Residential Building Construction
# 4                4842 Specialized Freight Trucking
#
#                                             LongName  \
# 0                    Paint and Coating Manufacturing
# 1                               Landscaping Services
# 2                                      Not Available
# 3  New Single-Family Housing Construction (except...
# 4             Used Household and Office Goods Moving
#
#                                        FullAdd
# 0            2410 Highway 15 South, Sumter, SC
# 1    7684 Southrail Road, North Charleston, SC
# 2                1850 BOYER AVE E, SEATTLE, WA
# 3     1661 MARTIN RANCH RD, SAN BERNARDINO, CA
# 4  Not Available, Not Available, Not Available

# %% [markdown]
# Column Check

# %%
ppp_pipe23.columns
print(len(ppp_pipe23.columns))
# Out:
# 39

# %% [markdown]
# Determining Necessary Columns for Final DataFrame

# %%
#keep track of columns removed
removed = ['NAICSCode', 'Industry', 'IndustrySubsector', 'LoanRange', 'JobRange', 'RuralUrbanIndicator','HubzoneIndicator','LMIIndicator']
#Industry and Industry Subsector taken from HASH file (NAICS)

cols =['LoanNumber','BorrowerName','DateApprovedTS','CurrentApprovalAmount','UndisbursedAmount', 
       'LoanStatus','LoanStatusDateTS','Term',
       'BusinessType','BusinessAge','JobsReported','CD','NonProfit', 
       'SBAOfficeCode','SBAOfficeLabel','ProcessingMethod', 
       'ServicingLenderLocationID','ServicingLenderName','ServicingLenderState','ServicingLenderFullAddress',
       'OriginatingLenderLocationID','OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
       'LenderPercent', 'LenderProfit',
       'ForgivenessAmount', 'ForgivenessDateTS','NAICSCode','LongName',] #30

ppp_pipe23 = ppp_pipe23[cols]
ppp_pipe23.head()
# Out:
#    LoanNumber              BorrowerName DateApprovedTS  CurrentApprovalAmount  \
# 0  9547507704     SUMTER COATINGS, INC.     2020-05-01              769358.78
# 1  9777677704     PLEASANT PLACES, INC.     2020-05-01              736927.79
# 2  5791407702   BOYER CHILDREN'S CLINIC     2020-05-01              691355.00
# 3  6223567700  KIRTLEY CONSTRUCTION INC     2020-05-01              499871.00
# 4  9662437702              AERO BOX LLC     2020-05-01              367437.00
#
#    UndisbursedAmount    LoanStatus     LoanStatusDateTS  Term  \
# 0                0.0  Paid in Full  2020-12-18 00:00:00    24
# 1                0.0  Paid in Full  2021-09-28 00:00:00    24
# 2                0.0  Paid in Full  2021-03-17 00:00:00    24
# 3                0.0  Paid in Full  2021-10-16 00:00:00    24
# 4                0.0  Paid in Full  2021-08-17 00:00:00    24
#
#               BusinessType                        BusinessAge  JobsReported  \
# 0              Corporation  Existing or more than 2 years old            62
# 1      Sole Proprietorship  Existing or more than 2 years old            73
# 2  Non-Profit Organization    New Business or 2 years or less            75
# 3              Corporation    New Business or 2 years or less            21
# 4            Not Available                      Not Available            25
#
#       CD NonProfit  SBAOfficeCode                  SBAOfficeLabel  \
# 0  SC-05         N            464  SOUTH CAROLINA DISTRICT OFFICE
# 1  SC-06         N            464  SOUTH CAROLINA DISTRICT OFFICE
# 2  WA-07         Y           1013         SEATTLE DISTRICT OFFICE
# 3  CA-23         N            920       SANTA ANA DISTRICT OFFICE
# 4    NaN         N            101   MASSACHUSETTS DISTRICT OFFICE
#
#   ProcessingMethod  ServicingLenderLocationID  \
# 0              PPP                      19248
# 1              PPP                      19248
# 2              PPP                       9551
# 3              PPP                       9551
# 4              PPP                      57328
#
#                      ServicingLenderName ServicingLenderState  \
# 0                           Synovus Bank                   GA
# 1                           Synovus Bank                   GA
# 2  Bank of America, National Association                   NC
# 3  Bank of America, National Association                   NC
# 4           The Huntington National Bank                   OH
#
#                ServicingLenderFullAddress  OriginatingLenderLocationID  \
# 0             1148 Broadway, COLUMBUS, GA                        19248
# 1             1148 Broadway, COLUMBUS, GA                        19248
# 2  100 N Tryon St, Ste 170, CHARLOTTE, NC                         9551
# 3  100 N Tryon St, Ste 170, CHARLOTTE, NC                         9551
# 4             17 S High St., COLUMBUS, OH                        57328
#
#                        OriginatingLender OriginatingLenderCity  \
# 0                           Synovus Bank              COLUMBUS
# 1                           Synovus Bank              COLUMBUS
# 2  Bank of America, National Association             CHARLOTTE
# 3  Bank of America, National Association             CHARLOTTE
# 4           The Huntington National Bank              COLUMBUS
#
#   OriginatingLenderState LenderPercent  LenderProfit  ForgivenessAmount  \
# 0                     GA            3%      23080.76          773553.37
# 1                     GA            3%      22107.83          746336.24
# 2                     NC            3%      20740.65          696677.49
# 3                     NC            3%      14996.13          395264.11
# 4                     OH            3%      11023.11          370819.35
#
#      ForgivenessDateTS  NAICSCode  \
# 0  2020-11-20 00:00:00     325510
# 1  2021-08-12 00:00:00     561730
# 2  2021-02-10 00:00:00          0
# 3  2021-09-10 00:00:00     236115
# 4  2021-04-08 00:00:00     484210
#
#                                             LongName
# 0                    Paint and Coating Manufacturing
# 1                               Landscaping Services
# 2                                      Not Available
# 3  New Single-Family Housing Construction (except...
# 4             Used Household and Office Goods Moving

# %% [markdown]
# <b>HASH file addition

# %%
ppp_hash = pd.read_csv("../data/ppp_hashSort23.csv", index_col=0) 
ppp_hash
# Out:
#         LoanNumber                 HASHcodePM                        Industry  \
# 0       3894287707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 1       3910757707  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 2       4559867701  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 3       4533907702  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# 4       9925367708  IND00SS00LR1JR1BT01BA1PPP                   Not Available
# ...            ...                        ...                             ...
# 965547  3488997103  IND99SS99LR5JR6BT02BA1PPP  Nonclassifiable Establishments
# 965548  5482257701  IND99SS99LR5JR7BT04BA2PPP  Nonclassifiable Establishments
# 965549  6699567107  IND99SS99LR5JR8BT02BA1PPP  Nonclassifiable Establishments
# 965550  5359597703  IND99SS99LR5JR8BT02BA2PPP  Nonclassifiable Establishments
# 965551  5843777700  IND99SS99LR5JR8BT02BA2PPP  Nonclassifiable Establishments
#
#                      IndustrySubsector
# 0                        Not Available
# 1                        Not Available
# 2                        Not Available
# 3                        Not Available
# 4                        Not Available
# ...                                ...
# 965547  Nonclassifiable Establishments
# 965548  Nonclassifiable Establishments
# 965549  Nonclassifiable Establishments
# 965550  Nonclassifiable Establishments
# 965551  Nonclassifiable Establishments
#
# [965552 rows x 4 columns]

# %% [markdown]
# <b>GEO, FIPS file addition

# %%
ppp_geo_fips=pd.read_csv("../data/state_data/geo/ppp_geo_fips23.csv", converters={'FIPS_z': str}, index_col=0)
ppp_geo_fips
# Out:
#         LoanNumber BorrowerState  \
# 0       5502308207            AK
# 1       6110847106            AK
# 2       4539098204            AK
# 3       5120868804            AK
# 4       6650277102            AK
# ...            ...           ...
# 965547  9725917702            MI
# 965548  9666867710            OH
# 965549  9662697710            MI
# 965550  9724667708            FL
# 965551  9672967701            OH
#
#                                                  FullAdd        Lat  \
# 0                 5015 BUSINESS PARK BLVD, ANCHORAGE, AK  61.174949
# 1                               7000 Uula St, BARROW, AK  71.297290
# 2       4700 Old International Airport Rd, Anchorage, AK  61.173232
# 3                   540 W Intl Airport Rd, Anchorage, AK  61.173164
# 4                        4300 BARTLETT STREET, HOMER, AK  59.652704
# ...                                                  ...        ...
# 965547                 128 E Front St, Traverse City, MI  44.985866
# 965548             11201 Shaker Blvd #126, Cleveland, OH  41.484647
# 965549            56409 Precision Dr, New Baltimore, MI   42.717196
# 965550              2707 Sadler Rd, Fernandina Beach, FL  30.639685
# 965551                    1602 N Curtice Rd, Curtice, OH  41.623289
#
#               Long           FIPS_z
# 0      -149.888309  020200019003022
# 1      -156.728897  021850001001069
# 2      -149.972718  020200023011009
# 3      -149.893283  020200025012000
# 4      -151.549793  021220010002001
# ...            ...              ...
# 965547  -85.603075  260899702012011
# 965548  -81.608183  390351986004000
# 965549  -82.808277  260992215001001
# 965550  -81.438653  120890501041005
# 965551  -83.370857  390950097001024
#
# [965552 rows x 6 columns]

# %%
lessthan=ppp_geo_fips.loc[ppp_geo_fips["FIPS_z"].astype(str).str.len() < 15]
lessthan
# Out:
# Empty DataFrame
# Columns: [LoanNumber, BorrowerState, FullAdd, Lat, Long, FIPS_z]
# Index: []

# %% [markdown]
# <b>Merged DataFrame

# %% [markdown]
# HASH > MAIN 23

# %%
#merge 
pd.set_option('display.max_columns', None)
ppp_hash_pipe23 = ppp_pipe23.merge(ppp_hash, on="LoanNumber", how="left")
ppp_hash_pipe23
# Out:
#         LoanNumber                                       BorrowerName  \
# 0       9547507704                              SUMTER COATINGS, INC.
# 1       9777677704                              PLEASANT PLACES, INC.
# 2       5791407702                            BOYER CHILDREN'S CLINIC
# 3       6223567700                           KIRTLEY CONSTRUCTION INC
# 4       9662437702                                       AERO BOX LLC
# ...            ...                                                ...
# 965547  4395967002                           ROY E PAULSON, JR., P.C.
# 965548  6985647108  SWEETWATER COUNTY CHILD DEVELOPMENTAL CENTER, ...
# 965549  7996438405                  ELECTRICAL SYSTEMS OF WYOMING INC
# 965550  9054647103                                     EDEN LIFE CARE
# 965551  9184687004                      S & S JOHNSON ENTERPRISES INC
#
#        DateApprovedTS  CurrentApprovalAmount  UndisbursedAmount    LoanStatus  \
# 0          2020-05-01              769358.78                0.0  Paid in Full
# 1          2020-05-01              736927.79                0.0  Paid in Full
# 2          2020-05-01              691355.00                0.0  Paid in Full
# 3          2020-05-01              499871.00                0.0  Paid in Full
# 4          2020-05-01              367437.00                0.0  Paid in Full
# ...               ...                    ...                ...           ...
# 965547     2020-04-03              150000.00                0.0  Paid in Full
# 965548     2020-04-14              150000.00                0.0  Paid in Full
# 965549     2021-02-12              150000.00                0.0  Paid in Full
# 965550     2020-04-15              150000.00                0.0  Paid in Full
# 965551     2020-04-09              150000.00                0.0  Paid in Full
#
#            LoanStatusDateTS  Term                 BusinessType  \
# 0       2020-12-18 00:00:00    24                  Corporation
# 1       2021-09-28 00:00:00    24          Sole Proprietorship
# 2       2021-03-17 00:00:00    24      Non-Profit Organization
# 3       2021-10-16 00:00:00    24                  Corporation
# 4       2021-08-17 00:00:00    24                Not Available
# ...                     ...   ...                          ...
# 965547  2021-01-13 00:00:00    24                  Corporation
# 965548  2020-12-08 00:00:00    24  Non-Profit Childcare Center
# 965549  2021-09-15 00:00:00    60     Subchapter S Corporation
# 965550  2022-03-08 00:00:00    60                  Corporation
# 965551  2021-10-22 00:00:00    24     Subchapter S Corporation
#
#                               BusinessAge  JobsReported     CD NonProfit  \
# 0       Existing or more than 2 years old            62  SC-05         N
# 1       Existing or more than 2 years old            73  SC-06         N
# 2         New Business or 2 years or less            75  WA-07         Y
# 3         New Business or 2 years or less            21  CA-23         N
# 4                           Not Available            25    NaN         N
# ...                                   ...           ...    ...       ...
# 965547  Existing or more than 2 years old            15    WY-         N
# 965548  Existing or more than 2 years old            42    WY-         Y
# 965549  Existing or more than 2 years old             5    WY-         N
# 965550    New Business or 2 years or less             7    WY-         N
# 965551  Existing or more than 2 years old            11    WY-         N
#
#         SBAOfficeCode                  SBAOfficeLabel ProcessingMethod  \
# 0                 464  SOUTH CAROLINA DISTRICT OFFICE              PPP
# 1                 464  SOUTH CAROLINA DISTRICT OFFICE              PPP
# 2                1013         SEATTLE DISTRICT OFFICE              PPP
# 3                 920       SANTA ANA DISTRICT OFFICE              PPP
# 4                 101   MASSACHUSETTS DISTRICT OFFICE              PPP
# ...               ...                             ...              ...
# 965547            897         WYOMING DISTRICT OFFICE              PPP
# 965548            897         WYOMING DISTRICT OFFICE              PPP
# 965549            897         WYOMING DISTRICT OFFICE              PPS
# 965550            897         WYOMING DISTRICT OFFICE              PPP
# 965551            897         WYOMING DISTRICT OFFICE              PPP
#
#         ServicingLenderLocationID                         ServicingLenderName  \
# 0                           19248                                Synovus Bank
# 1                           19248                                Synovus Bank
# 2                            9551       Bank of America, National Association
# 3                            9551       Bank of America, National Association
# 4                           57328                The Huntington National Bank
# ...                           ...                                         ...
# 965547                      42366                          Platte Valley Bank
# 965548                     122813                           NebraskaLand Bank
# 965549                      77189             First National Bank of Gillette
# 965550                      25901                         Small Business Bank
# 965551                     478121  Community Banks of Colorado, A Division of
#
#        ServicingLenderState  \
# 0                        GA
# 1                        GA
# 2                        NC
# 3                        NC
# 4                        OH
# ...                     ...
# 965547                   WY
# 965548                   NE
# 965549                   WY
# 965550                   KS
# 965551                   CO
#
#                                ServicingLenderFullAddress  \
# 0                             1148 Broadway, COLUMBUS, GA
# 1                             1148 Broadway, COLUMBUS, GA
# 2                  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 3                  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 4                             17 S High St., COLUMBUS, OH
# ...                                                   ...
# 965547                       2201 Main St, TORRINGTON, WY
# 965548                  1400 S Dewey St, NORTH PLATTE, NE
# 965549                   319 S Gillette Ave, GILLETTE, WY
# 965550                        13423 W 92nd St, LENEXA, KS
# 965551  7800 E Orchard Rd, Ste 200, GREENWOOD VILLAGE, CO
#
#         OriginatingLenderLocationID                      OriginatingLender  \
# 0                             19248                           Synovus Bank
# 1                             19248                           Synovus Bank
# 2                              9551  Bank of America, National Association
# 3                              9551  Bank of America, National Association
# 4                             57328           The Huntington National Bank
# ...                             ...                                    ...
# 965547                        42366                     Platte Valley Bank
# 965548                       122813                      NebraskaLand Bank
# 965549                        77189        First National Bank of Gillette
# 965550                        25901                    Small Business Bank
# 965551                        77193             Bank of Jackson Hole Trust
#
#        OriginatingLenderCity OriginatingLenderState LenderPercent  \
# 0                   COLUMBUS                     GA            3%
# 1                   COLUMBUS                     GA            3%
# 2                  CHARLOTTE                     NC            3%
# 3                  CHARLOTTE                     NC            3%
# 4                   COLUMBUS                     OH            3%
# ...                      ...                    ...           ...
# 965547            TORRINGTON                     WY            5%
# 965548          NORTH PLATTE                     NE            5%
# 965549              GILLETTE                     WY            5%
# 965550                LENEXA                     KS            5%
# 965551               Jackson                     WY            5%
#
#         LenderProfit  ForgivenessAmount    ForgivenessDateTS  NAICSCode  \
# 0           23080.76          773553.37  2020-11-20 00:00:00     325510
# 1           22107.83          746336.24  2021-08-12 00:00:00     561730
# 2           20740.65          696677.49  2021-02-10 00:00:00          0
# 3           14996.13          395264.11  2021-09-10 00:00:00     236115
# 4           11023.11          370819.35  2021-04-08 00:00:00     484210
# ...              ...                ...                  ...        ...
# 965547       7500.00          151037.50  2020-12-09 00:00:00     621210
# 965548       7500.00          150789.04  2020-11-03 00:00:00     624410
# 965549       7500.00          150743.84  2021-08-17 00:00:00     238210
# 965550       7500.00          152820.83  2022-02-23 00:00:00     621610
# 965551       7500.00          152162.50  2021-09-22 00:00:00     722511
#
#                                                  LongName  \
# 0                         Paint and Coating Manufacturing
# 1                                    Landscaping Services
# 2                                           Not Available
# 3       New Single-Family Housing Construction (except...
# 4                  Used Household and Office Goods Moving
# ...                                                   ...
# 965547                                Offices of Dentists
# 965548                            Child Day Care Services
# 965549  Electrical Contractors and Other Wiring Instal...
# 965550                          Home Health Care Services
# 965551                           Full-Service Restaurants
#
#                        HASHcodePM  \
# 0       IND32SS55LR2JR5BT01BA1PPP
# 1       IND56SS17LR2JR5BT07BA1PPP
# 2       IND00SS00LR2JR5BT04BA2PPP
# 3       IND23SS61LR2JR4BT01BA2PPP
# 4       IND48SS42LR2JR4BT13BA3PPP
# ...                           ...
# 965547  IND62SS12LR1JR3BT01BA1PPP
# 965548  IND62SS44LR1JR4BT11BA1PPP
# 965549  IND23SS82LR1JR1BT03BA1PPS
# 965550  IND62SS16LR1JR2BT01BA2PPP
# 965551  IND72SS25LR1JR3BT03BA1PPP
#
#                                                  Industry  \
# 0                                           Manufacturing
# 1       Administrative and Support and Waste Managemen...
# 2                                           Not Available
# 3                                            Construction
# 4                          Transportation and Warehousing
# ...                                                   ...
# 965547                  Health Care and Social Assistance
# 965548                  Health Care and Social Assistance
# 965549                                       Construction
# 965550                  Health Care and Social Assistance
# 965551                    Accommodation and Food Services
#
#                                       IndustrySubsector
# 0       3255 Paint, Coating, and Adhesive Manufacturing
# 1              5617 Services to Buildings and Dwellings
# 2                                         Not Available
# 3                2361 Residential Building Construction
# 4                     4842 Specialized Freight Trucking
# ...                                                 ...
# 965547                         6212 Offices of Dentists
# 965548                     6244 Child Day Care Services
# 965549              2382 Building Equipment Contractors
# 965550                   6216 Home Health Care Services
# 965551         7225 Restaurants and Other Eating Places
#
# [965552 rows x 33 columns]

# %% [markdown]
# HASH PIPE > RESULT (FIPS, GEO)

# %%
# Combine (coords, fips) only if "LoanNumber", "BorrowerState", "full_add" match 
ppp_hpgf = ppp_hash_pipe23.merge(ppp_geo_fips, on=["LoanNumber"], how="left")
ppp_hpgf
# Out:
#         LoanNumber                                       BorrowerName  \
# 0       9547507704                              SUMTER COATINGS, INC.
# 1       9777677704                              PLEASANT PLACES, INC.
# 2       5791407702                            BOYER CHILDREN'S CLINIC
# 3       6223567700                           KIRTLEY CONSTRUCTION INC
# 4       9662437702                                       AERO BOX LLC
# ...            ...                                                ...
# 965547  4395967002                           ROY E PAULSON, JR., P.C.
# 965548  6985647108  SWEETWATER COUNTY CHILD DEVELOPMENTAL CENTER, ...
# 965549  7996438405                  ELECTRICAL SYSTEMS OF WYOMING INC
# 965550  9054647103                                     EDEN LIFE CARE
# 965551  9184687004                      S & S JOHNSON ENTERPRISES INC
#
#        DateApprovedTS  CurrentApprovalAmount  UndisbursedAmount    LoanStatus  \
# 0          2020-05-01              769358.78                0.0  Paid in Full
# 1          2020-05-01              736927.79                0.0  Paid in Full
# 2          2020-05-01              691355.00                0.0  Paid in Full
# 3          2020-05-01              499871.00                0.0  Paid in Full
# 4          2020-05-01              367437.00                0.0  Paid in Full
# ...               ...                    ...                ...           ...
# 965547     2020-04-03              150000.00                0.0  Paid in Full
# 965548     2020-04-14              150000.00                0.0  Paid in Full
# 965549     2021-02-12              150000.00                0.0  Paid in Full
# 965550     2020-04-15              150000.00                0.0  Paid in Full
# 965551     2020-04-09              150000.00                0.0  Paid in Full
#
#            LoanStatusDateTS  Term                 BusinessType  \
# 0       2020-12-18 00:00:00    24                  Corporation
# 1       2021-09-28 00:00:00    24          Sole Proprietorship
# 2       2021-03-17 00:00:00    24      Non-Profit Organization
# 3       2021-10-16 00:00:00    24                  Corporation
# 4       2021-08-17 00:00:00    24                Not Available
# ...                     ...   ...                          ...
# 965547  2021-01-13 00:00:00    24                  Corporation
# 965548  2020-12-08 00:00:00    24  Non-Profit Childcare Center
# 965549  2021-09-15 00:00:00    60     Subchapter S Corporation
# 965550  2022-03-08 00:00:00    60                  Corporation
# 965551  2021-10-22 00:00:00    24     Subchapter S Corporation
#
#                               BusinessAge  JobsReported     CD NonProfit  \
# 0       Existing or more than 2 years old            62  SC-05         N
# 1       Existing or more than 2 years old            73  SC-06         N
# 2         New Business or 2 years or less            75  WA-07         Y
# 3         New Business or 2 years or less            21  CA-23         N
# 4                           Not Available            25    NaN         N
# ...                                   ...           ...    ...       ...
# 965547  Existing or more than 2 years old            15    WY-         N
# 965548  Existing or more than 2 years old            42    WY-         Y
# 965549  Existing or more than 2 years old             5    WY-         N
# 965550    New Business or 2 years or less             7    WY-         N
# 965551  Existing or more than 2 years old            11    WY-         N
#
#         SBAOfficeCode                  SBAOfficeLabel ProcessingMethod  \
# 0                 464  SOUTH CAROLINA DISTRICT OFFICE              PPP
# 1                 464  SOUTH CAROLINA DISTRICT OFFICE              PPP
# 2                1013         SEATTLE DISTRICT OFFICE              PPP
# 3                 920       SANTA ANA DISTRICT OFFICE              PPP
# 4                 101   MASSACHUSETTS DISTRICT OFFICE              PPP
# ...               ...                             ...              ...
# 965547            897         WYOMING DISTRICT OFFICE              PPP
# 965548            897         WYOMING DISTRICT OFFICE              PPP
# 965549            897         WYOMING DISTRICT OFFICE              PPS
# 965550            897         WYOMING DISTRICT OFFICE              PPP
# 965551            897         WYOMING DISTRICT OFFICE              PPP
#
#         ServicingLenderLocationID                         ServicingLenderName  \
# 0                           19248                                Synovus Bank
# 1                           19248                                Synovus Bank
# 2                            9551       Bank of America, National Association
# 3                            9551       Bank of America, National Association
# 4                           57328                The Huntington National Bank
# ...                           ...                                         ...
# 965547                      42366                          Platte Valley Bank
# 965548                     122813                           NebraskaLand Bank
# 965549                      77189             First National Bank of Gillette
# 965550                      25901                         Small Business Bank
# 965551                     478121  Community Banks of Colorado, A Division of
#
#        ServicingLenderState  \
# 0                        GA
# 1                        GA
# 2                        NC
# 3                        NC
# 4                        OH
# ...                     ...
# 965547                   WY
# 965548                   NE
# 965549                   WY
# 965550                   KS
# 965551                   CO
#
#                                ServicingLenderFullAddress  \
# 0                             1148 Broadway, COLUMBUS, GA
# 1                             1148 Broadway, COLUMBUS, GA
# 2                  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 3                  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 4                             17 S High St., COLUMBUS, OH
# ...                                                   ...
# 965547                       2201 Main St, TORRINGTON, WY
# 965548                  1400 S Dewey St, NORTH PLATTE, NE
# 965549                   319 S Gillette Ave, GILLETTE, WY
# 965550                        13423 W 92nd St, LENEXA, KS
# 965551  7800 E Orchard Rd, Ste 200, GREENWOOD VILLAGE, CO
#
#         OriginatingLenderLocationID                      OriginatingLender  \
# 0                             19248                           Synovus Bank
# 1                             19248                           Synovus Bank
# 2                              9551  Bank of America, National Association
# 3                              9551  Bank of America, National Association
# 4                             57328           The Huntington National Bank
# ...                             ...                                    ...
# 965547                        42366                     Platte Valley Bank
# 965548                       122813                      NebraskaLand Bank
# 965549                        77189        First National Bank of Gillette
# 965550                        25901                    Small Business Bank
# 965551                        77193             Bank of Jackson Hole Trust
#
#        OriginatingLenderCity OriginatingLenderState LenderPercent  \
# 0                   COLUMBUS                     GA            3%
# 1                   COLUMBUS                     GA            3%
# 2                  CHARLOTTE                     NC            3%
# 3                  CHARLOTTE                     NC            3%
# 4                   COLUMBUS                     OH            3%
# ...                      ...                    ...           ...
# 965547            TORRINGTON                     WY            5%
# 965548          NORTH PLATTE                     NE            5%
# 965549              GILLETTE                     WY            5%
# 965550                LENEXA                     KS            5%
# 965551               Jackson                     WY            5%
#
#         LenderProfit  ForgivenessAmount    ForgivenessDateTS  NAICSCode  \
# 0           23080.76          773553.37  2020-11-20 00:00:00     325510
# 1           22107.83          746336.24  2021-08-12 00:00:00     561730
# 2           20740.65          696677.49  2021-02-10 00:00:00          0
# 3           14996.13          395264.11  2021-09-10 00:00:00     236115
# 4           11023.11          370819.35  2021-04-08 00:00:00     484210
# ...              ...                ...                  ...        ...
# 965547       7500.00          151037.50  2020-12-09 00:00:00     621210
# 965548       7500.00          150789.04  2020-11-03 00:00:00     624410
# 965549       7500.00          150743.84  2021-08-17 00:00:00     238210
# 965550       7500.00          152820.83  2022-02-23 00:00:00     621610
# 965551       7500.00          152162.50  2021-09-22 00:00:00     722511
#
#                                                  LongName  \
# 0                         Paint and Coating Manufacturing
# 1                                    Landscaping Services
# 2                                           Not Available
# 3       New Single-Family Housing Construction (except...
# 4                  Used Household and Office Goods Moving
# ...                                                   ...
# 965547                                Offices of Dentists
# 965548                            Child Day Care Services
# 965549  Electrical Contractors and Other Wiring Instal...
# 965550                          Home Health Care Services
# 965551                           Full-Service Restaurants
#
#                        HASHcodePM  \
# 0       IND32SS55LR2JR5BT01BA1PPP
# 1       IND56SS17LR2JR5BT07BA1PPP
# 2       IND00SS00LR2JR5BT04BA2PPP
# 3       IND23SS61LR2JR4BT01BA2PPP
# 4       IND48SS42LR2JR4BT13BA3PPP
# ...                           ...
# 965547  IND62SS12LR1JR3BT01BA1PPP
# 965548  IND62SS44LR1JR4BT11BA1PPP
# 965549  IND23SS82LR1JR1BT03BA1PPS
# 965550  IND62SS16LR1JR2BT01BA2PPP
# 965551  IND72SS25LR1JR3BT03BA1PPP
#
#                                                  Industry  \
# 0                                           Manufacturing
# 1       Administrative and Support and Waste Managemen...
# 2                                           Not Available
# 3                                            Construction
# 4                          Transportation and Warehousing
# ...                                                   ...
# 965547                  Health Care and Social Assistance
# 965548                  Health Care and Social Assistance
# 965549                                       Construction
# 965550                  Health Care and Social Assistance
# 965551                    Accommodation and Food Services
#
#                                       IndustrySubsector BorrowerState  \
# 0       3255 Paint, Coating, and Adhesive Manufacturing            SC
# 1              5617 Services to Buildings and Dwellings            SC
# 2                                         Not Available            WA
# 3                2361 Residential Building Construction            CA
# 4                     4842 Specialized Freight Trucking            MI
# ...                                                 ...           ...
# 965547                         6212 Offices of Dentists            WY
# 965548                     6244 Child Day Care Services            WY
# 965549              2382 Building Equipment Contractors            WY
# 965550                   6216 Home Health Care Services            WY
# 965551         7225 Restaurants and Other Eating Places            WY
#
#                                             FullAdd        Lat        Long  \
# 0                 2410 Highway 15 South, Sumter, SC  33.853682  -80.369867
# 1         7684 Southrail Road, North Charleston, SC  32.942332  -80.066165
# 2                     1850 BOYER AVE E, SEATTLE, WA  47.636067 -122.302559
# 3          1661 MARTIN RANCH RD, SAN BERNARDINO, CA  34.224719 -117.372550
# 4                 20101 Cornillie Dr, Roseville, MI  42.521542  -82.913466
# ...                                             ...        ...         ...
# 965547                   102 N. Kenwood, CASPER, WY  42.850300 -106.304365
# 965548       1715 HITCHING POST DR, GREEN RIVER, WY  41.499071 -109.464675
# 965549                      1105 Adon Rd, Rozet, WY  44.435381 -105.226008
# 965550  30 N. Gould Street Suite 4000, SHERIDAN, WY  44.797763 -106.954952
# 965551      7342 Granite Loop Rd, TETON VILLAGE, WY  43.587714 -110.822222
#
#                  FIPS_z
# 0       450850019032026
# 1       450190031132025
# 2       530330062002034
# 3       060710045031000
# 4       260992551002000
# ...                 ...
# 965547  560250003001012
# 965548  560379707001020
# 965549  560050007023086
# 965550  560330003001053
# 965551  560399676021007
#
# [965552 rows x 38 columns]

# %% [markdown]
# <b>Null Check

# %%
#checks
pd.set_option('display.max_rows', 70)
print(ppp_hpgf.isnull().sum())
# Out:
# LoanNumber                      0
# BorrowerName                    0
# DateApprovedTS                  0
# CurrentApprovalAmount           0
# UndisbursedAmount               0
# LoanStatus                      0
# LoanStatusDateTS                0
# Term                            0
# BusinessType                    0
# BusinessAge                     0
# JobsReported                    0
# CD                             46
# NonProfit                       0
# SBAOfficeCode                   0
# SBAOfficeLabel                  0
# ProcessingMethod                0
# ServicingLenderLocationID       0
# ServicingLenderName             0
# ServicingLenderState            0
# ServicingLenderFullAddress      0
# OriginatingLenderLocationID     0
# OriginatingLender               0
# OriginatingLenderCity           0
# OriginatingLenderState          0
# LenderPercent                   0
# LenderProfit                    0
# ForgivenessAmount               0
# ForgivenessDateTS               0
# NAICSCode                       0
# LongName                        0
# HASHcodePM                      0
# Industry                        0
# IndustrySubsector               0
# BorrowerState                   0
# FullAdd                         0
# Lat                             0
# Long                            0
# FIPS_z                          0
# dtype: int64

# %%
ppp_hpgf.dtypes
# Out:
# LoanNumber                       int64
# BorrowerName                    object
# DateApprovedTS                  object
# CurrentApprovalAmount          float64
# UndisbursedAmount              float64
# LoanStatus                      object
# LoanStatusDateTS                object
# Term                             int64
# BusinessType                    object
# BusinessAge                     object
# JobsReported                     int64
# CD                              object
# NonProfit                       object
# SBAOfficeCode                    int64
# SBAOfficeLabel                  object
# ProcessingMethod                object
# ServicingLenderLocationID        int64
# ServicingLenderName             object
# ServicingLenderState            object
# ServicingLenderFullAddress      object
# OriginatingLenderLocationID      int64
# OriginatingLender               object
# OriginatingLenderCity           object
# OriginatingLenderState          object
# LenderPercent                   object
# LenderProfit                   float64
# ForgivenessAmount              float64
# ForgivenessDateTS               object
# NAICSCode                        int64
# LongName                        object
# HASHcodePM                      object
# Industry                        object
# IndustrySubsector               object
# BorrowerState                   object
# FullAdd                         object
# Lat                            float64
# Long                           float64
# FIPS_z                          object
# dtype: object

# %% [markdown]
# <b>Output for Labeled, Hashed, Geocoded, FIPS file

# %%
cols = ['LoanNumber','HASHcodePM','BorrowerName', 'DateApprovedTS', 'CurrentApprovalAmount',
       'UndisbursedAmount', 'LoanStatus', 'LoanStatusDateTS', 'Term',
       'BusinessType', 'BusinessAge', 'JobsReported', 'CD',
       'NonProfit', 'SBAOfficeCode', 'SBAOfficeLabel', 'ProcessingMethod',
       'ServicingLenderLocationID', 'ServicingLenderName','ServicingLenderState', 'ServicingLenderFullAddress',
       'OriginatingLenderLocationID', 'OriginatingLender','OriginatingLenderCity', 'OriginatingLenderState',
       'LenderPercent', 'LenderProfit', 'ForgivenessAmount','ForgivenessDateTS', 
       'NAICSCode', 'LongName', 'Industry','IndustrySubsector', 
       'BorrowerState', 'FullAdd', 'Lat', 'Long','FIPS_z']
ppp_hpgf = ppp_hpgf[cols]
ppp_hpgf.head()
# Out:
#    LoanNumber                 HASHcodePM              BorrowerName  \
# 0  9547507704  IND32SS55LR2JR5BT01BA1PPP     SUMTER COATINGS, INC.
# 1  9777677704  IND56SS17LR2JR5BT07BA1PPP     PLEASANT PLACES, INC.
# 2  5791407702  IND00SS00LR2JR5BT04BA2PPP   BOYER CHILDREN'S CLINIC
# 3  6223567700  IND23SS61LR2JR4BT01BA2PPP  KIRTLEY CONSTRUCTION INC
# 4  9662437702  IND48SS42LR2JR4BT13BA3PPP              AERO BOX LLC
#
#   DateApprovedTS  CurrentApprovalAmount  UndisbursedAmount    LoanStatus  \
# 0     2020-05-01              769358.78                0.0  Paid in Full
# 1     2020-05-01              736927.79                0.0  Paid in Full
# 2     2020-05-01              691355.00                0.0  Paid in Full
# 3     2020-05-01              499871.00                0.0  Paid in Full
# 4     2020-05-01              367437.00                0.0  Paid in Full
#
#       LoanStatusDateTS  Term             BusinessType  \
# 0  2020-12-18 00:00:00    24              Corporation
# 1  2021-09-28 00:00:00    24      Sole Proprietorship
# 2  2021-03-17 00:00:00    24  Non-Profit Organization
# 3  2021-10-16 00:00:00    24              Corporation
# 4  2021-08-17 00:00:00    24            Not Available
#
#                          BusinessAge  JobsReported     CD NonProfit  \
# 0  Existing or more than 2 years old            62  SC-05         N
# 1  Existing or more than 2 years old            73  SC-06         N
# 2    New Business or 2 years or less            75  WA-07         Y
# 3    New Business or 2 years or less            21  CA-23         N
# 4                      Not Available            25    NaN         N
#
#    SBAOfficeCode                  SBAOfficeLabel ProcessingMethod  \
# 0            464  SOUTH CAROLINA DISTRICT OFFICE              PPP
# 1            464  SOUTH CAROLINA DISTRICT OFFICE              PPP
# 2           1013         SEATTLE DISTRICT OFFICE              PPP
# 3            920       SANTA ANA DISTRICT OFFICE              PPP
# 4            101   MASSACHUSETTS DISTRICT OFFICE              PPP
#
#    ServicingLenderLocationID                    ServicingLenderName  \
# 0                      19248                           Synovus Bank
# 1                      19248                           Synovus Bank
# 2                       9551  Bank of America, National Association
# 3                       9551  Bank of America, National Association
# 4                      57328           The Huntington National Bank
#
#   ServicingLenderState              ServicingLenderFullAddress  \
# 0                   GA             1148 Broadway, COLUMBUS, GA
# 1                   GA             1148 Broadway, COLUMBUS, GA
# 2                   NC  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 3                   NC  100 N Tryon St, Ste 170, CHARLOTTE, NC
# 4                   OH             17 S High St., COLUMBUS, OH
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                        19248                           Synovus Bank
# 1                        19248                           Synovus Bank
# 2                         9551  Bank of America, National Association
# 3                         9551  Bank of America, National Association
# 4                        57328           The Huntington National Bank
#
#   OriginatingLenderCity OriginatingLenderState LenderPercent  LenderProfit  \
# 0              COLUMBUS                     GA            3%      23080.76
# 1              COLUMBUS                     GA            3%      22107.83
# 2             CHARLOTTE                     NC            3%      20740.65
# 3             CHARLOTTE                     NC            3%      14996.13
# 4              COLUMBUS                     OH            3%      11023.11
#
#    ForgivenessAmount    ForgivenessDateTS  NAICSCode  \
# 0          773553.37  2020-11-20 00:00:00     325510
# 1          746336.24  2021-08-12 00:00:00     561730
# 2          696677.49  2021-02-10 00:00:00          0
# 3          395264.11  2021-09-10 00:00:00     236115
# 4          370819.35  2021-04-08 00:00:00     484210
#
#                                             LongName  \
# 0                    Paint and Coating Manufacturing
# 1                               Landscaping Services
# 2                                      Not Available
# 3  New Single-Family Housing Construction (except...
# 4             Used Household and Office Goods Moving
#
#                                             Industry  \
# 0                                      Manufacturing
# 1  Administrative and Support and Waste Managemen...
# 2                                      Not Available
# 3                                       Construction
# 4                     Transportation and Warehousing
#
#                                  IndustrySubsector BorrowerState  \
# 0  3255 Paint, Coating, and Adhesive Manufacturing            SC
# 1         5617 Services to Buildings and Dwellings            SC
# 2                                    Not Available            WA
# 3           2361 Residential Building Construction            CA
# 4                4842 Specialized Freight Trucking            MI
#
#                                      FullAdd        Lat        Long  \
# 0          2410 Highway 15 South, Sumter, SC  33.853682  -80.369867
# 1  7684 Southrail Road, North Charleston, SC  32.942332  -80.066165
# 2              1850 BOYER AVE E, SEATTLE, WA  47.636067 -122.302559
# 3   1661 MARTIN RANCH RD, SAN BERNARDINO, CA  34.224719 -117.372550
# 4          20101 Cornillie Dr, Roseville, MI  42.521542  -82.913466
#
#             FIPS_z
# 0  450850019032026
# 1  450190031132025
# 2  530330062002034
# 3  060710045031000
# 4  260992551002000

# %%
ppp_hpgf.to_csv("../data/pipe_hpgf23.csv")

# %% [markdown]
# <b>Duplicate Row Fix:

# %% [markdown]
# #Locate extra row 965553/965552
# dups =ppp_hpgf["LoanNumber"]
# ppp_hpgf[dups.isin(dups[dups.duplicated()])].sort_values("LoanNumber")
# #Duplicated row does not have FIPS_z value
# ppp_hpgf = ppp_hpgf.drop(index=904806).reset_index(drop=True)
# #verify
# dups =ppp_hpgf["LoanNumber"]
# ppp_hpgf[dups.isin(dups[dups.duplicated()])].sort_values("LoanNumber")
# #Lat='None'>NaN
# ppp_hpgf["Lat"].replace(r'None', np.nan, regex=True)

# %% [markdown]
# <b>Parsing by State Output for Labeled, Hashed, Geocoded, FIPS file

# %% [markdown]
# Removed State Hashed Files 07/19

# %%
#compute file for each state
ak_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AK", :]
al_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AL", :]
ar_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AR", :]
as_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AS", :] #American Samoa
az_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "AZ", :]

ca_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CA", :]
co_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CO", :]
ct_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "CT", :]
dc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DC", :] #D.C.
de_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "DE", :]

fl_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "FL", :]
ga_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GA", :]
gu_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "GU", :] #Guam
hi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "HI", :]
ia_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IA", :]

id_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ID", :]
il_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IL", :]
in_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "IN", :]
ks_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KS", :]
ky_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "KY", :]
la_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "LA", :]
ma_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MA", :]
md_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MD", :]
me_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ME", :]
mi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MI", :]
mn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MN", :]
mo_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MO", :]
mp_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MP", :] #Saipan Member of Parliament
ms_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MS", :]
mt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "MT", :]
nc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NC", :]
nd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "ND", :]
ne_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NE", :]
nh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NH", :]
nj_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NJ", :]
nm_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NM", :]
nv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NV", :]
ny_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "NY", :]
oh_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OH", :]
ok_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OK", :]
or_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "OR", :]
pa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PA", :]
pr_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "PR", :] #Puerto Rico
ri_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "RI", :]
sc_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SC", :]
sd_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "SD", :]
tn_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TN", :]
tx_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "TX", :]
ut_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "UT", :]
va_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VA", :]
vi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VI", :] #Virgin Islands
vt_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "VT", :]
wa_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WA", :]
wi_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WI", :]
wv_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WV", :]
wy_hpgf = ppp_hpgf.loc[ppp_hpgf["BorrowerState"] == "WY", :]

# %% [markdown]
# FIPS states

# %% [markdown]
# All States 2023 update

# %%
#PointPair each state file separately in aggregation notebook
ak_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ak.csv") 
al_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_al.csv")
ar_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ar.csv") 
as_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_as.csv")
az_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_az.csv")  
ca_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ca.csv")  
co_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_co.csv") 
ct_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ct.csv")  
dc_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_dc.csv")
de_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_de.csv") 
fl_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_fl.csv") 
ga_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ga.csv") 
gu_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_gu.csv")
hi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_hi.csv") 
ia_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ia.csv")  
id_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_id.csv")  
il_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_il.csv")  
in_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_in.csv") 
ks_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ks.csv")  
ky_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ky.csv")  
la_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_la.csv")
ma_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ma.csv") 
md_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_md.csv")
me_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_me.csv")  
mi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mi.csv") 
mn_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mn.csv") 
mo_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mo.csv")  
mp_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mp.csv") 
ms_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ms.csv")
mt_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_mt.csv")
nc_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nc.csv") 
nd_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nd.csv")  
ne_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ne.csv")
nh_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nh.csv")  
nj_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nj.csv")
nm_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nm.csv") 
nv_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_nv.csv")  
ny_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ny.csv")  
oh_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_oh.csv")
ok_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ok.csv") 
or_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_or.csv")  
pa_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_pa.csv")
pr_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_pr.csv")  
ri_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ri.csv") 
sc_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_sc.csv") 
sd_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_sd.csv") 
tn_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_tn.csv")  
tx_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_tx.csv")  
ut_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_ut.csv")  
va_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_va.csv")  
vi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_vi.csv")  
vt_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_vt.csv")
wa_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wa.csv")  
wi_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wi.csv")  
wv_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wv.csv") 
wy_hpgf.to_csv("../data/state_data/hash_states/23/hpgf_wy.csv")
